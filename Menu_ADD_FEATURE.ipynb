# %%
import pandas as pd
import numpy as np
from pycaret.regression import setup, compare_models, blend_models,tune_model,predict_model,get_config, finalize_model

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['font.family'] = 'Gulim'

# %%
from workalendar.asia import SouthKorea
import pendulum

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# ## 전처리
# - 일자에서 월과 일을 분리
# - 요일을 레이블 인코딩화(EDA로 요일의 중요도 순 파악)
# - 월 별, 일 별 중식 석식 수요 차이 파악

# %%
train['월'] = pd.DatetimeIndex(train['일자']).month
test['월'] = pd.DatetimeIndex(test['일자']).month
train['주'] = pd.DatetimeIndex(train['일자']).week
test['주'] = pd.DatetimeIndex(test['일자']).week
train['일'] = pd.DatetimeIndex(train['일자']).day
test['일'] = pd.DatetimeIndex(test['일자']).day

train['출근'] = train['본사정원수']-(train['본사휴가자수']+train['본사출장자수']+train['현본사소속재택근무자수'])
train['휴가비율'] = train['본사휴가자수']/train['본사정원수']
train['출장비율'] = train['본사출장자수']/train['본사정원수']
train['야근비율'] = train['본사시간외근무명령서승인건수']/train['출근']
train['재택비율'] = train['현본사소속재택근무자수']/train['본사정원수']

test['출근'] = test['본사정원수']-(test['본사휴가자수']+test['본사출장자수']+test['현본사소속재택근무자수'])
test['휴가비율'] = test['본사휴가자수']/test['본사정원수']
test['출장비율'] = test['본사출장자수']/test['본사정원수']
test['야근비율'] = test['본사시간외근무명령서승인건수']/test['출근']
test['재택비율'] = test['현본사소속재택근무자수']/test['본사정원수']

# %%
month_rank4dinner = {
    1: 11,
    2: 2,
    3: 1,
    4: 4,
    5: 7,
    6: 6,
    7: 10,
    8: 8,
    9: 5,
    10: 3,
    11: 9,
    12: 12
}
train['월(석식)'] = train['월'].map(month_rank4dinner)
test['월(석식)'] = test['월'].map(month_rank4dinner)

month_rank4lunch = {
    1: 3,
    2: 1,
    3: 2,
    4: 6,
    5: 7,
    6: 8,
    7: 10,
    8: 9,
    9: 5,
    10: 4,
    11: 11,
    12: 12
}
train['월(중식)'] = train['월'].map(month_rank4lunch)
test['월(중식)'] = test['월'].map(month_rank4lunch)

weekday_rank4dinner = {
    '월': 1,
    '화': 2,
    '수': 4,
    '목': 3,
    '금': 5,
}

weekday_rank4lunch = {
    '월': 1,
    '화': 2,
    '수': 3,
    '목': 4,
    '금': 5,
}

train['요일(석식)'] = train['요일'].map(weekday_rank4dinner)
test['요일(석식)'] = test['요일'].map(weekday_rank4dinner)

train['요일(중식)'] = train['요일'].map(weekday_rank4lunch)
test['요일(중식)'] = test['요일'].map(weekday_rank4lunch)

# %%
rank = pd.DataFrame(range(1,53))
week_rank_lunch = pd.pivot_table(train,values='중식계',index='주').sort_values(by='중식계').reset_index().drop('중식계',axis=1)
week_rank_dinner = pd.pivot_table(train,values='석식계',index='주').sort_values(by='석식계').reset_index().drop('석식계',axis=1)


week_rank4lunch = {}
for i in range(len(rank)):
    week_rank4lunch[week_rank_lunch['주'][i]] = rank[0][i]


week_rank4dinner = {}
for i in range(len(rank)):
    week_rank4dinner[week_rank_dinner['주'][i]] = rank[0][i]
    
    
train['주(중식)'] = train['주'].map(week_rank4lunch)
test['주(중식)'] = test['주'].map(week_rank4lunch)

train['주(석식)'] = train['주'].map(week_rank4dinner)
test['주(석식)'] = test['주'].map(week_rank4dinner)

# %%
def is_holiday(date):
    holidays = list(map(str, pd.Series(np.array(SouthKorea().holidays(int(date[:4])))[:, 0])))
    
    yesterday = str(np.datetime64(date) - 1)
    tomorrow = str(np.datetime64(date) + 1)

    if tomorrow in holidays and yesterday in holidays:
        return 'S'
    if tomorrow in holidays:
        return 'T'
    elif yesterday in holidays:
        return 'Y'
    else : 
        return 'N'

def week_of_month(x):
    dt = pendulum.parse(x)
    
    wom = dt.week_of_month
    if wom < 0:
        wom += 52
    return wom
    

df = pd.concat([train[['본사정원수', '일자']], test[['본사정원수', '일자']]])
df['년월'] = df['일자'].apply(lambda x : x[:7])
df = df[['년월', '본사정원수']].groupby(by=['년월'], as_index=False).mean()

def member_change(date):
    this_month = date[:7]
    last_month = str(np.datetime64(this_month) - 1)
    
    this_month_member = int(df[df['년월'] == this_month]['본사정원수'])
    last_month_member = int(df[df['년월'] == last_month]['본사정원수'])
    
    
    return  this_month_member - last_month_member

train['공휴일전후'] = train['일자'].apply(is_holiday)
test['공휴일전후'] = test['일자'].apply(is_holiday)

train['몇주차'] = train['일자'].apply(week_of_month)
test['몇주차'] = test['일자'].apply(week_of_month)

train = train[train['일자'] > '2016-03']
train['인원변화'] = train['일자'].apply(member_change)
test['인원변화'] = test['일자'].apply(member_change)

# %% [markdown]
# ## 공휴일 변수 생성

# %%
# 메뉴 변수 없이 사용할떄 해당 코드 사용['공휴일전후', '몇주차', '인원변화']

lunch_train = train[['공휴일전후', '몇주차', '인원변화', '요일(중식)','월(중식)','일','주(중식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','중식계']]
lunch_test = test[['공휴일전후', '몇주차', '인원변화', '요일(중식)','월(중식)','일','주(중식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수']]

dinner_train= train[['공휴일전후', '몇주차', '인원변화', '요일(석식)','월(석식)','일','주(석식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','석식계']]
dinner_test = test[['공휴일전후', '몇주차', '인원변화', '요일(석식)','월(석식)','일','주(석식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수']]

# %%
lunch_train.columns
# Out:
# Index(['공휴일전후', '몇주차', '인원변화', '요일(중식)', '월(중식)', '일', '주(중식)', '출근', '휴가비율',
#        '출장비율', '야근비율', '재택비율', '본사출장자수', '본사휴가자수', '중식계'],
#       dtype='object')

# %%
print(lunch_train.shape)
print(lunch_test.shape)
# Out:
# (1187, 15)
# (50, 14)

# %%
print(dinner_train.shape)
print(dinner_test.shape)
# Out:
# (1187, 15)
# (50, 14)

# %% [markdown]
# #### 분포 확인 및 분포 조정

# %% [markdown]
# # 중식 예측모델

# %%
lunch_regression_model = setup(data=lunch_train, target='중식계',
                               train_size=0.8,
                               n_jobs=-1,
                               fold=8,
                               numeric_imputation = 'mean',
                               normalize = True)
# Out:
# <style  type="text/css" >
# #T_3ab4d_row27_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_3ab4d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ab4d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3ab4d_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_3ab4d_row0_col1" class="data row0 col1" >6832</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3ab4d_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_3ab4d_row1_col1" class="data row1 col1" >중식계</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3ab4d_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_3ab4d_row2_col1" class="data row2 col1" >(1187, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3ab4d_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_3ab4d_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3ab4d_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_3ab4d_row4_col1" class="data row4 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3ab4d_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_3ab4d_row5_col1" class="data row5 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3ab4d_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_3ab4d_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3ab4d_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_3ab4d_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3ab4d_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_3ab4d_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3ab4d_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_3ab4d_row9_col1" class="data row9 col1" >(949, 37)</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_3ab4d_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_3ab4d_row10_col1" class="data row10 col1" >(238, 37)</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_3ab4d_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_3ab4d_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_3ab4d_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_3ab4d_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_3ab4d_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_3ab4d_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_3ab4d_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_3ab4d_row14_col1" class="data row14 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_3ab4d_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_3ab4d_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_3ab4d_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_3ab4d_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_3ab4d_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_3ab4d_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_3ab4d_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_3ab4d_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_3ab4d_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_3ab4d_row19_col1" class="data row19 col1" >c93b</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_3ab4d_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_3ab4d_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_3ab4d_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_3ab4d_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_3ab4d_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_3ab4d_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_3ab4d_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_3ab4d_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab4d_level0_row24" class="row_heading level0 row24" >

# %%
# 최고 성능 모델 선정(2개)
lunch_regression_best_models = compare_models(fold=8, sort='MAE', n_select=2, exclude=['huber','llar','lar','par','lasso'])
# Out:
# <style  type="text/css" >
#     #T_40319_ th {
#           text-align: left;
#     }#T_40319_row0_col0,#T_40319_row0_col2,#T_40319_row0_col3,#T_40319_row0_col4,#T_40319_row0_col5,#T_40319_row0_col6,#T_40319_row1_col0,#T_40319_row1_col1,#T_40319_row2_col0,#T_40319_row2_col1,#T_40319_row2_col2,#T_40319_row2_col3,#T_40319_row2_col4,#T_40319_row2_col5,#T_40319_row2_col6,#T_40319_row3_col0,#T_40319_row3_col1,#T_40319_row3_col2,#T_40319_row3_col3,#T_40319_row3_col4,#T_40319_row3_col5,#T_40319_row3_col6,#T_40319_row4_col0,#T_40319_row4_col1,#T_40319_row4_col2,#T_40319_row4_col3,#T_40319_row4_col4,#T_40319_row4_col5,#T_40319_row4_col6,#T_40319_row5_col0,#T_40319_row5_col1,#T_40319_row5_col2,#T_40319_row5_col3,#T_40319_row5_col4,#T_40319_row5_col5,#T_40319_row5_col6,#T_40319_row6_col0,#T_40319_row6_col1,#T_40319_row6_col2,#T_40319_row6_col3,#T_40319_row6_col4,#T_40319_row6_col5,#T_40319_row6_col6,#T_40319_row7_col0,#T_40319_row7_col1,#T_40319_row7_col2,#T_40319_row7_col3,#T_40319_row7_col4,#T_40319_row7_col5,#T_40319_row7_col6,#T_40319_row8_col0,#T_40319_row8_col1,#T_40319_row8_col2,#T_40319_row8_col3,#T_40319_row8_col4,#T_40319_row8_col5,#T_40319_row8_col6,#T_40319_row9_col0,#T_40319_row9_col1,#T_40319_row9_col2,#T_40319_row9_col3,#T_40319_row9_col4,#T_40319_row9_col5,#T_40319_row9_col6,#T_40319_row10_col0,#T_40319_row10_col1,#T_40319_row10_col2,#T_40319_row10_col3,#T_40319_row10_col4,#T_40319_row10_col5,#T_40319_row10_col6,#T_40319_row11_col0,#T_40319_row11_col1,#T_40319_row11_col2,#T_40319_row11_col3,#T_40319_row11_col4,#T_40319_row11_col5,#T_40319_row11_col6,#T_40319_row12_col0,#T_40319_row12_col1,#T_40319_row12_col2,#T_40319_row12_col3,#T_40319_row12_col4,#T_40319_row12_col5,#T_40319_row12_col6,#T_40319_row13_col0,#T_40319_row13_col1,#T_40319_row13_col2,#T_40319_row13_col3,#T_40319_row13_col4,#T_40319_row13_col5,#T_40319_row13_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_40319_row0_col1,#T_40319_row1_col2,#T_40319_row1_col3,#T_40319_row1_col4,#T_40319_row1_col5,#T_40319_row1_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_40319_row0_col7,#T_40319_row1_col7,#T_40319_row2_col7,#T_40319_row3_col7,#T_40319_row5_col7,#T_40319_row6_col7,#T_40319_row7_col7,#T_40319_row8_col7,#T_40319_row9_col7,#T_40319_row10_col7,#T_40319_row12_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_40319_row4_col7,#T_40319_row11_col7,#T_40319_row13_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_40319_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40319_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_40319_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_40319_row0_col1" class="data row0 col1" >67.3802</td>
#                         <td id="T_40319_row0_col2" class="data row0 col2" >7941.1659</td>
#                         <td id="T_40319_row0_col3" class="data row0 col3" >88.8640</td>
#                         <td id="T_40319_row0_col4" class="data row0 col4" >0.8133</td>
#                         <td id="T_40319_row0_col5" class="data row0 col5" >0.1124</td>
#                         <td id="T_40319_row0_col6" class="data row0 col6" >0.0828</td>
#                         <td id="T_40319_row0_col7" class="data row0 col7" >1.0025</td>
#             </tr>
#             <tr>
#                         <th id="T_40319_level0_row1" class="row_heading level0 row1" >gbr</th>
#                         <td id="T_40319_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_40319_row1_col1" class="data row1 col1" >67.3868</td>
#                         <td id="T_40319_row1_col2" class="data row1 col2" >7927.4191</td>
#                         <td id="T_40319_row1_col3" class="data row1 col3" >88.7261</td>
#                         <td id="T_40319_row1_col4" class="data row1 col4" >0.8138</td>
#                         <td id="T_40319_row1_col5" class="data row1 col5" >0.1098</td>
#                         <td id="T_40319_row1_col6" class="data row1 col6" >0.0816</td>
#                         <td id="T_40319_row1_col7" class="data row1 col7" >0.0475</td>
#             </tr>
#             <tr>
#                         <th id="T_40319_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_40319_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#                         <td id="T_40319_row2_col1" class="data row2 col1" >70.3790</td>
#                         <td id="T_40319_row2_col2" class="data row2 col2" >9105.6355</td>
#                         <td id="T_40319_row2_col3" class="data row2 col3" >94.9577</td>
#                         <td id="T_40319_row2_col4" class="data row2 col4" >0.7864</td>
#                         <td id="T_40319_row2_col5" class="data row2 col5" >0.1188</td>
#                         <td id="T_40319_row2_col6" class="data row2 col6" >0.0863</td>
#                         <td id="T_40319_row2_col7" class="data row2 col7" >0.1562</td>
#             </tr>
#             <tr>
#                         <th id="T_40319_level0_row3" class="row_heading level0 row3" >ridge</th>
#                         <td id="T_40319_row3_col0" class="data row3 col0" >Ridge Regression</td>
#                         <td id="T_40319_row3_col1" class="data row3 col1" >71.0115</td>
#                         <td id="T_40319_row3_col2" class="data row3 col2" >8990.0336</td>
#                         <td id="T_40319_row3_col3" class="data row3 col3" >94.4018</td>
#                         <td id="T_40319_row3_col4" class="data row3 col4" >0.7890</td>
#                         <td id="T_40319_row3_col5" class="data row3 col5" >0.1175</td>
#                         <td id="T_40319_row3_col6" class="data row3 col6" >0.0859</td>
#                         <td id="T_40319_row3_col7" class="data row3 col7" >0.0088</td>
#             </tr>
#             <tr>
#                         <th id="T_40319_level0_row4" class="row_heading level0 row4" >br</th>
#                         <td id="T_40319_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#                         <td id="T_40319_row4_col1" class="data row4 col1" >71.0158</td>
#                         <td id="T_40319_row4_col2" class="data row4 col2" >8971.3659</td>
#                         <td id="T_40319_row4_col3" class="data row4 col3" >94.3025</td>
#                         <td id="T_40319_row4_col4" class="data row4 col4" >0.7894</td>
#                         <td id="T_40319_row4_col5" class="data row4 col5" >0.1173</td>
#                         <td id="T_40319_row4_col6" class="data row4 col6" >0.0858</td>
#                         <td id="T_40319_row4_col7" class="data row4 col7" >0.0075</td>
#             </tr>
#             <tr>
#                         <th id="T_40319_level0_row5" class="row_heading level0 row5" >lr</th>
#                         <td id="T_40319_row5_col0" class="data row5 col0" >Linear Regression</td>
#                         <td id="T_40319_row5_col1" class="data row5 col1" >71.2060</td>
#                         <td id="T_40319_row5_col2" class="data row5 col2" >9050.8275</td>
#                         <td id="T_40319_row5_col3" class="data row5 col3" >94.7295</td>
#                         <td id="T_40319_row5_col4" class="data

# %%
lunch_regression_best_models_tuned = [tune_model(i, optimize='MAE') for i in lunch_regression_best_models]
# Out:
# <style  type="text/css" >
# #T_9949f_row8_col0,#T_9949f_row8_col1,#T_9949f_row8_col2,#T_9949f_row8_col3,#T_9949f_row8_col4,#T_9949f_row8_col5{
#             background:  yellow;
#         }</style><table id="T_9949f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9949f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9949f_row0_col0" class="data row0 col0" >60.1716</td>
#                         <td id="T_9949f_row0_col1" class="data row0 col1" >6450.0668</td>
#                         <td id="T_9949f_row0_col2" class="data row0 col2" >80.3123</td>
#                         <td id="T_9949f_row0_col3" class="data row0 col3" >0.8474</td>
#                         <td id="T_9949f_row0_col4" class="data row0 col4" >0.1026</td>
#                         <td id="T_9949f_row0_col5" class="data row0 col5" >0.0762</td>
#             </tr>
#             <tr>
#                         <th id="T_9949f_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9949f_row1_col0" class="data row1 col0" >77.4621</td>
#                         <td id="T_9949f_row1_col1" class="data row1 col1" >10300.5201</td>
#                         <td id="T_9949f_row1_col2" class="data row1 col2" >101.4915</td>
#                         <td id="T_9949f_row1_col3" class="data row1 col3" >0.7656</td>
#                         <td id="T_9949f_row1_col4" class="data row1 col4" >0.1134</td>
#                         <td id="T_9949f_row1_col5" class="data row1 col5" >0.0879</td>
#             </tr>
#             <tr>
#                         <th id="T_9949f_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9949f_row2_col0" class="data row2 col0" >66.2129</td>
#                         <td id="T_9949f_row2_col1" class="data row2 col1" >6663.2828</td>
#                         <td id="T_9949f_row2_col2" class="data row2 col2" >81.6289</td>
#                         <td id="T_9949f_row2_col3" class="data row2 col3" >0.8206</td>
#                         <td id="T_9949f_row2_col4" class="data row2 col4" >0.1088</td>
#                         <td id="T_9949f_row2_col5" class="data row2 col5" >0.0823</td>
#             </tr>
#             <tr>
#                         <th id="T_9949f_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9949f_row3_col0" class="data row3 col0" >69.7933</td>
#                         <td id="T_9949f_row3_col1" class="data row3 col1" >9616.6043</td>
#                         <td id="T_9949f_row3_col2" class="data row3 col2" >98.0643</td>
#                         <td id="T_9949f_row3_col3" class="data row3 col3" >0.7753</td>
#                         <td id="T_9949f_row3_col4" class="data row3 col4" >0.1211</td>
#                         <td id="T_9949f_row3_col5" class="data row3 col5" >0.0843</td>
#             </tr>
#             <tr>
#                         <th id="T_9949f_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9949f_row4_col0" class="data row4 col0" >66.8674</td>
#                         <td id="T_9949f_row4_col1" class="data row4 col1" >8714.4451</td>
#                         <td id="T_9949f_row4_col2" class="data row4 col2" >93.3512</td>
#                         <td id="T_9949f_row4_col3" class="data row4 col3" >0.8042</td>
#                         <td id="T_9949f_row4_col4" class="data row4 col4" >0.1035</td>
#                         <td id="T_9949f_row4_col5" class="data row4 col5" >0.0743</td>
#             </tr>
#             <tr>
#                         <th id="T_9949f_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9949f_row5_col0" class="data row5 col0" >71.1330</td>
#                         <td id="T_9949f_row5_col1" class="data row5 col1" >8026.2782</td>
#                         <td id="T_9949f_row5_col2" class="data row5 col2" >89.5895</td>
#                         <td id="T_9949f_row5_col3" class="data row5 col3" >0.8180</td>
#                         <td id="T_9949f_row5_col4" class="data row5 col4" >0.1174</td>
#                         <td id="T_9949f_row5_col5" class="data row5 col5" >0.0907</td>
#             </tr>
#             <tr>
#                         <th id="T_9949f_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9949f_row6_col0" class="data row6 col0" >63.8945</td>
#                         <td id="T_9949f_row6_col1" class="data row6 col1" >7374.2564</td>
#                         <td id="T_9949f_row6_col2" class="data row6 col2" >85.8735</td>
#                         <td id="T_9949f_row6_col3" class="data row6 col3" >0.8185</td>
#                         <td id="T_9949f_row6_col4" class="data row6 col4" >0.1006</td>
#                         <td id="T_9949f_row6_col5" class="data row6 col5" >0.0758</td>
#             </tr>
#             <tr>
#                         <th id="T_9949f_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9949f_row7_col0" class="data row7 col0" >74.0669</td>
#                         <td id="T_9949f_row7_col1" class="data row7 col1" >9766.4902</td>
#                         <td id="T_9949f_row7_col2" class="data row7 col2" >98.8256</td>
#                         <td id="T_9949f_row7_col3" class="data row7 col3" >0.7782</td>
#                         <td id="T_9949f_row7_col4" class="data row7 col4" >0.1274</td>
#                         <td id="T_9949f_row7_col5" class="data row7 col5" >0.0914</td>
#             </tr>
#             <tr>
#                         <th id="T_9949f_level0_row8" class="row_heading level0 row8" >Mean</th>
#                         <td id="T_9949f_row8_col0" class="data row8 col0" >68.7002</td>
#                         <td id="T_9949f_row8_col1" class="data row8 col1" >8363.9930</td>
#                         <td id="T_9949f_row8_col2" class="data row8 col2" >91.1421</td>
#                         <td id="T_9949f_row8_col3" class="data row8 col3" >0.8035</td>
#                         <td id="T_9949f_row8_col4" class="data row8 col4" >0.1118</td>
#                         <td id="T_9949f_row8_col5" class="data row8 col5" >0.0829</td>
#             </tr>
#             <tr>
#                         <th id="T_9949f_level0_row9" class="row_heading level0 row9" >SD</th>
#                         <td id="T_9949f_row9_col0" class="data row9 col0" >5.2209</td>
#                         <td id="T_9949f_row9_col1" class="data row9 col1" >1371.9578</td>
#                         <td id="T_9949f_row9_col2" class="data row9 col2" >7.5572</td>
#                         <td id="T_9949f_row9_col3" class="data row9 col3" >0.0263</td>
#                         <td id="T_9949f_row9_col4" class="data row9 col4" >0.0090</td>
#                         <td id="T_9949f_row9_col5" class="data row9 col5" >0.0064</td>
#             </tr>
#     </tbody></table>

# %%
lunch_model = blend_models(estimator_list=lunch_regression_best_models_tuned, fold=8, optimize='MAE')
# Out:
# <style  type="text/css" >
# #T_6ef12_row8_col0,#T_6ef12_row8_col1,#T_6ef12_row8_col2,#T_6ef12_row8_col3,#T_6ef12_row8_col4,#T_6ef12_row8_col5{
#             background:  yellow;
#         }</style><table id="T_6ef12_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ef12_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6ef12_row0_col0" class="data row0 col0" >61.1785</td>
#                         <td id="T_6ef12_row0_col1" class="data row0 col1" >6497.5640</td>
#                         <td id="T_6ef12_row0_col2" class="data row0 col2" >80.6075</td>
#                         <td id="T_6ef12_row0_col3" class="data row0 col3" >0.8463</td>
#                         <td id="T_6ef12_row0_col4" class="data row0 col4" >0.1040</td>
#                         <td id="T_6ef12_row0_col5" class="data row0 col5" >0.0779</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef12_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6ef12_row1_col0" class="data row1 col0" >79.0957</td>
#                         <td id="T_6ef12_row1_col1" class="data row1 col1" >10672.3322</td>
#                         <td id="T_6ef12_row1_col2" class="data row1 col2" >103.3070</td>
#                         <td id="T_6ef12_row1_col3" class="data row1 col3" >0.7571</td>
#                         <td id="T_6ef12_row1_col4" class="data row1 col4" >0.1152</td>
#                         <td id="T_6ef12_row1_col5" class="data row1 col5" >0.0901</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef12_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6ef12_row2_col0" class="data row2 col0" >63.5752</td>
#                         <td id="T_6ef12_row2_col1" class="data row2 col1" >6103.8204</td>
#                         <td id="T_6ef12_row2_col2" class="data row2 col2" >78.1270</td>
#                         <td id="T_6ef12_row2_col3" class="data row2 col3" >0.8357</td>
#                         <td id="T_6ef12_row2_col4" class="data row2 col4" >0.1033</td>
#                         <td id="T_6ef12_row2_col5" class="data row2 col5" >0.0790</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef12_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6ef12_row3_col0" class="data row3 col0" >63.7380</td>
#                         <td id="T_6ef12_row3_col1" class="data row3 col1" >7852.8562</td>
#                         <td id="T_6ef12_row3_col2" class="data row3 col2" >88.6163</td>
#                         <td id="T_6ef12_row3_col3" class="data row3 col3" >0.8165</td>
#                         <td id="T_6ef12_row3_col4" class="data row3 col4" >0.1115</td>
#                         <td id="T_6ef12_row3_col5" class="data row3 col5" >0.0776</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef12_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6ef12_row4_col0" class="data row4 col0" >66.9868</td>
#                         <td id="T_6ef12_row4_col1" class="data row4 col1" >8410.2968</td>
#                         <td id="T_6ef12_row4_col2" class="data row4 col2" >91.7077</td>
#                         <td id="T_6ef12_row4_col3" class="data row4 col3" >0.8110</td>
#                         <td id="T_6ef12_row4_col4" class="data row4 col4" >0.1041</td>
#                         <td id="T_6ef12_row4_col5" class="data row4 col5" >0.0761</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef12_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6ef12_row5_col0" class="data row5 col0" >72.6029</td>
#                         <td id="T_6ef12_row5_col1" class="data row5 col1" >8805.9864</td>
#                         <td id="T_6ef12_row5_col2" class="data row5 col2" >93.8402</td>
#                         <td id="T_6ef12_row5_col3" class="data row5 col3" >0.8003</td>
#                         <td id="T_6ef12_row5_col4" class="data row5 col4" >0.1304</td>
#                         <td id="T_6ef12_row5_col5" class="data row5 col5" >0.0955</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef12_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6ef12_row6_col0" class="data row6 col0" >59.8092</td>
#                         <td id="T_6ef12_row6_col1" class="data row6 col1" >6859.7682</td>
#                         <td id="T_6ef12_row6_col2" class="data row6 col2" >82.8237</td>
#                         <td id="T_6ef12_row6_col3" class="data row6 col3" >0.8312</td>
#                         <td id="T_6ef12_row6_col4" class="data row6 col4" >0.0986</td>
#                         <td id="T_6ef12_row6_col5" class="data row6 col5" >0.0716</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef12_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6ef12_row7_col0" class="data row7 col0" >73.1563</td>
#                         <td id="T_6ef12_row7_col1" class="data row7 col1" >9558.3911</td>
#                         <td id="T_6ef12_row7_col2" class="data row7 col2" >97.7670</td>
#                         <td id="T_6ef12_row7_col3" class="data row7 col3" >0.7829</td>
#                         <td id="T_6ef12_row7_col4" class="data row7 col4" >0.1322</td>
#                         <td id="T_6ef12_row7_col5" class="data row7 col5" >0.0927</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef12_level0_row8" class="row_heading level0 row8" >Mean</th>
#                         <td id="T_6ef12_row8_col0" class="data row8 col0" >67.5178</td>
#                         <td id="T_6ef12_row8_col1" class="data row8 col1" >8095.1269</td>
#                         <td id="T_6ef12_row8_col2" class="data row8 col2" >89.5995</td>
#                         <td id="T_6ef12_row8_col3" class="data row8 col3" >0.8101</td>
#                         <td id="T_6ef12_row8_col4" class="data row8 col4" >0.1124</td>
#                         <td id="T_6ef12_row8_col5" class="data row8 col5" >0.0826</td>
#             </tr>
#             <tr>
#                         <th id="T_6ef12_level0_row9" class="row_heading level0 row9" >SD</th>
#                         <td id="T_6ef12_row9_col0" class="data row9 col0" >6.3386</td>
#                         <td id="T_6ef12_row9_col1" class="data row9 col1" >1478.6014</td>
#                         <td id="T_6ef12_row9_col2" class="data row9 col2" >8.1883</td>
#                         <td id="T_6ef12_row9_col3" class="data row9 col3" >0.0276</td>
#                         <td id="T_6ef12_row9_col4" class="data row9 col4" >0.0119</td>
#                         <td id="T_6ef12_row9_col5" class="data row9 col5" >0.0083</td>
#             </tr>
#     </tbody></table>

# %%
pred = predict_model(lunch_model)
# Out:
# <style  type="text/css" >
# </style><table id="T_6040b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6040b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6040b_row0_col0" class="data row0 col0" >Voting Regressor</td>
#                         <td id="T_6040b_row0_col1" class="data row0 col1" >69.9204</td>
#                         <td id="T_6040b_row0_col2" class="data row0 col2" >8171.7839</td>
#                         <td id="T_6040b_row0_col3" class="data row0 col3" >90.3979</td>
#                         <td id="T_6040b_row0_col4" class="data row0 col4" >0.8363</td>
#                         <td id="T_6040b_row0_col5" class="data row0 col5" >0.1206</td>
#                         <td id="T_6040b_row0_col6" class="data row0 col6" >0.0912</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 테스트 데이터 예측

# %%
submission = pd.read_csv('../data/sample_submission.csv')

# %%
final_model_lunch = finalize_model(lunch_model)
prep_pipe_lunch = get_config('prep_pipe')
prep_pipe_lunch.steps.append(['trained_model', final_model_lunch])

# %%
pred_lunch = prep_pipe_lunch.predict(lunch_test)

submission.iloc[:,1] = pred_lunch
submission.head()
# Out:
#            일자          중식계  석식계
# 0  2021-01-27   966.858545    0
# 1  2021-01-28   941.295149    0
# 2  2021-01-29   624.248693    0
# 3  2021-02-01  1269.357770    0
# 4  2021-02-02  1060.346000    0

# %% [markdown]
# # 석식 예측모델

# %%
dinner_regression_model = setup(data=dinner_train,
                                target='석식계',
                                train_size=0.8,
                                n_jobs=-1,
                                fold = 8,
                                numeric_imputation = 'mean',
                                normalize = True)
# Out:
# <style  type="text/css" >
# #T_4aa15_row27_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_4aa15_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4aa15_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4aa15_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4aa15_row0_col1" class="data row0 col1" >2813</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4aa15_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_4aa15_row1_col1" class="data row1 col1" >석식계</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4aa15_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_4aa15_row2_col1" class="data row2 col1" >(1187, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4aa15_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_4aa15_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4aa15_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_4aa15_row4_col1" class="data row4 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4aa15_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_4aa15_row5_col1" class="data row5 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4aa15_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_4aa15_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4aa15_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_4aa15_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4aa15_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_4aa15_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4aa15_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_4aa15_row9_col1" class="data row9 col1" >(949, 37)</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4aa15_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_4aa15_row10_col1" class="data row10 col1" >(238, 37)</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4aa15_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_4aa15_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4aa15_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_4aa15_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_4aa15_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_4aa15_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_4aa15_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_4aa15_row14_col1" class="data row14 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_4aa15_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_4aa15_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_4aa15_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_4aa15_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_4aa15_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_4aa15_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_4aa15_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_4aa15_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_4aa15_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_4aa15_row19_col1" class="data row19 col1" >5f7e</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_4aa15_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_4aa15_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_4aa15_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_4aa15_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_4aa15_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_4aa15_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_4aa15_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_4aa15_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4aa15_level0_row24" class="row_heading level0 row24" >

# %%
dinner_regression_best_models = compare_models(fold=8,
                                               n_select=3,
                                               exclude=['huber','llar','lar','par','lasso'])
# Out:
# <style  type="text/css" >
#     #T_1545e_ th {
#           text-align: left;
#     }#T_1545e_row0_col0,#T_1545e_row0_col5,#T_1545e_row1_col0,#T_1545e_row1_col1,#T_1545e_row1_col2,#T_1545e_row1_col3,#T_1545e_row1_col4,#T_1545e_row1_col5,#T_1545e_row1_col6,#T_1545e_row2_col0,#T_1545e_row2_col1,#T_1545e_row2_col2,#T_1545e_row2_col3,#T_1545e_row2_col4,#T_1545e_row2_col5,#T_1545e_row2_col6,#T_1545e_row3_col0,#T_1545e_row3_col1,#T_1545e_row3_col2,#T_1545e_row3_col3,#T_1545e_row3_col4,#T_1545e_row3_col5,#T_1545e_row3_col6,#T_1545e_row4_col0,#T_1545e_row4_col1,#T_1545e_row4_col2,#T_1545e_row4_col3,#T_1545e_row4_col4,#T_1545e_row4_col5,#T_1545e_row4_col6,#T_1545e_row5_col0,#T_1545e_row5_col1,#T_1545e_row5_col2,#T_1545e_row5_col3,#T_1545e_row5_col4,#T_1545e_row5_col6,#T_1545e_row6_col0,#T_1545e_row6_col1,#T_1545e_row6_col2,#T_1545e_row6_col3,#T_1545e_row6_col4,#T_1545e_row6_col5,#T_1545e_row6_col6,#T_1545e_row7_col0,#T_1545e_row7_col1,#T_1545e_row7_col2,#T_1545e_row7_col3,#T_1545e_row7_col4,#T_1545e_row7_col5,#T_1545e_row7_col6,#T_1545e_row8_col0,#T_1545e_row8_col1,#T_1545e_row8_col2,#T_1545e_row8_col3,#T_1545e_row8_col4,#T_1545e_row8_col5,#T_1545e_row8_col6,#T_1545e_row9_col0,#T_1545e_row9_col1,#T_1545e_row9_col2,#T_1545e_row9_col3,#T_1545e_row9_col4,#T_1545e_row9_col5,#T_1545e_row9_col6,#T_1545e_row10_col0,#T_1545e_row10_col1,#T_1545e_row10_col2,#T_1545e_row10_col3,#T_1545e_row10_col4,#T_1545e_row10_col5,#T_1545e_row10_col6,#T_1545e_row11_col0,#T_1545e_row11_col1,#T_1545e_row11_col2,#T_1545e_row11_col3,#T_1545e_row11_col4,#T_1545e_row11_col5,#T_1545e_row11_col6,#T_1545e_row12_col0,#T_1545e_row12_col1,#T_1545e_row12_col2,#T_1545e_row12_col3,#T_1545e_row12_col4,#T_1545e_row12_col5,#T_1545e_row12_col6,#T_1545e_row13_col0,#T_1545e_row13_col1,#T_1545e_row13_col2,#T_1545e_row13_col3,#T_1545e_row13_col4,#T_1545e_row13_col5,#T_1545e_row13_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_1545e_row0_col1,#T_1545e_row0_col2,#T_1545e_row0_col3,#T_1545e_row0_col4,#T_1545e_row0_col6,#T_1545e_row5_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_1545e_row0_col7,#T_1545e_row1_col7,#T_1545e_row2_col7,#T_1545e_row3_col7,#T_1545e_row4_col7,#T_1545e_row5_col7,#T_1545e_row6_col7,#T_1545e_row7_col7,#T_1545e_row8_col7,#T_1545e_row9_col7,#T_1545e_row10_col7,#T_1545e_row11_col7,#T_1545e_row13_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_1545e_row12_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_1545e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1545e_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_1545e_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_1545e_row0_col1" class="data row0 col1" >52.1478</td>
#                         <td id="T_1545e_row0_col2" class="data row0 col2" >6105.8447</td>
#                         <td id="T_1545e_row0_col3" class="data row0 col3" >77.6201</td>
#                         <td id="T_1545e_row0_col4" class="data row0 col4" >0.6730</td>
#                         <td id="T_1545e_row0_col5" class="data row0 col5" >0.9286</td>
#                         <td id="T_1545e_row0_col6" class="data row0 col6" >0.1126</td>
#                         <td id="T_1545e_row0_col7" class="data row0 col7" >0.9550</td>
#             </tr>
#             <tr>
#                         <th id="T_1545e_level0_row1" class="row_heading level0 row1" >gbr</th>
#                         <td id="T_1545e_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_1545e_row1_col1" class="data row1 col1" >55.6045</td>
#                         <td id="T_1545e_row1_col2" class="data row1 col2" >6476.8438</td>
#                         <td id="T_1545e_row1_col3" class="data row1 col3" >80.1388</td>
#                         <td id="T_1545e_row1_col4" class="data row1 col4" >0.6567</td>
#                         <td id="T_1545e_row1_col5" class="data row1 col5" >0.9569</td>
#                         <td id="T_1545e_row1_col6" class="data row1 col6" >0.1183</td>
#                         <td id="T_1545e_row1_col7" class="data row1 col7" >0.0438</td>
#             </tr>
#             <tr>
#                         <th id="T_1545e_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#                         <td id="T_1545e_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_1545e_row2_col1" class="data row2 col1" >56.5975</td>
#                         <td id="T_1545e_row2_col2" class="data row2 col2" >6692.1966</td>
#                         <td id="T_1545e_row2_col3" class="data row2 col3" >81.3313</td>
#                         <td id="T_1545e_row2_col4" class="data row2 col4" >0.6422</td>
#                         <td id="T_1545e_row2_col5" class="data row2 col5" >0.9231</td>
#                         <td id="T_1545e_row2_col6" class="data row2 col6" >0.1212</td>
#                         <td id="T_1545e_row2_col7" class="data row2 col7" >0.0662</td>
#             </tr>
#             <tr>
#                         <th id="T_1545e_level0_row3" class="row_heading level0 row3" >xgboost</th>
#                         <td id="T_1545e_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_1545e_row3_col1" class="data row3 col1" >55.6523</td>
#                         <td id="T_1545e_row3_col2" class="data row3 col2" >7113.5637</td>
#                         <td id="T_1545e_row3_col3" class="data row3 col3" >83.5703</td>
#                         <td id="T_1545e_row3_col4" class="data row3 col4" >0.6256</td>
#                         <td id="T_1545e_row3_col5" class="data row3 col5" >0.9290</td>
#                         <td id="T_1545e_row3_col6" class="data row3 col6" >0.1182</td>
#                         <td id="T_1545e_row3_col7" class="data row3 col7" >0.3300</td>
#             </tr>
#             <tr>
#                         <th id="T_1545e_level0_row4" class="row_heading level0 row4" >rf</th>
#                         <td id="T_1545e_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#                         <td id="T_1545e_row4_col1" class="data row4 col1" >56.7041</td>
#                         <td id="T_1545e_row4_col2" class="data row4 col2" >7044.2903</td>
#                         <td id="T_1545e_row4_col3" class="data row4 col3" >83.6056</td>
#                         <td id="T_1545e_row4_col4" class="data row4 col4" >0.6242</td>
#                         <td id="T_1545e_row4_col5" class="data row4 col5" >0.9460</td>
#                         <td id="T_1545e_row4_col6" class="data row4 col6" >0.1212</td>
#                         <td id="T_1545e_row4_col7" class="data row4 col7" >0.1425</td>
#             </tr>
#             <tr>
#                         <th id="T_1545e_level0_row5" class="row_heading level0 row5" >et</th>
#                         <td id="T_1545e_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#                         <td id="T_1545e_row5_col1" class="data row5 col1" >56.7482</td>
#                         <td id="T_1545e_row5_col2" class="data row5 col2" >7281.4227</td>
#                         <td id="T_1545e_row5_col3" class="data row5 col3" >84.7498</td>

# %%
dinner_regression_best_models_tuned = [tune_model(i, optimize='MAE') for i in dinner_regression_best_models]
# Out:
# <style  type="text/css" >
# #T_be556_row8_col0,#T_be556_row8_col1,#T_be556_row8_col2,#T_be556_row8_col3,#T_be556_row8_col4,#T_be556_row8_col5{
#             background:  yellow;
#         }</style><table id="T_be556_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_be556_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_be556_row0_col0" class="data row0 col0" >67.3479</td>
#                         <td id="T_be556_row0_col1" class="data row0 col1" >8332.6801</td>
#                         <td id="T_be556_row0_col2" class="data row0 col2" >91.2835</td>
#                         <td id="T_be556_row0_col3" class="data row0 col3" >0.4976</td>
#                         <td id="T_be556_row0_col4" class="data row0 col4" >0.7442</td>
#                         <td id="T_be556_row0_col5" class="data row0 col5" >0.1407</td>
#             </tr>
#             <tr>
#                         <th id="T_be556_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_be556_row1_col0" class="data row1 col0" >68.2543</td>
#                         <td id="T_be556_row1_col1" class="data row1 col1" >8341.7278</td>
#                         <td id="T_be556_row1_col2" class="data row1 col2" >91.3331</td>
#                         <td id="T_be556_row1_col3" class="data row1 col3" >0.5929</td>
#                         <td id="T_be556_row1_col4" class="data row1 col4" >1.2187</td>
#                         <td id="T_be556_row1_col5" class="data row1 col5" >0.1423</td>
#             </tr>
#             <tr>
#                         <th id="T_be556_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_be556_row2_col0" class="data row2 col0" >54.0620</td>
#                         <td id="T_be556_row2_col1" class="data row2 col1" >6978.5773</td>
#                         <td id="T_be556_row2_col2" class="data row2 col2" >83.5379</td>
#                         <td id="T_be556_row2_col3" class="data row2 col3" >0.6036</td>
#                         <td id="T_be556_row2_col4" class="data row2 col4" >0.7660</td>
#                         <td id="T_be556_row2_col5" class="data row2 col5" >0.1177</td>
#             </tr>
#             <tr>
#                         <th id="T_be556_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_be556_row3_col0" class="data row3 col0" >54.4582</td>
#                         <td id="T_be556_row3_col1" class="data row3 col1" >6590.5485</td>
#                         <td id="T_be556_row3_col2" class="data row3 col2" >81.1822</td>
#                         <td id="T_be556_row3_col3" class="data row3 col3" >0.7016</td>
#                         <td id="T_be556_row3_col4" class="data row3 col4" >1.2770</td>
#                         <td id="T_be556_row3_col5" class="data row3 col5" >0.1061</td>
#             </tr>
#             <tr>
#                         <th id="T_be556_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_be556_row4_col0" class="data row4 col0" >59.7522</td>
#                         <td id="T_be556_row4_col1" class="data row4 col1" >8349.6229</td>
#                         <td id="T_be556_row4_col2" class="data row4 col2" >91.3763</td>
#                         <td id="T_be556_row4_col3" class="data row4 col3" >0.4002</td>
#                         <td id="T_be556_row4_col4" class="data row4 col4" >0.7144</td>
#                         <td id="T_be556_row4_col5" class="data row4 col5" >0.1364</td>
#             </tr>
#             <tr>
#                         <th id="T_be556_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_be556_row5_col0" class="data row5 col0" >63.8870</td>
#                         <td id="T_be556_row5_col1" class="data row5 col1" >8567.4434</td>
#                         <td id="T_be556_row5_col2" class="data row5 col2" >92.5605</td>
#                         <td id="T_be556_row5_col3" class="data row5 col3" >0.6373</td>
#                         <td id="T_be556_row5_col4" class="data row5 col4" >1.2339</td>
#                         <td id="T_be556_row5_col5" class="data row5 col5" >0.1407</td>
#             </tr>
#             <tr>
#                         <th id="T_be556_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_be556_row6_col0" class="data row6 col0" >54.2373</td>
#                         <td id="T_be556_row6_col1" class="data row6 col1" >5239.3727</td>
#                         <td id="T_be556_row6_col2" class="data row6 col2" >72.3835</td>
#                         <td id="T_be556_row6_col3" class="data row6 col3" >0.7452</td>
#                         <td id="T_be556_row6_col4" class="data row6 col4" >1.0816</td>
#                         <td id="T_be556_row6_col5" class="data row6 col5" >0.1124</td>
#             </tr>
#             <tr>
#                         <th id="T_be556_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_be556_row7_col0" class="data row7 col0" >55.4757</td>
#                         <td id="T_be556_row7_col1" class="data row7 col1" >5551.8053</td>
#                         <td id="T_be556_row7_col2" class="data row7 col2" >74.5104</td>
#                         <td id="T_be556_row7_col3" class="data row7 col3" >0.7165</td>
#                         <td id="T_be556_row7_col4" class="data row7 col4" >0.7677</td>
#                         <td id="T_be556_row7_col5" class="data row7 col5" >0.1396</td>
#             </tr>
#             <tr>
#                         <th id="T_be556_level0_row8" class="row_heading level0 row8" >Mean</th>
#                         <td id="T_be556_row8_col0" class="data row8 col0" >59.6843</td>
#                         <td id="T_be556_row8_col1" class="data row8 col1" >7243.9722</td>
#                         <td id="T_be556_row8_col2" class="data row8 col2" >84.7709</td>
#                         <td id="T_be556_row8_col3" class="data row8 col3" >0.6119</td>
#                         <td id="T_be556_row8_col4" class="data row8 col4" >0.9754</td>
#                         <td id="T_be556_row8_col5" class="data row8 col5" >0.1295</td>
#             </tr>
#             <tr>
#                         <th id="T_be556_level0_row9" class="row_heading level0 row9" >SD</th>
#                         <td id="T_be556_row9_col0" class="data row9 col0" >5.6585</td>
#                         <td id="T_be556_row9_col1" class="data row9 col1" >1262.1230</td>
#                         <td id="T_be556_row9_col2" class="data row9 col2" >7.6068</td>
#                         <td id="T_be556_row9_col3" class="data row9 col3" >0.1094</td>
#                         <td id="T_be556_row9_col4" class="data row9 col4" >0.2337</td>
#                         <td id="T_be556_row9_col5" class="data row9 col5" >0.0139</td>
#             </tr>
#     </tbody></table>

# %%
dinner_model = blend_models(estimator_list=dinner_regression_best_models, fold=5, optimize='MAE')
# Out:
# <style  type="text/css" >
# #T_9f954_row5_col0,#T_9f954_row5_col1,#T_9f954_row5_col2,#T_9f954_row5_col3,#T_9f954_row5_col4,#T_9f954_row5_col5{
#             background:  yellow;
#         }</style><table id="T_9f954_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f954_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9f954_row0_col0" class="data row0 col0" >55.0733</td>
#                         <td id="T_9f954_row0_col1" class="data row0 col1" >6027.0212</td>
#                         <td id="T_9f954_row0_col2" class="data row0 col2" >77.6339</td>
#                         <td id="T_9f954_row0_col3" class="data row0 col3" >0.6852</td>
#                         <td id="T_9f954_row0_col4" class="data row0 col4" >0.8795</td>
#                         <td id="T_9f954_row0_col5" class="data row0 col5" >0.1197</td>
#             </tr>
#             <tr>
#                         <th id="T_9f954_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9f954_row1_col0" class="data row1 col0" >49.5030</td>
#                         <td id="T_9f954_row1_col1" class="data row1 col1" >5888.2175</td>
#                         <td id="T_9f954_row1_col2" class="data row1 col2" >76.7347</td>
#                         <td id="T_9f954_row1_col3" class="data row1 col3" >0.6817</td>
#                         <td id="T_9f954_row1_col4" class="data row1 col4" >0.8512</td>
#                         <td id="T_9f954_row1_col5" class="data row1 col5" >0.1024</td>
#             </tr>
#             <tr>
#                         <th id="T_9f954_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9f954_row2_col0" class="data row2 col0" >50.3903</td>
#                         <td id="T_9f954_row2_col1" class="data row2 col1" >5608.0451</td>
#                         <td id="T_9f954_row2_col2" class="data row2 col2" >74.8869</td>
#                         <td id="T_9f954_row2_col3" class="data row2 col3" >0.6675</td>
#                         <td id="T_9f954_row2_col4" class="data row2 col4" >0.9968</td>
#                         <td id="T_9f954_row2_col5" class="data row2 col5" >0.1013</td>
#             </tr>
#             <tr>
#                         <th id="T_9f954_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9f954_row3_col0" class="data row3 col0" >54.0509</td>
#                         <td id="T_9f954_row3_col1" class="data row3 col1" >6819.3825</td>
#                         <td id="T_9f954_row3_col2" class="data row3 col2" >82.5796</td>
#                         <td id="T_9f954_row3_col3" class="data row3 col3" >0.7088</td>
#                         <td id="T_9f954_row3_col4" class="data row3 col4" >1.0909</td>
#                         <td id="T_9f954_row3_col5" class="data row3 col5" >0.1176</td>
#             </tr>
#             <tr>
#                         <th id="T_9f954_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9f954_row4_col0" class="data row4 col0" >53.6883</td>
#                         <td id="T_9f954_row4_col1" class="data row4 col1" >5038.5017</td>
#                         <td id="T_9f954_row4_col2" class="data row4 col2" >70.9824</td>
#                         <td id="T_9f954_row4_col3" class="data row4 col3" >0.7418</td>
#                         <td id="T_9f954_row4_col4" class="data row4 col4" >0.9103</td>
#                         <td id="T_9f954_row4_col5" class="data row4 col5" >0.1239</td>
#             </tr>
#             <tr>
#                         <th id="T_9f954_level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_9f954_row5_col0" class="data row5 col0" >52.5412</td>
#                         <td id="T_9f954_row5_col1" class="data row5 col1" >5876.2336</td>
#                         <td id="T_9f954_row5_col2" class="data row5 col2" >76.5635</td>
#                         <td id="T_9f954_row5_col3" class="data row5 col3" >0.6970</td>
#                         <td id="T_9f954_row5_col4" class="data row5 col4" >0.9457</td>
#                         <td id="T_9f954_row5_col5" class="data row5 col5" >0.1130</td>
#             </tr>
#             <tr>
#                         <th id="T_9f954_level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_9f954_row6_col0" class="data row6 col0" >2.1847</td>
#                         <td id="T_9f954_row6_col1" class="data row6 col1" >580.7117</td>
#                         <td id="T_9f954_row6_col2" class="data row6 col2" >3.7770</td>
#                         <td id="T_9f954_row6_col3" class="data row6 col3" >0.0260</td>
#                         <td id="T_9f954_row6_col4" class="data row6 col4" >0.0875</td>
#                         <td id="T_9f954_row6_col5" class="data row6 col5" >0.0093</td>
#             </tr>
#     </tbody></table>

# %%
pred = predict_model(dinner_model)
# Out:
# <style  type="text/css" >
# </style><table id="T_04b44_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_04b44_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_04b44_row0_col0" class="data row0 col0" >Voting Regressor</td>
#                         <td id="T_04b44_row0_col1" class="data row0 col1" >55.3418</td>
#                         <td id="T_04b44_row0_col2" class="data row0 col2" >7282.8706</td>
#                         <td id="T_04b44_row0_col3" class="data row0 col3" >85.3397</td>
#                         <td id="T_04b44_row0_col4" class="data row0 col4" >0.6133</td>
#                         <td id="T_04b44_row0_col5" class="data row0 col5" >1.0494</td>
#                         <td id="T_04b44_row0_col6" class="data row0 col6" >0.1119</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 테스트

# %% [markdown]
# ### 테스트 데이터 예측

# %%
final_model_dinner = finalize_model(dinner_model)
prep_pipe_dinner = get_config('prep_pipe')
prep_pipe_dinner.steps.append(['trained_model', final_model_dinner])

# %%
pred_dinner = prep_pipe_dinner.predict(dinner_test)
submission.iloc[:,2] = pred_dinner
submission.head()
# Out:
#            일자          중식계         석식계
# 0  2021-01-27   966.858545  285.491704
# 1  2021-01-28   941.295149  417.762737
# 2  2021-01-29   624.248693  221.448050
# 3  2021-02-01  1269.357770  508.554400
# 4  2021-02-02  1060.346000  439.432134

# %% [markdown]
# # 저장

# %%
import datetime
today = str(datetime.datetime.now().date()).replace("-","")
print("오늘 날짜 : " + today)

submission.to_csv(f'../submission/{today}_pycaret_ADD_FEATURE.csv', index =False)
# Out:
# 오늘 날짜 : 20210628

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['font.family'] = 'Gulim'

# %%
from workalendar.asia import SouthKorea
import pendulum

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# ## 전처리
# - 일자에서 월과 일을 분리
# - 요일을 레이블 인코딩화(EDA로 요일의 중요도 순 파악)
# - 월 별, 일 별 중식 석식 수요 차이 파악

# %%
train['월'] = pd.DatetimeIndex(train['일자']).month
test['월'] = pd.DatetimeIndex(test['일자']).month
train['주'] = pd.DatetimeIndex(train['일자']).week
test['주'] = pd.DatetimeIndex(test['일자']).week
train['일'] = pd.DatetimeIndex(train['일자']).day
test['일'] = pd.DatetimeIndex(test['일자']).day

train['출근'] = train['본사정원수']-(train['본사휴가자수']+train['본사출장자수']+train['현본사소속재택근무자수'])
train['휴가비율'] = train['본사휴가자수']/train['본사정원수']
train['출장비율'] = train['본사출장자수']/train['본사정원수']
train['야근비율'] = train['본사시간외근무명령서승인건수']/train['출근']
train['재택비율'] = train['현본사소속재택근무자수']/train['본사정원수']

test['출근'] = test['본사정원수']-(test['본사휴가자수']+test['본사출장자수']+test['현본사소속재택근무자수'])
test['휴가비율'] = test['본사휴가자수']/test['본사정원수']
test['출장비율'] = test['본사출장자수']/test['본사정원수']
test['야근비율'] = test['본사시간외근무명령서승인건수']/test['출근']
test['재택비율'] = test['현본사소속재택근무자수']/test['본사정원수']

train['식사가능자수'] = train['본사정원수'] - train['본사휴가자수'] - train['현본사소속재택근무자수']
test['식사가능자수'] = test['본사정원수'] - test['본사휴가자수'] - test['현본사소속재택근무자수']

# train['중식참여율'] = train['중식계'] / train['식사가능자수']
# Out:
# <ipython-input-4-b11c832c5082>:3: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   train['주'] = pd.DatetimeIndex(train['일자']).week
# <ipython-input-4-b11c832c5082>:4: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   test['주'] = pd.DatetimeIndex(test['일자']).week

# %%
month_rank4dinner = {
    1: 11,
    2: 2,
    3: 1,
    4: 4,
    5: 7,
    6: 6,
    7: 10,
    8: 8,
    9: 5,
    10: 3,
    11: 9,
    12: 12
}
train['월(석식)'] = train['월'].map(month_rank4dinner)
test['월(석식)'] = test['월'].map(month_rank4dinner)

month_rank4lunch = {
    1: 3,
    2: 1,
    3: 2,
    4: 6,
    5: 7,
    6: 8,
    7: 10,
    8: 9,
    9: 5,
    10: 4,
    11: 11,
    12: 12
}
train['월(중식)'] = train['월'].map(month_rank4lunch)
test['월(중식)'] = test['월'].map(month_rank4lunch)

weekday_rank4dinner = {
    '월': 1,
    '화': 2,
    '수': 4,
    '목': 3,
    '금': 5,
}

weekday_rank4lunch = {
    '월': 1,
    '화': 2,
    '수': 3,
    '목': 4,
    '금': 5,
}

train['요일(석식)'] = train['요일'].map(weekday_rank4dinner)
test['요일(석식)'] = test['요일'].map(weekday_rank4dinner)

train['요일(중식)'] = train['요일'].map(weekday_rank4lunch)
test['요일(중식)'] = test['요일'].map(weekday_rank4lunch)

# %%
rank = pd.DataFrame(range(1,53))
week_rank_lunch = pd.pivot_table(train,values='중식계',index='주').sort_values(by='중식계').reset_index().drop('중식계',axis=1)
week_rank_dinner = pd.pivot_table(train,values='석식계',index='주').sort_values(by='석식계').reset_index().drop('석식계',axis=1)


week_rank4lunch = {}
for i in range(len(rank)):
    week_rank4lunch[week_rank_lunch['주'][i]] = rank[0][i]


week_rank4dinner = {}
for i in range(len(rank)):
    week_rank4dinner[week_rank_dinner['주'][i]] = rank[0][i]
    
    
train['주(중식)'] = train['주'].map(week_rank4lunch)
test['주(중식)'] = test['주'].map(week_rank4lunch)

train['주(석식)'] = train['주'].map(week_rank4dinner)
test['주(석식)'] = test['주'].map(week_rank4dinner)

# %%
def is_holiday(date):
    holidays = list(map(str, pd.Series(np.array(SouthKorea().holidays(int(date[:4])))[:, 0])))
    
    yesterday = str(np.datetime64(date) - 1)
    tomorrow = str(np.datetime64(date) + 1)

    if tomorrow in holidays and yesterday in holidays:
        return 3
    if tomorrow in holidays:
        return 2
    elif yesterday in holidays:
        return 1
    else : 
        return 0

def week_of_month(x):
    dt = pendulum.parse(x)
    
    wom = dt.week_of_month
    if wom < 0:
        wom += 52
    return wom
    

df = pd.concat([train[['본사정원수', '일자']], test[['본사정원수', '일자']]])
df['년월'] = df['일자'].apply(lambda x : x[:7])
df = df[['년월', '본사정원수']].groupby(by=['년월'], as_index=False).mean()

def member_change(date):
    this_month = date[:7]
    last_month = str(np.datetime64(this_month) - 1)
    
    this_month_member = int(df[df['년월'] == this_month]['본사정원수'])
    last_month_member = int(df[df['년월'] == last_month]['본사정원수'])
    
    
    return  this_month_member - last_month_member

train['공휴일전후'] = train['일자'].apply(is_holiday)
test['공휴일전후'] = test['일자'].apply(is_holiday)

train['몇주차'] = train['일자'].apply(week_of_month)
test['몇주차'] = test['일자'].apply(week_of_month)

train = train[train['일자'] > '2016-03']
train['인원변화'] = train['일자'].apply(member_change)
test['인원변화'] = test['일자'].apply(member_change)

# %% [markdown]
# ## 공휴일 변수 생성

# %%
train.columns
# Out:
# Index(['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
#        '현본사소속재택근무자수', '조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계', '월', '주', '일',
#        '출근', '휴가비율', '출장비율', '야근비율', '재택비율', '식사가능자수', '월(석식)', '월(중식)',
#        '요일(석식)', '요일(중식)', '주(중식)', '주(석식)', '공휴일전후', '몇주차', '인원변화'],
#       dtype='object')

# %%
# 메뉴 변수 없이 사용할떄 해당 코드 사용['공휴일전후', '몇주차', '인원변화']

lunch_train = train[['공휴일전후', '몇주차', '인원변화', '요일(중식)','월(중식)','일','주(중식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수','본사시간외근무명령서승인건수']]
lunch_test = test[['공휴일전후', '몇주차', '인원변화', '요일(중식)','월(중식)','일','주(중식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수','본사시간외근무명령서승인건수']]

dinner_train= train[['공휴일전후', '몇주차', '인원변화', '요일(석식)','월(석식)','일','주(석식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수','본사시간외근무명령서승인건수']]
dinner_test = test[['공휴일전후', '몇주차', '인원변화', '요일(석식)','월(석식)','일','주(석식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수','본사시간외근무명령서승인건수']]

# %%
lunch_train.columns
# Out:
# Index(['공휴일전후', '몇주차', '인원변화', '요일(중식)', '월(중식)', '일', '주(중식)', '출근', '휴가비율',
#        '출장비율', '야근비율', '재택비율', '본사출장자수', '본사휴가자수', '식사가능자수', '본사시간외근무명령서승인건수'],
#       dtype='object')

# %%
print(lunch_train.shape)
print(lunch_test.shape)
# Out:
# (1187, 16)
# (50, 16)

# %%
print(dinner_train.shape)
print(dinner_test.shape)
# Out:
# (1187, 16)
# (50, 16)

# %%
cat_features = [f for f in lunch_train.columns if lunch_train[f].dtype == 'object']

def column_index(df, cat_features):
    cols = df.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols, cat_features, sorter=sidx)]

cat_features_idx = column_index(lunch_train, cat_features)    
print("Cat features are: %s" % [f for f in cat_features])
print(cat_features_idx)
# Out:
# Cat features are: []
# []

# %%
y_lunch = train[['중식계']]
y_dinner = train[['석식계']]

# %% [markdown]
# #### 분포 확인 및 분포 조정

# %% [markdown]
# # 중식 예측모델

# %%
from automl_alex import LightGBMRegressor, XGBoostRegressor
from sklearn.metrics import mean_absolute_error
import sklearn

# %%
lunch_model = XGBoostRegressor(random_state=42)

lunch_model.opt(lunch_train,  y_lunch,
            verbose=3,  cold_start=120,folds=8,opt_lvl=3,early_stoping=120, auto_parameters=False,#metric=sklearn.metrics.roc_auc_score,
      timeout=1100,metric=sklearn.metrics.mean_absolute_error # optimization time in seconds,
      )
# Out:
# 20:43:59 | regression optimize: minimize
# --- Logging error in Loguru Handler #2 ---
# Record was: {'elapsed': datetime.timedelta(seconds=17, microseconds=144111), 'exception': None, 'extra': {}, 'file': (name='_base.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\_base.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 270, 'message': 'regression optimize: minimize', 'module': '_base', 'name': 'automl_alex._base', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 43, 59, 167287, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:43:59 | ##################################################
# --- Logging error in Loguru Handler #4 ---
# Record was: {'elapsed': datetime.timedelta(seconds=17, microseconds=163971), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 557, 'message': '##################################################', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 43, 59, 187147, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:43:59 | > Step 1: calc parameters and pruned score: get test 10 trials
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=17, microseconds=898645), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 600, 'message': '> Step 1: calc parameters and pruned score: get test 10 trials', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 43, 59, 921821, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 |  One iteration ~ 14.1 sec
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=248841), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 615, 'message': ' One iteration ~ 14.1 sec', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 272017, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 |  Possible iters ~ 77.0
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=253221), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 618, 'message': ' Possible iters ~ 77.0', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 276397, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | ! Not enough time to find the optimal parameters.
#                      Possible iters < 100.
#                      Please, Increase the 'timeout' parameter for normal optimization.
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=257214), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='WARNING', no=30, icon='⚠️'), 'line': 620, 'message': "! Not enough time to find the optimal parameters. \n                     Possible iters < 100. \n                     Please, Increase the 'timeout' parameter for normal optimization.", 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 280390, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | --------------------------------------------------
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=260366), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 625, 'message': '--------------------------------------------------', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 283542, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 |   Pruned Threshold Score: 80.7872
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=285493), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 651, 'message': '  Pruned Threshold Score: 80.7872', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 308669, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | ##################################################
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=289054), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 652, 'message': '##################################################', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 312230, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | > Step 2: Full opt with Threshold Score Pruner
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=295351), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 657, 'message': '> Step 2: Full opt with Threshold Score Pruner', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 318527, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | ##################################################
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=298043), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': '##################################################', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 321219, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | > Start optimization with the parameters:
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=300915), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 255, 'message': '> Start optimization with the parameters:', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 324091, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | CV_Folds = 8
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=306889), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 256, 'message': 'CV_Folds = 8', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 330065, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | Score_CV_Folds = 2
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=310399), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 257, 'message': 'Score_CV_Folds = 2', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 333575, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | Feature_Selection = False
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=312694), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 258, 'message': 'Feature_Selection = False', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 335870, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | Opt_lvl = 3
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=315241), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 259, 'message': 'Opt_lvl = 3', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 338417, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | Cold_start = 120
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=317227), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 260, 'message': 'Cold_start = 120', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 340403, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | Early_stoping = 120
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=321220), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 261, 'message': 'Early_stoping = 120', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 344396, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | Metric = mean_absolute_error
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=324202), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 262, 'message': 'Metric = mean_absolute_error', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 347378, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | Direction = minimize
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=327192), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 263, 'message': 'Direction = minimize', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 350368, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:46:21 | ##################################################
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=159, microseconds=331122), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 660, 'message': '##################################################', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 46, 21, 354298, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# Optimize: : 48it [14:16, 17.84s/it, | Model: XGBoost | OptScore: 68.1029 | Best mean_absolute_error: 67.627 ]
# 21:00:37 | > Finish Opt!
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1015, microseconds=855291), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 682, 'message': '> Finish Opt!', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 0, 37, 878467, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:00:39 | Best Score: 67.627 mean_absolute_error
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1017, microseconds=889404), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 689, 'message': 'Best Score: 67.627 mean_absolute_error', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 0, 39, 912580, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
#      number     value             datetime_start  ... params_xgb_skip_drop params_xgb_subsample     state
# 0         0   73.9754 2021-07-15 20:43:59.946390  ...                  NaN                  1.0  COMPLETE
# 1         1  101.8504 2021-07-15 20:44:06.044734  ...                  NaN                  0.3  COMPLETE
# 2         2  108.4775 2021-07-15 20:44:06.492398  ...                  NaN                  0.7  COMPLETE
# 3         3   69.6359 2021-07-15 20:44:07.079165  ...         1.884118e-08                  0.6  COMPLETE
# 4         4   77.7800 2021-07-15 20:45:20.961225  ...         1.286525e-05                  0.7  COMPLETE
# ..      ...       ...                        ...  ...                  ...                  ...       ...
# 124     124   73.5118 2021-07-15 20:59:37.425336  ...                  NaN                  1.0  COMPLETE
# 125     125   70.1207 2021-07-15 20:59:38.216996  ...         1.313715e-07                  0.9  COMPLETE
# 126     126   70.8338 2021-07-15 20:59:53.410725  ...         1.144838e-07                  0.9  COMPLETE
# 127     127   70.8338 2021-07-15 21:00:08.816969  ...         6.593197e-08                  0.9  COMPLETE
# 128     128   68.1029 2021-07-15 21:00:23.565328  ...         1.662334e-07                  0.9  COMPLETE
#
# [129 rows x 19 columns]

# %%
predicts_LGBM_lunch = lunch_model.predict(lunch_test)

# %%
dinner_model = XGBoostRegressor(random_state=42)

dinner_model.opt(dinner_train,  y_dinner,
            verbose=3,  cold_start=120,folds=8,opt_lvl=3,early_stoping=120, auto_parameters=False,#metric=sklearn.metrics.roc_auc_score,
      timeout=1100,metric=sklearn.metrics.mean_absolute_error # optimization time in seconds,
      )
# Out:
# 21:00:40 | regression optimize: minimize
# --- Logging error in Loguru Handler #6 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1018, microseconds=229856), 'exception': None, 'extra': {}, 'file': (name='_base.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\_base.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 270, 'message': 'regression optimize: minimize', 'module': '_base', 'name': 'automl_alex._base', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 0, 40, 253032, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:00:40 | ##################################################
# --- Logging error in Loguru Handler #8 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1018, microseconds=242769), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 557, 'message': '##################################################', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 0, 40, 265945, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:00:40 | > Step 1: calc parameters and pruned score: get test 10 trials
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1018, microseconds=592314), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 600, 'message': '> Step 1: calc parameters and pruned score: get test 10 trials', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 0, 40, 615490, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 |  One iteration ~ 15.1 sec
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=52248), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 615, 'message': ' One iteration ~ 15.1 sec', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 75424, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 |  Possible iters ~ 72.0
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=57157), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 618, 'message': ' Possible iters ~ 72.0', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 80333, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | ! Not enough time to find the optimal parameters.
#                      Possible iters < 100.
#                      Please, Increase the 'timeout' parameter for normal optimization.
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=62188), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='WARNING', no=30, icon='⚠️'), 'line': 620, 'message': "! Not enough time to find the optimal parameters. \n                     Possible iters < 100. \n                     Please, Increase the 'timeout' parameter for normal optimization.", 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 85364, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | --------------------------------------------------
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=65920), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 625, 'message': '--------------------------------------------------', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 89096, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 |   Pruned Threshold Score: 67.219
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=93086), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 651, 'message': '  Pruned Threshold Score: 67.219', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 116262, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | ##################################################
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=96570), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 652, 'message': '##################################################', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 119746, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | > Step 2: Full opt with Threshold Score Pruner
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=100241), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 657, 'message': '> Step 2: Full opt with Threshold Score Pruner', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 123417, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | ##################################################
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=103222), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': '##################################################', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 126398, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | > Start optimization with the parameters:
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=106404), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 255, 'message': '> Start optimization with the parameters:', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 129580, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | CV_Folds = 8
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=111481), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 256, 'message': 'CV_Folds = 8', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 134657, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | Score_CV_Folds = 2
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=115463), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 257, 'message': 'Score_CV_Folds = 2', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 138639, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | Feature_Selection = False
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=118994), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 258, 'message': 'Feature_Selection = False', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 142170, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | Opt_lvl = 3
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=123069), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 259, 'message': 'Opt_lvl = 3', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 146245, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | Cold_start = 120
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=126751), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 260, 'message': 'Cold_start = 120', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 149927, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | Early_stoping = 120
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=129743), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 261, 'message': 'Early_stoping = 120', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 152919, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | Metric = mean_absolute_error
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=135728), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 262, 'message': 'Metric = mean_absolute_error', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 158904, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | Direction = minimize
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=138267), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': '_print_opt_parameters', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 263, 'message': 'Direction = minimize', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 161443, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:03:12 | ##################################################
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=1170, microseconds=141478), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 660, 'message': '##################################################', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 3, 12, 164654, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# Optimize: : 40it [15:02, 22.57s/it, | Model: XGBoost | OptScore: 61.6465 | Best mean_absolute_error: 53.7486 ]
# 21:18:14 | > Finish Opt!
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=2072, microseconds=933930), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 682, 'message': '> Finish Opt!', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 18, 14, 957106, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 21:18:17 | Best Score: 53.7486 mean_absolute_error
# --- Logging error in Loguru Handler #10 ---
# Record was: {'elapsed': datetime.timedelta(seconds=2075, microseconds=973530), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 689, 'message': 'Best Score: 53.7486 mean_absolute_error', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=11572, name='MainProcess'), 'thread': (id=2380, name='MainThread'), 'time': datetime(2021, 7, 15, 21, 18, 17, 996706, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
#      number    value             datetime_start  ... params_xgb_skip_drop params_xgb_subsample     state
# 0         0  57.0494 2021-07-15 21:00:40.641594  ...                  NaN                  1.0  COMPLETE
# 1         1  76.4076 2021-07-15 21:00:47.513898  ...                  NaN                  0.3  COMPLETE
# 2         2  78.4022 2021-07-15 21:00:48.000437  ...                  NaN                  0.7  COMPLETE
# 3         3  57.8736 2021-07-15 21:00:48.667949  ...         1.884118e-08                  0.6  COMPLETE
# 4         4  65.9970 2021-07-15 21:02:12.831178  ...         1.286525e-05                  0.7  COMPLETE
# ..      ...      ...                        ...  ...                  ...                  ...       ...
# 114     114  61.4737 2021-07-15 21:13:26.660722  ...                  NaN                  0.5  COMPLETE
# 115     115  61.9643 2021-07-15 21:13:27.662838  ...         2.169378e-07                  0.4  COMPLETE
# 116     116  61.9526 2021-07-15 21:13:31.647024  ...         4.145646e-05                  0.8  COMPLETE
# 117     117  82.9994 2021-07-15 21:15:00.549961  ...         2.906963e-06                  0.6    PRUNED
# 118     118  61.6465 2021-07-15 21:15:49.767390  ...         1.750235e-08                  0.7  COMPLETE
#
# [119 rows x 19 columns]

# %%
predicts_LGBM_dinner = dinner_model.predict(dinner_test)

# %%
submission = pd.read_csv('../data/sample_submission.csv')

# %%
submission.iloc[:,1] = predicts_LGBM_lunch
submission.iloc[:,2] = predicts_LGBM_dinner
submission.head()
# Out:
#            일자          중식계         석식계
# 0  2021-01-27  1006.574158  300.069824
# 1  2021-01-28   957.091064  434.266998
# 2  2021-01-29   635.769653  237.423019
# 3  2021-02-01  1271.646484  531.715698
# 4  2021-02-02  1095.182495  497.948212

# %%
answer = pd.read_csv('../submission/20210630_lgbm_autoML.csv')

lunch_answer = np.array(answer.iloc[:,1])
dinner_answer = np.array(answer.iloc[:,2])

abs(predicts_LGBM_lunch - lunch_answer).mean(), abs(predicts_LGBM_dinner - dinner_answer).mean()
# Out:
# (17.552833603009592, 20.14220606134737)

# %% [markdown]
# # 저장

# %%
import datetime
today = str(datetime.datetime.now().date()).replace("-","")
print("오늘 날짜 : " + today)

submission.to_csv(f'../submission/{today}_xgb_autoML.csv', index =False)
# Out:
# 오늘 날짜 : 20210715

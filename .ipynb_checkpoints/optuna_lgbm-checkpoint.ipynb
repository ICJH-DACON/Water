# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['font.family'] = 'Gulim'

import warnings
warnings.filterwarnings(action='ignore')

# %%
from workalendar.asia import SouthKorea
import pendulum

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# ## 전처리
# - 일자에서 월과 일을 분리
# - 요일을 레이블 인코딩화(EDA로 요일의 중요도 순 파악)
# - 월 별, 일 별 중식 석식 수요 차이 파악

# %%
train['월'] = pd.DatetimeIndex(train['일자']).month
test['월'] = pd.DatetimeIndex(test['일자']).month
train['주'] = pd.DatetimeIndex(train['일자']).week
test['주'] = pd.DatetimeIndex(test['일자']).week
train['일'] = pd.DatetimeIndex(train['일자']).day
test['일'] = pd.DatetimeIndex(test['일자']).day

train['출근'] = train['본사정원수']-(train['본사휴가자수']+train['본사출장자수']+train['현본사소속재택근무자수'])
train['휴가비율'] = train['본사휴가자수']/train['본사정원수']
train['출장비율'] = train['본사출장자수']/train['본사정원수']
train['야근비율'] = train['본사시간외근무명령서승인건수']/train['출근']
train['재택비율'] = train['현본사소속재택근무자수']/train['본사정원수']

test['출근'] = test['본사정원수']-(test['본사휴가자수']+test['본사출장자수']+test['현본사소속재택근무자수'])
test['휴가비율'] = test['본사휴가자수']/test['본사정원수']
test['출장비율'] = test['본사출장자수']/test['본사정원수']
test['야근비율'] = test['본사시간외근무명령서승인건수']/test['출근']
test['재택비율'] = test['현본사소속재택근무자수']/test['본사정원수']

train['식사가능자수'] = train['본사정원수'] - train['본사휴가자수'] - train['현본사소속재택근무자수']
test['식사가능자수'] = test['본사정원수'] - test['본사휴가자수'] - test['현본사소속재택근무자수']

# train['중식참여율'] = train['중식계'] / train['식사가능자수']

# %%
month_rank4dinner = {
    1: 11,
    2: 2,
    3: 1,
    4: 4,
    5: 7,
    6: 6,
    7: 10,
    8: 8,
    9: 5,
    10: 3,
    11: 9,
    12: 12
}
train['월(석식)'] = train['월'].map(month_rank4dinner)
test['월(석식)'] = test['월'].map(month_rank4dinner)

month_rank4lunch = {
    1: 3,
    2: 1,
    3: 2,
    4: 6,
    5: 7,
    6: 8,
    7: 10,
    8: 9,
    9: 5,
    10: 4,
    11: 11,
    12: 12
}
train['월(중식)'] = train['월'].map(month_rank4lunch)
test['월(중식)'] = test['월'].map(month_rank4lunch)

weekday_rank4dinner = {
    '월': 1,
    '화': 2,
    '수': 4,
    '목': 3,
    '금': 5,
}

weekday_rank4lunch = {
    '월': 1,
    '화': 2,
    '수': 3,
    '목': 4,
    '금': 5,
}

train['요일(석식)'] = train['요일'].map(weekday_rank4dinner)
test['요일(석식)'] = test['요일'].map(weekday_rank4dinner)

train['요일(중식)'] = train['요일'].map(weekday_rank4lunch)
test['요일(중식)'] = test['요일'].map(weekday_rank4lunch)

# %%
rank = pd.DataFrame(range(1,53))
week_rank_lunch = pd.pivot_table(train,values='중식계',index='주').sort_values(by='중식계').reset_index().drop('중식계',axis=1)
week_rank_dinner = pd.pivot_table(train,values='석식계',index='주').sort_values(by='석식계').reset_index().drop('석식계',axis=1)


week_rank4lunch = {}
for i in range(len(rank)):
    week_rank4lunch[week_rank_lunch['주'][i]] = rank[0][i]


week_rank4dinner = {}
for i in range(len(rank)):
    week_rank4dinner[week_rank_dinner['주'][i]] = rank[0][i]
    
    
train['주(중식)'] = train['주'].map(week_rank4lunch)
test['주(중식)'] = test['주'].map(week_rank4lunch)

train['주(석식)'] = train['주'].map(week_rank4dinner)
test['주(석식)'] = test['주'].map(week_rank4dinner)

# %%
def is_holiday(date):
    holidays = list(map(str, pd.Series(np.array(SouthKorea().holidays(int(date[:4])))[:, 0])))
    
    yesterday = str(np.datetime64(date) - 1)
    tomorrow = str(np.datetime64(date) + 1)

    if tomorrow in holidays and yesterday in holidays:
        return 3
    if tomorrow in holidays:
        return 2
    elif yesterday in holidays:
        return 1
    else : 
        return 0

def week_of_month(x):
    dt = pendulum.parse(x)
    
    wom = dt.week_of_month
    if wom < 0:
        wom += 52
    return wom
    

df = pd.concat([train[['본사정원수', '일자']], test[['본사정원수', '일자']]])
df['년월'] = df['일자'].apply(lambda x : x[:7])
df = df[['년월', '본사정원수']].groupby(by=['년월'], as_index=False).mean()

def member_change(date):
    this_month = date[:7]
    last_month = str(np.datetime64(this_month) - 1)
    
    this_month_member = int(df[df['년월'] == this_month]['본사정원수'])
    last_month_member = int(df[df['년월'] == last_month]['본사정원수'])
    
    
    return  this_month_member - last_month_member

train['공휴일전후'] = train['일자'].apply(is_holiday)
test['공휴일전후'] = test['일자'].apply(is_holiday)

train['몇주차'] = train['일자'].apply(week_of_month)
test['몇주차'] = test['일자'].apply(week_of_month)

train = train[train['일자'] > '2016-03']
train['인원변화'] = train['일자'].apply(member_change)
test['인원변화'] = test['일자'].apply(member_change)

# %% [markdown]
# ## 공휴일 변수 생성

# %%
train.columns
# Out:
# Index(['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
#        '현본사소속재택근무자수', '조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계', '월', '주', '일',
#        '출근', '휴가비율', '출장비율', '야근비율', '재택비율', '식사가능자수', '월(석식)', '월(중식)',
#        '요일(석식)', '요일(중식)', '주(중식)', '주(석식)', '공휴일전후', '몇주차', '인원변화'],
#       dtype='object')

# %%
# 메뉴 변수 없이 사용할떄 해당 코드 사용['공휴일전후', '몇주차', '인원변화']

lunch_train = train[['공휴일전후', '몇주차', '인원변화', '요일(중식)','월(중식)','일','주(중식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수','본사시간외근무명령서승인건수']]
lunch_test = test[['공휴일전후', '몇주차', '인원변화', '요일(중식)','월(중식)','일','주(중식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수','본사시간외근무명령서승인건수']]

dinner_train= train[['공휴일전후', '몇주차', '인원변화', '요일(석식)','월(석식)','일','주(석식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수','본사시간외근무명령서승인건수']]
dinner_test = test[['공휴일전후', '몇주차', '인원변화', '요일(석식)','월(석식)','일','주(석식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수','본사시간외근무명령서승인건수']]

# %%
lunch_train.columns
# Out:
# Index(['공휴일전후', '몇주차', '인원변화', '요일(중식)', '월(중식)', '일', '주(중식)', '출근', '휴가비율',
#        '출장비율', '야근비율', '재택비율', '본사출장자수', '본사휴가자수', '식사가능자수', '본사시간외근무명령서승인건수'],
#       dtype='object')

# %%
print(lunch_train.shape)
print(lunch_test.shape)
# Out:
# (1187, 16)
# (50, 16)

# %%
print(dinner_train.shape)
print(dinner_test.shape)
# Out:
# (1187, 16)
# (50, 16)

# %%
cat_features = [f for f in lunch_train.columns if lunch_train[f].dtype == 'object']

def column_index(df, cat_features):
    cols = df.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols, cat_features, sorter=sidx)]

cat_features_idx = column_index(lunch_train, cat_features)    
print("Cat features are: %s" % [f for f in cat_features])
print(cat_features_idx)
# Out:
# Cat features are: []
# []

# %%
y_lunch = np.array(train[['중식계']])
y_dinner = np.array(train[['석식계']])

# %% [markdown]
# #### 분포 확인 및 분포 조정

# %% [markdown]
# # 중식 예측모델

# %%
import optuna
from lightgbm import LGBMRegressor
from optuna import Trial
from optuna.samplers import TPESampler
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split, KFold

# %%
# from automl_alex import LightGBMRegressor, CatBoostRegressor, AutoMLRegressor
from sklearn.metrics import mean_absolute_error as MAE
import sklearn

# %%
def objective_lunch(trial: Trial) -> float:
    params_lgb = {
        "random_state": 42,
        "verbosity": -1,
        "learning_rate": 0.05,
        "n_estimators": trial.suggest_int("num_leaves", 100, 10000),
        "metric": "mae",
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 3e-5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 9e-2),
        "max_depth": trial.suggest_int("max_depth", 1, 20),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
        "subsample": trial.suggest_float("subsample", 0.3, 1.0),
        "subsample_freq": trial.suggest_int("subsample_freq", 1, 10),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "max_bin": trial.suggest_int("max_bin", 200, 500),
    }
    
    n_fold = 4
    kf = KFold(n_splits=n_fold, random_state=42, shuffle=True)
    mae = 0
#     X_train, X_valid, y_train, y_valid = train_test_split(lunch_train, y_lunch, test_size=0.2)
    for train_index, test_index in kf.split(lunch_train):
        X_train, X_valid = lunch_train.iloc[train_index], lunch_train.iloc[test_index]
        y_train, y_valid = y_lunch[train_index], y_lunch[test_index]

        model = LGBMRegressor(**params_lgb)

        evaluation = [(X_train, y_train), (X_valid, y_valid)]

        model.fit(X_train,
                  y_train,
                  eval_set=[(X_train, y_train), (X_valid, y_valid)],
                  early_stopping_rounds=100,
                  verbose=False,
                 )

        pred = model.predict(X_valid)
        mae += MAE(y_valid, pred)/n_fold
    
    return mae

# %%
sampler = TPESampler(seed=42)
study = optuna.create_study(
    study_name="lgbm_parameter_opt",
    direction="minimize",
    sampler=sampler,
)
study.optimize(objective_lunch, n_trials=1000)
lunch_param = study.best_trial.params

print("Best Score:", study.best_value)
print("Best trial:", study.best_trial.params)
# Out:
# [I 2021-07-22 18:11:32,485] A new study created in memory with name: lgbm_parameter_opt
# [I 2021-07-22 18:11:34,476] Trial 0 finished with value: 85.97962576581826 and parameters: {'num_leaves': 3808, 'reg_alpha': 2.8521922049233386e-05, 'reg_lambda': 0.06587945744308704, 'max_depth': 12, 'colsample_bytree': 0.4936111842654619, 'subsample': 0.40919616423534183, 'subsample_freq': 1, 'min_child_samples': 88, 'max_bin': 380}. Best is trial 0 with value: 85.97962576581826.
# [I 2021-07-22 18:11:36,691] Trial 1 finished with value: 70.14695556430492 and parameters: {'num_leaves': 7110, 'reg_alpha': 6.273289839311154e-07, 'reg_lambda': 0.08729188699548096, 'max_depth': 17, 'colsample_bytree': 0.5274034664069657, 'subsample': 0.42727747704497043, 'subsample_freq': 2, 'min_child_samples': 34, 'max_bin': 357}. Best is trial 1 with value: 70.14695556430492.
# [I 2021-07-22 18:11:37,165] Trial 2 finished with value: 73.60239095956125 and parameters: {'num_leaves': 4376, 'reg_alpha': 8.743961914539277e-06, 'reg_lambda': 0.05506676440648521, 'max_depth': 3, 'colsample_bytree': 0.5752867891211308, 'subsample': 0.5564532903055841, 'subsample_freq': 5, 'min_child_samples': 80, 'max_bin': 260}. Best is trial 1 with value: 70.14695556430492.
# [I 2021-07-22 18:11:38,424] Trial 3 finished with value: 94.88253073451642 and parameters: {'num_leaves': 5191, 'reg_alpha': 1.7776512920172654e-05, 'reg_lambda': 0.004180546680295668, 'max_depth': 13, 'colsample_bytree': 0.502314474212375, 'subsample': 0.3455361150896956, 'subsample_freq': 10, 'min_child_samples': 97, 'max_bin': 443}. Best is trial 1 with value: 70.14695556430492.
# [I 2021-07-22 18:11:39,239] Trial 4 finished with value: 73.52744470482371 and parameters: {'num_leaves': 3115, 'reg_alpha': 2.939186699051452e-06, 'reg_lambda': 0.061580975543763856, 'max_depth': 9, 'colsample_bytree': 0.47322294090686734, 'subsample': 0.6466238370778892, 'subsample_freq': 1, 'min_child_samples': 92, 'max_bin': 277}. Best is trial 1 with value: 70.14695556430492.
# [I 2021-07-22 18:11:40,151] Trial 5 finished with value: 70.12036979631831 and parameters: {'num_leaves': 6659, 'reg_alpha': 9.358215171921434e-06, 'reg_lambda': 0.04680612670532276, 'max_depth': 11, 'colsample_bytree': 0.5109126733153162, 'subsample': 0.9787092394351908, 'subsample_freq': 8, 'min_child_samples': 95, 'max_bin': 469}. Best is trial 5 with value: 70.12036979631831.
# [I 2021-07-22 18:11:40,703] Trial 6 finished with value: 69.75468739188156 and parameters: {'num_leaves': 6019, 'reg_alpha': 2.7657008308343274e-05, 'reg_lambda': 0.007964334299747734, 'max_depth': 4, 'colsample_bytree': 0.4271363733463229, 'subsample': 0.527731231534285, 'subsample_freq': 4, 'min_child_samples': 31, 'max_bin': 449}. Best is trial 6 with value: 69.75468739188156.
# [I 2021-07-22 18:11:41,056] Trial 7 finished with value: 91.00283078135831 and parameters: {'num_leaves': 3632, 'reg_alpha': 8.43522594552455e-06, 'reg_lambda': 0.048842652057281534, 'max_depth': 3, 'colsample_bytree': 0.8813181884524238, 'subsample': 0.35218545057583955, 'subsample_freq': 10, 'min_child_samples': 79, 'max_bin': 259}. Best is trial 6 with value: 69.75468739188156.
# [I 2021-07-22 18:11:41,409] Trial 8 finished with value: 70.72701375667737 and parameters: {'num_leaves': 154, 'reg_alpha': 2.4465688239360478e-05, 'reg_lambda': 0.0636171638777121, 'max_depth': 15, 'colsample_bytree': 0.8627622080115674, 'subsample': 0.35183125621386324, 'subsample_freq': 4, 'min_child_samples': 16, 'max_bin': 459}. Best is trial 6 with value: 69.75468739188156.
# [I 2021-07-22 18:11:41,965] Trial 9 finished with value: 71.00663930080836 and parameters: {'num_leaves': 6271, 'reg_alpha': 9.933631765330948e-06, 'reg_lambda': 0.005720260890158624, 'max_depth': 7, 'colsample_bytree': 0.5951099932160482, 'subsample': 0.8107243248366449, 'subsample_freq': 7, 'min_child_samples': 90, 'max_bin': 342}. Best is trial 6 with value: 69.75468739188156.
# [I 2021-07-22 18:11:42,395] Trial 10 finished with value: 75.34260859363292 and parameters: {'num_leaves': 9540, 'reg_alpha': 2.118694822215234e-05, 'reg_lambda': 0.023350345225999068, 'max_depth': 1, 'colsample_bytree': 0.744330034535852, 'subsample': 0.8003835201228653, 'subsample_freq': 3, 'min_child_samples': 52, 'max_bin': 401}. Best is trial 6 with value: 69.75468739188156.
# [I 2021-07-22 18:11:43,130] Trial 11 finished with value: 68.31798129081105 and parameters: {'num_leaves': 8850, 'reg_alpha': 1.3389290958287313e-05, 'reg_lambda': 0.028042386705602256, 'max_depth': 7, 'colsample_bytree': 0.6635771898687691, 'subsample': 0.9936659158640533, 'subsample_freq': 7, 'min_child_samples': 6, 'max_bin': 498}. Best is trial 11 with value: 68.31798129081105.
# [I 2021-07-22 18:11:43,727] Trial 12 finished with value: 67.73553093770695 and parameters: {'num_leaves': 9965, 'reg_alpha': 1.50566707122547e-05, 'reg_lambda': 0.024250234144568863, 'max_depth': 6, 'colsample_bytree': 0.7152071913859575, 'subsample': 0.5319893946149051, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 499}. Best is trial 12 with value: 67.73553093770695.
# [I 2021-07-22 18:11:44,619] Trial 13 finished with value: 68.38218213054115 and parameters: {'num_leaves': 9977, 'reg_alpha': 1.5181800163506232e-05, 'reg_lambda': 0.027608692587736086, 'max_depth': 7, 'colsample_bytree': 0.7312437202532609, 'subsample': 0.9993086610783681, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 494}. Best is trial 12 with value: 67.73553093770695.
# [I 2021-07-22 18:11:45,361] Trial 14 finished with value: 67.56247052535639 and parameters: {'num_leaves': 8557, 'reg_alpha': 1.3724933043971749e-05, 'reg_lambda': 0.026885242247914574, 'max_depth': 7, 'colsample_bytree': 0.6627361446111619, 'subsample': 0.8112379230234356, 'subsample_freq': 8, 'min_child_samples': 10, 'max_bin': 500}. Best is trial 14 with value: 67.56247052535639.
# [I 2021-07-22 18:11:46,062] Trial 15 finished with value: 68.97196918844644 and parameters: {'num_leaves': 8401, 'reg_alpha': 1.891334808241224e-05, 'reg_lambda': 0.018622990493754005, 'max_depth': 9, 'colsample_bytree': 0.7906207820864339, 'subsample': 0.814495316090922, 'subsample_freq': 9, 'min_child_samples': 21, 'max_bin': 500}. Best is trial 14 with value: 67.56247052535639.
# [I 2021-07-22 18:11:46,599] Trial 16 finished with value: 69.24242557133446 and parameters: {'num_leaves': 8345, 'reg_alpha': 1.2304426501407797e-05, 'reg_lambda': 0.03576574244492211, 'max_depth': 5, 'colsample_bytree': 0.6673693164566754, 'subsample': 0.6892344358624438, 'subsample_freq': 6, 'min_child_samples': 53, 'max_bin': 213}. Best is trial 14 with value: 67.56247052535639.
# [I 2021-07-22 18:11:47,212] Trial 17 finished with value: 70.42293283301655 and parameters: {'num_leaves': 1668, 'reg_alpha': 4.851508998483666e-06, 'reg_lambda': 0.01467622485095454, 'max_depth': 1, 'colsample_bytree': 0.9971117680924547, 'subsample': 0.8789148188241778, 'subsample_freq': 9, 'min_child_samples': 14, 'max_bin': 409}. Best is trial 14 with value: 67.56247052535639.
# [I 2021-07-22 18:11:47,843] Trial 18 finished with value: 69.31148729254645 and parameters: {'num_leaves': 7811, 'reg_alpha': 1.6570810994846303e-05, 'reg_lambda': 0.03867396005419289, 'max_depth': 9, 'colsample_bytree': 0.8199439626014555, 'subsample': 0.6907340503415385, 'subsample_freq': 8, 'min_child_samples': 43, 'max_bin': 418}. Best is trial 14 with value: 67.56247052535639.
# [I 2021-07-22 18:11:48,271] Trial 19 finished with value: 68.6350428591925 and parameters: {'num_leaves': 9031, 'reg_alpha': 2.219521199655099e-05, 'reg_lambda': 0.035526485549229686, 'max_depth': 6, 'colsample_bytree': 0.6330368118797098, 'subsample': 0.5734449090355216, 'subsample_freq': 6, 'min_child_samples': 26, 'max_bin': 308}. Best is trial 14 with value: 67.56247052535639.
# [I 2021-07-22 18:11:48,825] Trial 20 finished with value: 70.40995619040885 and parameters: {'num_leaves': 9603, 'reg_alpha': 5.393947088705108e-06, 'reg_lambda': 0.013846934364442202, 'max_depth': 1, 'colsample_bytree': 0.9719028273458007, 'subsample': 0.7499517594410624, 'subsample_freq': 8, 'min_child_samples': 5, 'max_bin': 485}. Best is trial 14 with value: 67.56247052535639.
# [I 2021-07-22 18:11:49,822] Trial 21 finished with value: 68.98589360986344 and parameters: {'num_leaves': 9954, 'reg_alpha': 1.3275133106491296e-05, 'reg_lambda': 0.02862383023623223, 'max_depth': 8, 'colsample_bytree': 0.6858217471871327, 'subsample': 0.9397333706502208, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 493}. Best is trial 14 with value: 67.56247052535639.
# [I 2021-07-22 18:11:50,333] Trial 22 finished with value: 66.46331706553221 and parameters: {'num_leaves': 7862, 'reg_alpha': 1.3224986300192552e-05, 'reg_lambda': 0.02772124014450937, 'max_depth': 5, 'colsample_bytree': 0.6215227375698865, 'subsample': 0.8993563347209121, 'subsample_freq': 9, 'min_child_samples': 11, 'max_bin': 439}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:50,825] Trial 23 finished with value: 66.94771839554467 and parameters: {'num_leaves': 7980, 'reg_alpha': 1.1877134706425478e-05, 'reg_lambda': 0.020599414497959233, 'max_depth': 5, 'colsample_bytree': 0.588228935187439, 'subsample': 0.9041238395586411, 'subsample_freq': 9, 'min_child_samples': 13, 'max_bin': 433}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:51,284] Trial 24 finished with value: 66.5059879185617 and parameters: {'num_leaves': 7469, 'reg_alpha': 1.2187444564509942e-05, 'reg_lambda': 0.04185038655596347, 'max_depth': 3, 'colsample_bytree': 0.5863203168977693, 'subsample': 0.8993788458247098, 'subsample_freq': 9, 'min_child_samples': 15, 'max_bin': 436}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:51,738] Trial 25 finished with value: 66.85697213079416 and parameters: {'num_leaves': 7603, 'reg_alpha': 1.1209924682446158e-05, 'reg_lambda': 0.04280713689897749, 'max_depth': 3, 'colsample_bytree': 0.5736250786825483, 'subsample': 0.9062332590937976, 'subsample_freq': 10, 'min_child_samples': 21, 'max_bin': 434}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:52,161] Trial 26 finished with value: 67.02072526459497 and parameters: {'num_leaves': 6915, 'reg_alpha': 6.02968457267719e-06, 'reg_lambda': 0.07652992176330789, 'max_depth': 3, 'colsample_bytree': 0.5543886127504459, 'subsample': 0.8794870922738428, 'subsample_freq': 10, 'min_child_samples': 22, 'max_bin': 371}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:52,666] Trial 27 finished with value: 68.60373915951429 and parameters: {'num_leaves': 5646, 'reg_alpha': 1.0697180036856838e-05, 'reg_lambda': 0.0419198600223768, 'max_depth': 2, 'colsample_bytree': 0.4301758073908891, 'subsample': 0.9469963028991147, 'subsample_freq': 10, 'min_child_samples': 38, 'max_bin': 391}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:53,242] Trial 28 finished with value: 68.04558693486668 and parameters: {'num_leaves': 7302, 'reg_alpha': 7.200319360013973e-06, 'reg_lambda': 0.05070150295494234, 'max_depth': 4, 'colsample_bytree': 0.6138953864247765, 'subsample': 0.8521579569667592, 'subsample_freq': 9, 'min_child_samples': 25, 'max_bin': 431}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:53,794] Trial 29 finished with value: 68.8051009920361 and parameters: {'num_leaves': 7539, 'reg_alpha': 1.897971679647231e-05, 'reg_lambda': 0.05587566399719971, 'max_depth': 2, 'colsample_bytree': 0.4654262492119481, 'subsample': 0.7505490926371698, 'subsample_freq': 9, 'min_child_samples': 51, 'max_bin': 468}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:54,324] Trial 30 finished with value: 68.96787020491637 and parameters: {'num_leaves': 4623, 'reg_alpha': 1.674089808706648e-05, 'reg_lambda': 0.07218474114546936, 'max_depth': 4, 'colsample_bytree': 0.5451204616164895, 'subsample': 0.9459100311721435, 'subsample_freq': 10, 'min_child_samples': 65, 'max_bin': 379}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:54,797] Trial 31 finished with value: 67.26210721232619 and parameters: {'num_leaves': 7864, 'reg_alpha': 1.1215047333536508e-05, 'reg_lambda': 0.0408499874021271, 'max_depth': 5, 'colsample_bytree': 0.5947229528454242, 'subsample': 0.8970541095713362, 'subsample_freq': 9, 'min_child_samples': 16, 'max_bin': 427}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:56,954] Trial 32 finished with value: 68.57866109979072 and parameters: {'num_leaves': 6658, 'reg_alpha': 1.1794941602061483e-05, 'reg_lambda': 0.032651215214657636, 'max_depth': 20, 'colsample_bytree': 0.6293489666706225, 'subsample': 0.9107373105125098, 'subsample_freq': 9, 'min_child_samples': 12, 'max_bin': 436}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:57,511] Trial 33 finished with value: 67.80223086847715 and parameters: {'num_leaves': 7894, 'reg_alpha': 7.587912959472433e-06, 'reg_lambda': 0.01835237949964753, 'max_depth': 5, 'colsample_bytree': 0.5534349739212749, 'subsample': 0.8392208242652026, 'subsample_freq': 10, 'min_child_samples': 20, 'max_bin': 360}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:58,041] Trial 34 finished with value: 68.08629955469205 and parameters: {'num_leaves': 9088, 'reg_alpha': 1.4630955832917461e-05, 'reg_lambda': 0.0445180668833226, 'max_depth': 2, 'colsample_bytree': 0.5759742116546347, 'subsample': 0.7573025398063293, 'subsample_freq': 8, 'min_child_samples': 27, 'max_bin': 404}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:11:58,567] Trial 35 finished with value: 68.7706014969688 and parameters: {'num_leaves': 5216, 'reg_alpha': 1.0188577750167835e-05, 'reg_lambda': 0.0325242644547606, 'max_depth': 3, 'colsample_bytree': 0.5260196706642628, 'subsample': 0.9226707068797586, 'subsample_freq': 9, 'min_child_samples': 34, 'max_bin': 449}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:12:01,094] Trial 36 finished with value: 69.07893042933108 and parameters: {'num_leaves': 7262, 'reg_alpha': 2.4184627676342777e-06, 'reg_lambda': 0.05421044899270894, 'max_depth': 13, 'colsample_bytree': 0.47948065423725705, 'subsample': 0.9819953121053117, 'subsample_freq': 10, 'min_child_samples': 12, 'max_bin': 330}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:12:02,215] Trial 37 finished with value: 68.92447061855839 and parameters: {'num_leaves': 6281, 'reg_alpha': 1.2296917299852095e-05, 'reg_lambda': 0.0002458281243392299, 'max_depth': 11, 'colsample_bytree': 0.6290655610555707, 'subsample': 0.8610860498155407, 'subsample_freq': 8, 'min_child_samples': 18, 'max_bin': 474}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:12:02,812] Trial 38 finished with value: 68.37776850774674 and parameters: {'num_leaves': 8231, 'reg_alpha': 9.147735952193099e-06, 'reg_lambda': 0.021571718663282058, 'max_depth': 5, 'colsample_bytree': 0.5787933039890084, 'subsample': 0.9666018941456547, 'subsample_freq': 9, 'min_child_samples': 30, 'max_bin': 446}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:12:03,359] Trial 39 finished with value: 68.52721018751723 and parameters: {'num_leaves': 5625, 'reg_alpha': 1.564846937489799e-05, 'reg_lambda': 0.013589778338814112, 'max_depth': 3, 'colsample_bytree': 0.5092665147016608, 'subsample': 0.9088233328283539, 'subsample_freq': 10, 'min_child_samples': 42, 'max_bin': 417}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:12:04,034] Trial 40 finished with value: 67.55479853049457 and parameters: {'num_leaves': 6728, 'reg_alpha': 1.798690939160786e-05, 'reg_lambda': 0.05926612149542772, 'max_depth': 6, 'colsample_bytree': 0.4510914309523594, 'subsample': 0.7668555539366364, 'subsample_freq': 8, 'min_child_samples': 9, 'max_bin': 459}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:12:04,491] Trial 41 finished with value: 68.0237875097525 and parameters: {'num_leaves': 6886, 'reg_alpha': 6.0934256012998115e-06, 'reg_lambda': 0.08513376436049097, 'max_depth': 4, 'colsample_bytree': 0.5547376327293737, 'subsample': 0.8770605521859397, 'subsample_freq': 10, 'min_child_samples': 23, 'max_bin': 369}. Best is trial 22 with value: 66.46331706553221.
# [I 2021-07-22 18:12:05,014] Trial 42 finished with value: 66.38030516955489 and parameters: {'num_leaves': 7261, 'reg_alpha': 1.1469736377795195e-06, 'reg_lambda': 0.07258536373632571, 'max_depth': 2, 'colsample_bytree': 0.5368703814691799, 'subsample': 0.8380684125398865, 'subsample_freq': 10, 'min_child_samples': 19, 'max_bin': 386}. Best is trial 42 with value: 66.38030516955489.
# [I 2021-07-22 18:12:05,574] Trial 43 finished with value: 66.1199139619315 and parameters: {'num_leaves': 7565, 'reg_alpha': 1.1000724133321039e-06, 'reg_lambda': 0.06899203961135741, 'max_depth': 2, 'colsample_bytree': 0.6014458679259116, 'subsample': 0.8377928058067148, 'subsample_freq': 9, 'min_child_samples': 17, 'max_bin': 391}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:06,080] Trial 44 finished with value: 75.48215979352439 and parameters: {'num_leaves': 7455, 'reg_alpha': 1.5965802825329408e-06, 'reg_lambda': 0.0675031380402716, 'max_depth': 1, 'colsample_bytree': 0.49928895413676844, 'subsample': 0.8401192421540841, 'subsample_freq': 10, 'min_child_samples': 31, 'max_bin': 392}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:06,573] Trial 45 finished with value: 66.68114448852323 and parameters: {'num_leaves': 5987, 'reg_alpha': 3.589532138209734e-06, 'reg_lambda': 0.08012241347741791, 'max_depth': 2, 'colsample_bytree': 0.531963949923853, 'subsample': 0.716407981042843, 'subsample_freq': 9, 'min_child_samples': 17, 'max_bin': 350}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:07,068] Trial 46 finished with value: 66.29753296399451 and parameters: {'num_leaves': 6141, 'reg_alpha': 5.479839117820049e-07, 'reg_lambda': 0.08899314601008178, 'max_depth': 2, 'colsample_bytree': 0.6536601355841051, 'subsample': 0.6999168645642992, 'subsample_freq': 1, 'min_child_samples': 17, 'max_bin': 344}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:07,701] Trial 47 finished with value: 70.02673169687209 and parameters: {'num_leaves': 6379, 'reg_alpha': 1.0744927594792764e-08, 'reg_lambda': 0.08830103317469304, 'max_depth': 1, 'colsample_bytree': 0.6494425589871475, 'subsample': 0.6091292605132709, 'subsample_freq': 3, 'min_child_samples': 9, 'max_bin': 331}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:08,412] Trial 48 finished with value: 71.23216193234833 and parameters: {'num_leaves': 4348, 'reg_alpha': 9.263555722195508e-07, 'reg_lambda': 0.06793468774691316, 'max_depth': 2, 'colsample_bytree': 0.6819794555504444, 'subsample': 0.7796434696401436, 'subsample_freq': 1, 'min_child_samples': 81, 'max_bin': 387}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:08,787] Trial 49 finished with value: 69.5758975268752 and parameters: {'num_leaves': 8721, 'reg_alpha': 4.036383690446457e-06, 'reg_lambda': 0.08345492361710036, 'max_depth': 4, 'colsample_bytree': 0.7545987398313606, 'subsample': 0.4486439485657704, 'subsample_freq': 5, 'min_child_samples': 28, 'max_bin': 299}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:09,285] Trial 50 finished with value: 68.72029555926639 and parameters: {'num_leaves': 5547, 'reg_alpha': 2.841443664037545e-05, 'reg_lambda': 0.06242401137625097, 'max_depth': 2, 'colsample_bytree': 0.7036424351993992, 'subsample': 0.7251511164224764, 'subsample_freq': 2, 'min_child_samples': 35, 'max_bin': 337}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:09,789] Trial 51 finished with value: 66.44457351256264 and parameters: {'num_leaves': 5976, 'reg_alpha': 3.3710634638511334e-06, 'reg_lambda': 0.07979035016310113, 'max_depth': 2, 'colsample_bytree': 0.6117270548981166, 'subsample': 0.6916564149535293, 'subsample_freq': 8, 'min_child_samples': 17, 'max_bin': 348}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:10,194] Trial 52 finished with value: 67.2621916230911 and parameters: {'num_leaves': 5998, 'reg_alpha': 2.4301259312750595e-06, 'reg_lambda': 0.078980633018349, 'max_depth': 3, 'colsample_bytree': 0.6068016964973615, 'subsample': 0.6639576005267008, 'subsample_freq': 8, 'min_child_samples': 17, 'max_bin': 318}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:10,766] Trial 53 finished with value: 70.4477284946286 and parameters: {'num_leaves': 4992, 'reg_alpha': 7.545327016411837e-07, 'reg_lambda': 0.07401062917873047, 'max_depth': 1, 'colsample_bytree': 0.6419666923810249, 'subsample': 0.6275583407305628, 'subsample_freq': 7, 'min_child_samples': 8, 'max_bin': 362}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:11,487] Trial 54 finished with value: 70.65110506656376 and parameters: {'num_leaves': 7048, 'reg_alpha': 1.5228130374738344e-07, 'reg_lambda': 0.07099409455697303, 'max_depth': 1, 'colsample_bytree': 0.6122824698475277, 'subsample': 0.7913267409533954, 'subsample_freq': 4, 'min_child_samples': 14, 'max_bin': 347}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:11,995] Trial 55 finished with value: 67.88307617786734 and parameters: {'num_leaves': 6490, 'reg_alpha': 1.5408775170496713e-06, 'reg_lambda': 0.08177012701576707, 'max_depth': 2, 'colsample_bytree': 0.6620535947334323, 'subsample': 0.8202297003112459, 'subsample_freq': 6, 'min_child_samples': 24, 'max_bin': 282}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:12,452] Trial 56 finished with value: 67.24014348068943 and parameters: {'num_leaves': 8202, 'reg_alpha': 3.862028861145049e-06, 'reg_lambda': 0.08763946074938773, 'max_depth': 4, 'colsample_bytree': 0.524743789352422, 'subsample': 0.6692833160856673, 'subsample_freq': 8, 'min_child_samples': 11, 'max_bin': 415}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:14,375] Trial 57 finished with value: 68.7283261198127 and parameters: {'num_leaves': 7053, 'reg_alpha': 2.5282563643861046e-05, 'reg_lambda': 0.08988630655208492, 'max_depth': 17, 'colsample_bytree': 0.690064655355537, 'subsample': 0.7160730495224477, 'subsample_freq': 9, 'min_child_samples': 20, 'max_bin': 400}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:14,903] Trial 58 finished with value: 67.37397804727556 and parameters: {'num_leaves': 3596, 'reg_alpha': 2.606759449987388e-06, 'reg_lambda': 0.07437628048839508, 'max_depth': 3, 'colsample_bytree': 0.7334632153250622, 'subsample': 0.4695652480209177, 'subsample_freq': 8, 'min_child_samples': 7, 'max_bin': 382}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:15,481] Trial 59 finished with value: 67.16363908110417 and parameters: {'num_leaves': 9364, 'reg_alpha': 4.647215292968923e-06, 'reg_lambda': 0.04870441062397129, 'max_depth': 6, 'colsample_bytree': 0.6138187723881845, 'subsample': 0.591019319459322, 'subsample_freq': 9, 'min_child_samples': 15, 'max_bin': 354}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:15,952] Trial 60 finished with value: 78.95058768228301 and parameters: {'num_leaves': 5952, 'reg_alpha': 7.278436933497313e-06, 'reg_lambda': 0.07740501359625637, 'max_depth': 1, 'colsample_bytree': 0.5710671849241331, 'subsample': 0.8304051288325173, 'subsample_freq': 7, 'min_child_samples': 100, 'max_bin': 374}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:16,416] Trial 61 finished with value: 67.09922283726995 and parameters: {'num_leaves': 6059, 'reg_alpha': 3.830520583434964e-06, 'reg_lambda': 0.07908845775339761, 'max_depth': 2, 'colsample_bytree': 0.5389205094500923, 'subsample': 0.7266158328643324, 'subsample_freq': 9, 'min_child_samples': 19, 'max_bin': 320}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:16,881] Trial 62 finished with value: 67.21093497555778 and parameters: {'num_leaves': 5230, 'reg_alpha': 2.988494321342576e-06, 'reg_lambda': 0.08253690526577605, 'max_depth': 2, 'colsample_bytree': 0.4892090779298538, 'subsample': 0.6963294368643849, 'subsample_freq': 9, 'min_child_samples': 15, 'max_bin': 342}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:17,345] Trial 63 finished with value: 68.24978371682252 and parameters: {'num_leaves': 7592, 'reg_alpha': 1.2010319831155278e-07, 'reg_lambda': 0.0652501235893211, 'max_depth': 4, 'colsample_bytree': 0.6498268672751129, 'subsample': 0.6455034427822113, 'subsample_freq': 10, 'min_child_samples': 18, 'max_bin': 351}. Best is trial 43 with value: 66.1199139619315.
# [I 2021-07-22 18:12:17,820] Trial 64 finished with value: 65.6593533768751 and parameters: {'num_leaves': 4733, 'reg_alpha': 1.677975289146708e-06, 'reg_lambda': 0.06929409664496167, 'max_depth': 3, 'colsample_bytree': 0.5972280958356424, 'subsample': 0.8016339604108655, 'subsample_freq': 9, 'min_child_samples': 5, 'max_bin': 365}. Best is trial 64 with value: 65.6593533768751.
# [I 2021-07-22 18:12:18,365] Trial 65 finished with value: 65.64442935443356 and parameters: {'num_leaves': 2532, 'reg_alpha': 1.6423006305810287e-06, 'reg_lambda': 0.06923649741794881, 'max_depth': 3, 'colsample_bytree': 0.5926842973782248, 'subsample': 0.8656125750531953, 'subsample_freq': 8, 'min_child_samples': 5, 'max_bin': 395}. Best is trial 65 with value: 65.64442935443356.
# [I 2021-07-22 18:12:18,972] Trial 66 finished with value: 65.81320050121604 and parameters: {'num_leaves': 2053, 'reg_alpha': 1.3589411714454489e-06, 'reg_lambda': 0.07087243648807141, 'max_depth': 3, 'colsample_bytree': 0.6032143252569719, 'subsample': 0.8027332748025011, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 397}. Best is trial 65 with value: 65.64442935443356.
# [I 2021-07-22 18:12:19,469] Trial 67 finished with value: 65.56855393373829 and parameters: {'num_leaves': 2084, 'reg_alpha': 1.5199771019262749e-06, 'reg_lambda': 0.059303624094646706, 'max_depth': 3, 'colsample_bytree': 0.6012487174154997, 'subsample': 0.7968194990633413, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 393}. Best is trial 67 with value: 65.56855393373829.
# [I 2021-07-22 18:12:19,943] Trial 68 finished with value: 65.91741654309884 and parameters: {'num_leaves': 2003, 'reg_alpha': 2.1533345454360264e-06, 'reg_lambda': 0.05959321203719709, 'max_depth': 3, 'colsample_bytree': 0.5993562528692635, 'subsample': 0.8015078957039024, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 397}. Best is trial 67 with value: 65.56855393373829.
# [I 2021-07-22 18:12:20,452] Trial 69 finished with value: 65.47916675733347 and parameters: {'num_leaves': 2027, 'reg_alpha': 1.6941613487985888e-06, 'reg_lambda': 0.05942047919682872, 'max_depth': 3, 'colsample_bytree': 0.5919663163606199, 'subsample': 0.7972809855964462, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 395}. Best is trial 69 with value: 65.47916675733347.
# [I 2021-07-22 18:12:21,512] Trial 70 finished with value: 68.53582190401487 and parameters: {'num_leaves': 2041, 'reg_alpha': 1.9322120512525506e-06, 'reg_lambda': 0.056751435605720164, 'max_depth': 8, 'colsample_bytree': 0.5961404352562267, 'subsample': 0.7968801857620523, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 397}. Best is trial 69 with value: 65.47916675733347.
# [I 2021-07-22 18:12:21,971] Trial 71 finished with value: 65.74929365811279 and parameters: {'num_leaves': 2134, 'reg_alpha': 2.696090743527719e-07, 'reg_lambda': 0.05962047275268359, 'max_depth': 3, 'colsample_bytree': 0.6699352454438561, 'subsample': 0.7771094417855504, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 409}. Best is trial 69 with value: 65.47916675733347.
# [I 2021-07-22 18:12:22,412] Trial 72 finished with value: 65.50929039276645 and parameters: {'num_leaves': 1997, 'reg_alpha': 5.1758916427946734e-06, 'reg_lambda': 0.05982140825757617, 'max_depth': 3, 'colsample_bytree': 0.5590109092438449, 'subsample': 0.778446770019057, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 407}. Best is trial 69 with value: 65.47916675733347.
# [I 2021-07-22 18:12:22,987] Trial 73 finished with value: 65.33514021740959 and parameters: {'num_leaves': 2096, 'reg_alpha': 5.095482023991251e-06, 'reg_lambda': 0.05960972904003394, 'max_depth': 4, 'colsample_bytree': 0.5624832797971228, 'subsample': 0.7812736022857937, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 406}. Best is trial 73 with value: 65.33514021740959.
# [I 2021-07-22 18:12:23,503] Trial 74 finished with value: 65.82676284411886 and parameters: {'num_leaves': 1048, 'reg_alpha': 6.196215226197746e-06, 'reg_lambda': 0.05263980926877292, 'max_depth': 4, 'colsample_bytree': 0.5644002605032554, 'subsample': 0.7752889040900224, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 411}. Best is trial 73 with value: 65.33514021740959.
# [I 2021-07-22 18:12:24,026] Trial 75 finished with value: 65.5213217613699 and parameters: {'num_leaves': 2601, 'reg_alpha': 5.281226981136083e-06, 'reg_lambda': 0.06473006175537428, 'max_depth': 4, 'colsample_bytree': 0.6735452180552685, 'subsample': 0.7480655595875273, 'subsample_freq': 5, 'min_child_samples': 7, 'max_bin': 425}. Best is trial 73 with value: 65.33514021740959.
# [I 2021-07-22 18:12:24,619] Trial 76 finished with value: 67.17770303878004 and parameters: {'num_leaves': 2577, 'reg_alpha': 5.127580516049595e-06, 'reg_lambda': 0.06392815348172846, 'max_depth': 6, 'colsample_bytree': 0.6726258875057688, 'subsample': 0.7432849325986499, 'subsample_freq': 5, 'min_child_samples': 8, 'max_bin': 426}. Best is trial 73 with value: 65.33514021740959.
# [I 2021-07-22 18:12:25,179] Trial 77 finished with value: 66.82892650016527 and parameters: {'num_leaves': 1062, 'reg_alpha': 8.323198134589066e-06, 'reg_lambda': 0.05993857594898698, 'max_depth': 5, 'colsample_bytree': 0.6325652935501321, 'subsample': 0.8598906018116255, 'subsample_freq': 5, 'min_child_samples': 10, 'max_bin': 420}. Best is trial 73 with value: 65.33514021740959.
# [I 2021-07-22 18:12:25,663] Trial 78 finished with value: 65.29803731665872 and parameters: {'num_leaves': 3069, 'reg_alpha': 4.604568803863953e-06, 'reg_lambda': 0.056664520419052566, 'max_depth': 4, 'colsample_bytree': 0.7646378293269978, 'subsample': 0.7399728441026854, 'subsample_freq': 6, 'min_child_samples': 8, 'max_bin': 410}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:26,151] Trial 79 finished with value: 65.4110858809809 and parameters: {'num_leaves': 3060, 'reg_alpha': 4.604727515652141e-06, 'reg_lambda': 0.05705834590905635, 'max_depth': 4, 'colsample_bytree': 0.7748463331450642, 'subsample': 0.7375161053990471, 'subsample_freq': 6, 'min_child_samples': 8, 'max_bin': 406}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:26,706] Trial 80 finished with value: 66.15792135103368 and parameters: {'num_leaves': 2986, 'reg_alpha': 5.714539315834801e-06, 'reg_lambda': 0.05668965607084505, 'max_depth': 5, 'colsample_bytree': 0.7808357055725296, 'subsample': 0.7632609243739973, 'subsample_freq': 6, 'min_child_samples': 11, 'max_bin': 425}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:27,202] Trial 81 finished with value: 65.77006453955991 and parameters: {'num_leaves': 2865, 'reg_alpha': 4.427574395189817e-06, 'reg_lambda': 0.06229472130396117, 'max_depth': 4, 'colsample_bytree': 0.8164988871229427, 'subsample': 0.7390833827585507, 'subsample_freq': 6, 'min_child_samples': 8, 'max_bin': 407}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:27,825] Trial 82 finished with value: 67.52181352617356 and parameters: {'num_leaves': 1339, 'reg_alpha': 6.50907656127503e-06, 'reg_lambda': 0.06582175480053869, 'max_depth': 7, 'colsample_bytree': 0.819638887350857, 'subsample': 0.8136663904688962, 'subsample_freq': 5, 'min_child_samples': 13, 'max_bin': 380}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:28,286] Trial 83 finished with value: 65.56970782408843 and parameters: {'num_leaves': 3445, 'reg_alpha': 5.235903557979109e-06, 'reg_lambda': 0.05211977570311526, 'max_depth': 4, 'colsample_bytree': 0.7689987003338984, 'subsample': 0.7892328941436612, 'subsample_freq': 6, 'min_child_samples': 7, 'max_bin': 368}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:28,903] Trial 84 finished with value: 66.56206583308762 and parameters: {'num_leaves': 2420, 'reg_alpha': 5.098378627046221e-06, 'reg_lambda': 0.051885355230024514, 'max_depth': 5, 'colsample_bytree': 0.8853440730839436, 'subsample': 0.7412165115297354, 'subsample_freq': 6, 'min_child_samples': 7, 'max_bin': 374}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:29,412] Trial 85 finished with value: 69.89200116047647 and parameters: {'num_leaves': 3328, 'reg_alpha': 7.018950761620329e-06, 'reg_lambda': 0.04591556386511279, 'max_depth': 4, 'colsample_bytree': 0.7641117522325307, 'subsample': 0.7821420712235221, 'subsample_freq': 5, 'min_child_samples': 67, 'max_bin': 421}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:30,057] Trial 86 finished with value: 67.9698397747715 and parameters: {'num_leaves': 1706, 'reg_alpha': 3.095699009534571e-06, 'reg_lambda': 0.04906468278920821, 'max_depth': 6, 'colsample_bytree': 0.798852437501689, 'subsample': 0.3215556217127017, 'subsample_freq': 6, 'min_child_samples': 10, 'max_bin': 405}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:30,603] Trial 87 finished with value: 66.78971927911147 and parameters: {'num_leaves': 2720, 'reg_alpha': 8.255731044726686e-06, 'reg_lambda': 0.054837868946412, 'max_depth': 5, 'colsample_bytree': 0.8477311167305193, 'subsample': 0.7564388830698732, 'subsample_freq': 4, 'min_child_samples': 12, 'max_bin': 441}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:31,146] Trial 88 finished with value: 65.90509140636533 and parameters: {'num_leaves': 3183, 'reg_alpha': 4.584028309456137e-06, 'reg_lambda': 0.05828943214296368, 'max_depth': 4, 'colsample_bytree': 0.7326454861474382, 'subsample': 0.8746381103846311, 'subsample_freq': 6, 'min_child_samples': 7, 'max_bin': 451}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:31,802] Trial 89 finished with value: 68.33031486214736 and parameters: {'num_leaves': 3925, 'reg_alpha': 6.617983959903444e-06, 'reg_lambda': 0.06131552857552383, 'max_depth': 7, 'colsample_bytree': 0.711161984518624, 'subsample': 0.8171604567364498, 'subsample_freq': 5, 'min_child_samples': 9, 'max_bin': 384}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:32,237] Trial 90 finished with value: 66.66601053191124 and parameters: {'num_leaves': 2389, 'reg_alpha': 5.54491392241529e-06, 'reg_lambda': 0.05355155825590895, 'max_depth': 4, 'colsample_bytree': 0.7669851929625938, 'subsample': 0.7320437735796226, 'subsample_freq': 6, 'min_child_samples': 13, 'max_bin': 415}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:32,792] Trial 91 finished with value: 65.51304613032991 and parameters: {'num_leaves': 1663, 'reg_alpha': 3.084174612609985e-06, 'reg_lambda': 0.05729971470401428, 'max_depth': 3, 'colsample_bytree': 0.797574519066401, 'subsample': 0.710088562151202, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 362}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:33,290] Trial 92 finished with value: 65.47357632253893 and parameters: {'num_leaves': 622, 'reg_alpha': 3.233081371069887e-06, 'reg_lambda': 0.0641984676252327, 'max_depth': 3, 'colsample_bytree': 0.7992300149432923, 'subsample': 0.7154260820750964, 'subsample_freq': 7, 'min_child_samples': 7, 'max_bin': 393}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:33,633] Trial 93 finished with value: 66.32966412316833 and parameters: {'num_leaves': 195, 'reg_alpha': 7.820564477897076e-06, 'reg_lambda': 0.057381510646490094, 'max_depth': 3, 'colsample_bytree': 0.8370147455049464, 'subsample': 0.6696531391458308, 'subsample_freq': 7, 'min_child_samples': 7, 'max_bin': 388}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:34,241] Trial 94 finished with value: 65.92387266916907 and parameters: {'num_leaves': 334, 'reg_alpha': 3.184998949079044e-06, 'reg_lambda': 0.06440115422269783, 'max_depth': 5, 'colsample_bytree': 0.7908469530715546, 'subsample': 0.7140307552536345, 'subsample_freq': 7, 'min_child_samples': 10, 'max_bin': 376}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:34,722] Trial 95 finished with value: 67.11197315499045 and parameters: {'num_leaves': 1658, 'reg_alpha': 4.681169337157685e-06, 'reg_lambda': 0.06142687866499819, 'max_depth': 4, 'colsample_bytree': 0.8803639785236687, 'subsample': 0.7099310322455294, 'subsample_freq': 6, 'min_child_samples': 12, 'max_bin': 402}. Best is trial 78 with value: 65.29803731665872.
# [I 2021-07-22 18:12:35,223] Trial 96 finished with value: 65.02830703557942 and parameters: {'num_leaves': 852, 'reg_alpha': 4.2867564148426824e-06, 'reg_lambda': 0.04821614137651858, 'max_depth': 3, 'colsample_bytree': 0.8094198053879665, 'subsample': 0.7611583276985988, 'subsample_freq': 7, 'min_child_samples': 8, 'max_bin': 363}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:35,771] Trial 97 finished with value: 65.96100160958636 and parameters: {'num_leaves': 731, 'reg_alpha': 4.064516608538538e-06, 'reg_lambda': 0.048895487951180996, 'max_depth': 3, 'colsample_bytree': 0.8060563549031553, 'subsample': 0.6786204831544449, 'subsample_freq': 7, 'min_child_samples': 9, 'max_bin': 430}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:36,276] Trial 98 finished with value: 71.81391482713433 and parameters: {'num_leaves': 623, 'reg_alpha': 2.6612523123400745e-06, 'reg_lambda': 0.05571211530438863, 'max_depth': 1, 'colsample_bytree': 0.8447242329995619, 'subsample': 0.76837509800045, 'subsample_freq': 7, 'min_child_samples': 14, 'max_bin': 391}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:37,421] Trial 99 finished with value: 68.55722553492906 and parameters: {'num_leaves': 1737, 'reg_alpha': 5.77635416689571e-06, 'reg_lambda': 0.06373185089851197, 'max_depth': 10, 'colsample_bytree': 0.7813271411790793, 'subsample': 0.7543003685552583, 'subsample_freq': 5, 'min_child_samples': 11, 'max_bin': 359}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:38,148] Trial 100 finished with value: 66.6638303896675 and parameters: {'num_leaves': 1322, 'reg_alpha': 3.7560289151116814e-06, 'reg_lambda': 0.050330541889311436, 'max_depth': 6, 'colsample_bytree': 0.8283923653634006, 'subsample': 0.7062189395918078, 'subsample_freq': 7, 'min_child_samples': 7, 'max_bin': 406}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:38,658] Trial 101 finished with value: 65.47145739847802 and parameters: {'num_leaves': 2265, 'reg_alpha': 5.257312915939939e-06, 'reg_lambda': 0.04421553845839521, 'max_depth': 4, 'colsample_bytree': 0.7480654418569578, 'subsample': 0.7315845577292932, 'subsample_freq': 6, 'min_child_samples': 7, 'max_bin': 367}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:39,058] Trial 102 finished with value: 65.47553770878723 and parameters: {'num_leaves': 2242, 'reg_alpha': 4.271206314593194e-06, 'reg_lambda': 0.04719992731264496, 'max_depth': 3, 'colsample_bytree': 0.7526155207473451, 'subsample': 0.7355642549585623, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 413}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:39,692] Trial 103 finished with value: 66.14976552865923 and parameters: {'num_leaves': 1363, 'reg_alpha': 6.814626436841783e-06, 'reg_lambda': 0.03725286088043741, 'max_depth': 5, 'colsample_bytree': 0.7486020403414033, 'subsample': 0.7291463196046122, 'subsample_freq': 6, 'min_child_samples': 9, 'max_bin': 413}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:40,223] Trial 104 finished with value: 66.65912161380146 and parameters: {'num_leaves': 1833, 'reg_alpha': 9.212517842085455e-06, 'reg_lambda': 0.04005594843134275, 'max_depth': 4, 'colsample_bytree': 0.7228857764371199, 'subsample': 0.6816730237570595, 'subsample_freq': 6, 'min_child_samples': 14, 'max_bin': 419}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:40,620] Trial 105 finished with value: 66.28690562984002 and parameters: {'num_leaves': 3958, 'reg_alpha': 3.3556590218585736e-06, 'reg_lambda': 0.04451298326894349, 'max_depth': 2, 'colsample_bytree': 0.8068966759443403, 'subsample': 0.7477700114093727, 'subsample_freq': 5, 'min_child_samples': 7, 'max_bin': 201}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:41,074] Trial 106 finished with value: 66.22620447422307 and parameters: {'num_leaves': 1484, 'reg_alpha': 4.333466026000435e-06, 'reg_lambda': 0.04667993389806077, 'max_depth': 3, 'colsample_bytree': 0.7390212156311243, 'subsample': 0.7645758352422292, 'subsample_freq': 6, 'min_child_samples': 12, 'max_bin': 368}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:41,594] Trial 107 finished with value: 65.9742814321781 and parameters: {'num_leaves': 2285, 'reg_alpha': 5.876948790502596e-06, 'reg_lambda': 0.044079644033952654, 'max_depth': 4, 'colsample_bytree': 0.7783563334214173, 'subsample': 0.6383569734731793, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 382}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:42,019] Trial 108 finished with value: 66.09459001602747 and parameters: {'num_leaves': 1093, 'reg_alpha': 2.429934740898169e-06, 'reg_lambda': 0.06654330271196103, 'max_depth': 3, 'colsample_bytree': 0.7547464543753225, 'subsample': 0.7219541517463288, 'subsample_freq': 5, 'min_child_samples': 10, 'max_bin': 358}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:42,502] Trial 109 finished with value: 66.11987022027128 and parameters: {'num_leaves': 673, 'reg_alpha': 5.116130243649365e-06, 'reg_lambda': 0.05480492969960422, 'max_depth': 2, 'colsample_bytree': 0.7962584974550766, 'subsample': 0.6987877363141445, 'subsample_freq': 6, 'min_child_samples': 8, 'max_bin': 436}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:43,110] Trial 110 finished with value: 67.47021807247646 and parameters: {'num_leaves': 2804, 'reg_alpha': 7.564897775206313e-06, 'reg_lambda': 0.050482406019035524, 'max_depth': 5, 'colsample_bytree': 0.7192465687976439, 'subsample': 0.8261305758492851, 'subsample_freq': 7, 'min_child_samples': 16, 'max_bin': 401}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:43,673] Trial 111 finished with value: 65.41681141524685 and parameters: {'num_leaves': 2228, 'reg_alpha': 3.496261487269363e-06, 'reg_lambda': 0.05832465645495007, 'max_depth': 3, 'colsample_bytree': 0.7569649608640364, 'subsample': 0.7813180931857242, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 424}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:44,210] Trial 112 finished with value: 65.4438703449906 and parameters: {'num_leaves': 2221, 'reg_alpha': 4.0325887427994265e-06, 'reg_lambda': 0.05782466560645202, 'max_depth': 4, 'colsample_bytree': 0.7616868493667326, 'subsample': 0.7800264106056092, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 424}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:44,674] Trial 113 finished with value: 65.43389542416364 and parameters: {'num_leaves': 2253, 'reg_alpha': 3.564961146577441e-06, 'reg_lambda': 0.06076180141417766, 'max_depth': 3, 'colsample_bytree': 0.7570003931920096, 'subsample': 0.7817839374643096, 'subsample_freq': 7, 'min_child_samples': 6, 'max_bin': 412}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:45,198] Trial 114 finished with value: 65.7234574247221 and parameters: {'num_leaves': 2233, 'reg_alpha': 3.781704670095546e-06, 'reg_lambda': 0.06168604404287154, 'max_depth': 3, 'colsample_bytree': 0.7500743787268596, 'subsample': 0.777325350640827, 'subsample_freq': 7, 'min_child_samples': 10, 'max_bin': 409}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:45,684] Trial 115 finished with value: 69.74970282672037 and parameters: {'num_leaves': 3056, 'reg_alpha': 4.280375226592276e-06, 'reg_lambda': 0.0470750533579688, 'max_depth': 2, 'colsample_bytree': 0.758533477199198, 'subsample': 0.7892988353979309, 'subsample_freq': 6, 'min_child_samples': 57, 'max_bin': 433}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:46,214] Trial 116 finished with value: 65.30379477025538 and parameters: {'num_leaves': 2305, 'reg_alpha': 2.3134887679449224e-06, 'reg_lambda': 0.054262593363533326, 'max_depth': 4, 'colsample_bytree': 0.6981132477260258, 'subsample': 0.7648368600971965, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 413}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:46,697] Trial 117 finished with value: 65.73345796642914 and parameters: {'num_leaves': 2570, 'reg_alpha': 2.2817499960218524e-06, 'reg_lambda': 0.05385986693438548, 'max_depth': 4, 'colsample_bytree': 0.7800512202262571, 'subsample': 0.7370243477358418, 'subsample_freq': 7, 'min_child_samples': 13, 'max_bin': 422}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:47,281] Trial 118 finished with value: 65.69488338726417 and parameters: {'num_leaves': 1866, 'reg_alpha': 2.8606579161205987e-06, 'reg_lambda': 0.05814595744840755, 'max_depth': 4, 'colsample_bytree': 0.6978265990154122, 'subsample': 0.8470965851962603, 'subsample_freq': 7, 'min_child_samples': 6, 'max_bin': 452}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:47,949] Trial 119 finished with value: 66.21303666767146 and parameters: {'num_leaves': 2292, 'reg_alpha': 1.0391278183546214e-06, 'reg_lambda': 0.051690113152735515, 'max_depth': 5, 'colsample_bytree': 0.7431675113847953, 'subsample': 0.7658147239408566, 'subsample_freq': 7, 'min_child_samples': 9, 'max_bin': 412}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:48,487] Trial 120 finished with value: 68.2542626216714 and parameters: {'num_leaves': 3235, 'reg_alpha': 3.4395434746030136e-06, 'reg_lambda': 0.048204070820756575, 'max_depth': 6, 'colsample_bytree': 0.773540416680397, 'subsample': 0.8050351609525179, 'subsample_freq': 8, 'min_child_samples': 15, 'max_bin': 430}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:48,971] Trial 121 finished with value: 66.04170635425083 and parameters: {'num_leaves': 1944, 'reg_alpha': 4.5814260207868435e-06, 'reg_lambda': 0.060606687814489184, 'max_depth': 2, 'colsample_bytree': 0.7059415106281297, 'subsample': 0.7810348108370793, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 416}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:49,424] Trial 122 finished with value: 65.02955732363573 and parameters: {'num_leaves': 2966, 'reg_alpha': 3.916398505641239e-06, 'reg_lambda': 0.055793594265285844, 'max_depth': 3, 'colsample_bytree': 0.7247568807179796, 'subsample': 0.756460228565517, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 403}. Best is trial 96 with value: 65.02830703557942.
# [I 2021-07-22 18:12:49,823] Trial 123 finished with value: 65.48279025802023 and parameters: {'num_leaves': 2932, 'reg_alpha': 3.887564897693617e-06, 'reg_lambda': 0.05448404884766676, 'max_depth': 3, 'colsample_bytree': 0.7243424715589174, 'subsample': 0.7546904870013201, 'subsample_freq': 7, 'min_child_samples': 7, 'max_bin': 399}. Best is trial 96 with value: 65.02830703557942.
# ...
# [I 2021-07-22 18:20:26,093] Trial 960 finished with value: 66.1771281471311 and parameters: {'num_leaves': 3187, 'reg_alpha': 1.7135905868348437e-05, 'reg_lambda': 0.019870731606316867, 'max_depth': 2, 'colsample_bytree': 0.705353309643572, 'subsample': 0.7805738149404514, 'subsample_freq': 6, 'min_child_samples': 7, 'max_bin': 370}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:26,581] Trial 961 finished with value: 65.6376723057743 and parameters: {'num_leaves': 2725, 'reg_alpha': 1.1259087972415695e-06, 'reg_lambda': 0.07221951338120784, 'max_depth': 3, 'colsample_bytree': 0.9471598302228673, 'subsample': 0.7517355818206871, 'subsample_freq': 6, 'min_child_samples': 9, 'max_bin': 393}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:27,098] Trial 962 finished with value: 65.8014843290558 and parameters: {'num_leaves': 3742, 'reg_alpha': 2.0223253643450603e-06, 'reg_lambda': 0.03064595894075793, 'max_depth': 4, 'colsample_bytree': 0.7260826093949239, 'subsample': 0.7338081277090185, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 385}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:27,564] Trial 963 finished with value: 65.72592597253102 and parameters: {'num_leaves': 2237, 'reg_alpha': 3.580077161798135e-08, 'reg_lambda': 0.012490711719773326, 'max_depth': 3, 'colsample_bytree': 0.9298184475367881, 'subsample': 0.8046840725060687, 'subsample_freq': 6, 'min_child_samples': 14, 'max_bin': 471}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:28,140] Trial 964 finished with value: 66.21990116377339 and parameters: {'num_leaves': 2976, 'reg_alpha': 1.5397061073854649e-06, 'reg_lambda': 0.010191430473003416, 'max_depth': 2, 'colsample_bytree': 0.9328139663714444, 'subsample': 0.7652785125687072, 'subsample_freq': 6, 'min_child_samples': 7, 'max_bin': 452}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:28,627] Trial 965 finished with value: 66.19336561598506 and parameters: {'num_leaves': 3443, 'reg_alpha': 6.320173163004752e-07, 'reg_lambda': 0.06703369125546482, 'max_depth': 3, 'colsample_bytree': 0.6864374630960819, 'subsample': 0.7850272903546373, 'subsample_freq': 6, 'min_child_samples': 11, 'max_bin': 398}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:29,193] Trial 966 finished with value: 66.5280182212843 and parameters: {'num_leaves': 3138, 'reg_alpha': 2.599207877800063e-06, 'reg_lambda': 0.08823655410478363, 'max_depth': 4, 'colsample_bytree': 0.9885344839040087, 'subsample': 0.7455584892217425, 'subsample_freq': 6, 'min_child_samples': 9, 'max_bin': 380}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:29,885] Trial 967 finished with value: 67.06919351079807 and parameters: {'num_leaves': 2796, 'reg_alpha': 1.0878976559907108e-06, 'reg_lambda': 0.012988964047986419, 'max_depth': 5, 'colsample_bytree': 0.9683660890983437, 'subsample': 0.71363791596075, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 461}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:30,378] Trial 968 finished with value: 65.11427347689586 and parameters: {'num_leaves': 2516, 'reg_alpha': 3.3269879860647344e-06, 'reg_lambda': 0.06075830112037239, 'max_depth': 3, 'colsample_bytree': 0.9366785602057535, 'subsample': 0.773412437563623, 'subsample_freq': 6, 'min_child_samples': 7, 'max_bin': 391}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:30,950] Trial 969 finished with value: 65.07148549534314 and parameters: {'num_leaves': 3296, 'reg_alpha': 1.9900926710728745e-06, 'reg_lambda': 0.058374650622026986, 'max_depth': 3, 'colsample_bytree': 0.9217992894267175, 'subsample': 0.75678086406066, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 406}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:31,513] Trial 970 finished with value: 66.51533000218771 and parameters: {'num_leaves': 2873, 'reg_alpha': 6.158135888501538e-07, 'reg_lambda': 0.01556697558906285, 'max_depth': 4, 'colsample_bytree': 0.9531672699651873, 'subsample': 0.7956570028316637, 'subsample_freq': 6, 'min_child_samples': 8, 'max_bin': 369}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:32,056] Trial 971 finished with value: 68.69500753467359 and parameters: {'num_leaves': 1885, 'reg_alpha': 2.4134022131416154e-06, 'reg_lambda': 0.07053771063151802, 'max_depth': 2, 'colsample_bytree': 0.6766468625095219, 'subsample': 0.7328325189450671, 'subsample_freq': 6, 'min_child_samples': 37, 'max_bin': 477}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:32,630] Trial 972 finished with value: 66.9972418839441 and parameters: {'num_leaves': 2341, 'reg_alpha': 1.578931146225203e-08, 'reg_lambda': 0.06333716797302878, 'max_depth': 4, 'colsample_bytree': 0.9383100793924213, 'subsample': 0.8192445645179053, 'subsample_freq': 6, 'min_child_samples': 12, 'max_bin': 398}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:33,216] Trial 973 finished with value: 65.37126652187501 and parameters: {'num_leaves': 3584, 'reg_alpha': 1.544517579716308e-06, 'reg_lambda': 0.06208415867509645, 'max_depth': 3, 'colsample_bytree': 0.6980766829785049, 'subsample': 0.7693432545487296, 'subsample_freq': 6, 'min_child_samples': 10, 'max_bin': 376}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:33,681] Trial 974 finished with value: 65.10926463822649 and parameters: {'num_leaves': 3066, 'reg_alpha': 3.14691137865384e-06, 'reg_lambda': 0.0682566311084053, 'max_depth': 3, 'colsample_bytree': 0.9999444293088244, 'subsample': 0.7810398525041988, 'subsample_freq': 6, 'min_child_samples': 6, 'max_bin': 484}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:34,186] Trial 975 finished with value: 66.36933128373119 and parameters: {'num_leaves': 2677, 'reg_alpha': 1.7133690963813773e-06, 'reg_lambda': 0.06557216557508447, 'max_depth': 2, 'colsample_bytree': 0.9610593026470257, 'subsample': 0.5110662413566769, 'subsample_freq': 6, 'min_child_samples': 8, 'max_bin': 386}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:34,760] Trial 976 finished with value: 65.55882373201862 and parameters: {'num_leaves': 3246, 'reg_alpha': 1.0008442894022664e-06, 'reg_lambda': 0.029848543078904922, 'max_depth': 3, 'colsample_bytree': 0.9210053593758667, 'subsample': 0.7517840466770711, 'subsample_freq': 4, 'min_child_samples': 5, 'max_bin': 466}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:35,351] Trial 977 finished with value: 65.62835356534829 and parameters: {'num_leaves': 2912, 'reg_alpha': 1.2713357522684992e-05, 'reg_lambda': 0.06457018922605148, 'max_depth': 4, 'colsample_bytree': 0.903409030493802, 'subsample': 0.6985098680097039, 'subsample_freq': 6, 'min_child_samples': 10, 'max_bin': 449}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:35,849] Trial 978 finished with value: 65.22782404855283 and parameters: {'num_leaves': 2183, 'reg_alpha': 2.7704514593272183e-06, 'reg_lambda': 0.05805306225315924, 'max_depth': 3, 'colsample_bytree': 0.9488832333691777, 'subsample': 0.795657089187786, 'subsample_freq': 6, 'min_child_samples': 7, 'max_bin': 404}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:36,362] Trial 979 finished with value: 65.22381778993943 and parameters: {'num_leaves': 2495, 'reg_alpha': 2.0617120204229694e-06, 'reg_lambda': 0.061055455968643375, 'max_depth': 3, 'colsample_bytree': 0.9256916149353629, 'subsample': 0.7633610744165767, 'subsample_freq': 6, 'min_child_samples': 9, 'max_bin': 378}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:36,965] Trial 980 finished with value: 65.592366383785 and parameters: {'num_leaves': 3474, 'reg_alpha': 4.652279287944537e-07, 'reg_lambda': 0.06272501799876617, 'max_depth': 2, 'colsample_bytree': 0.6388799677625636, 'subsample': 0.7248294901383023, 'subsample_freq': 5, 'min_child_samples': 5, 'max_bin': 390}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:37,534] Trial 981 finished with value: 66.69400087252902 and parameters: {'num_leaves': 3857, 'reg_alpha': 9.159167712303875e-07, 'reg_lambda': 0.06639381984681761, 'max_depth': 3, 'colsample_bytree': 0.9388128167767885, 'subsample': 0.6629906784735905, 'subsample_freq': 6, 'min_child_samples': 12, 'max_bin': 395}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:38,136] Trial 982 finished with value: 65.87876274233311 and parameters: {'num_leaves': 3069, 'reg_alpha': 1.4770347253228975e-06, 'reg_lambda': 0.058959401246694805, 'max_depth': 4, 'colsample_bytree': 0.6141073545364162, 'subsample': 0.8089627342764921, 'subsample_freq': 6, 'min_child_samples': 7, 'max_bin': 454}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:38,702] Trial 983 finished with value: 65.50256105229846 and parameters: {'num_leaves': 2673, 'reg_alpha': 2.45881696603941e-06, 'reg_lambda': 0.06932580007000098, 'max_depth': 3, 'colsample_bytree': 0.977792809551602, 'subsample': 0.7428044507170172, 'subsample_freq': 7, 'min_child_samples': 9, 'max_bin': 381}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:39,861] Trial 984 finished with value: 68.90479420980084 and parameters: {'num_leaves': 1978, 'reg_alpha': 3.36211128065869e-06, 'reg_lambda': 0.01135444473893183, 'max_depth': 11, 'colsample_bytree': 0.9130620446217452, 'subsample': 0.7848581514026356, 'subsample_freq': 6, 'min_child_samples': 15, 'max_bin': 460}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:40,356] Trial 985 finished with value: 66.22052569539325 and parameters: {'num_leaves': 2804, 'reg_alpha': 4.624506433854714e-07, 'reg_lambda': 0.06359168263894736, 'max_depth': 2, 'colsample_bytree': 0.9709228997427136, 'subsample': 0.7617927235694583, 'subsample_freq': 5, 'min_child_samples': 5, 'max_bin': 409}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:40,931] Trial 986 finished with value: 66.81033105983141 and parameters: {'num_leaves': 3293, 'reg_alpha': 1.4597563658429003e-06, 'reg_lambda': 0.04199895659146719, 'max_depth': 4, 'colsample_bytree': 0.9570917808647723, 'subsample': 0.7776827131280016, 'subsample_freq': 4, 'min_child_samples': 7, 'max_bin': 444}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:41,397] Trial 987 finished with value: 66.46291285962417 and parameters: {'num_leaves': 2404, 'reg_alpha': 2.1462957513470286e-06, 'reg_lambda': 0.060202594766103984, 'max_depth': 3, 'colsample_bytree': 0.7145823348346784, 'subsample': 0.7490532119629835, 'subsample_freq': 3, 'min_child_samples': 11, 'max_bin': 371}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:41,903] Trial 988 finished with value: 66.09994790838826 and parameters: {'num_leaves': 3043, 'reg_alpha': 1.1148428762619094e-06, 'reg_lambda': 0.033076851775670144, 'max_depth': 2, 'colsample_bytree': 0.6830058901014571, 'subsample': 0.8273956292811406, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 494}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:42,362] Trial 989 finished with value: 65.47028626733422 and parameters: {'num_leaves': 3526, 'reg_alpha': 2.5773266335182442e-06, 'reg_lambda': 0.05756030751975725, 'max_depth': 3, 'colsample_bytree': 0.8928953618439414, 'subsample': 0.734154289157009, 'subsample_freq': 7, 'min_child_samples': 8, 'max_bin': 383}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:42,873] Trial 990 finished with value: 65.27442449225032 and parameters: {'num_leaves': 2578, 'reg_alpha': 3.2138551742565066e-06, 'reg_lambda': 0.014185730743306443, 'max_depth': 3, 'colsample_bytree': 0.9314706610422575, 'subsample': 0.7973543266878929, 'subsample_freq': 5, 'min_child_samples': 10, 'max_bin': 401}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:43,408] Trial 991 finished with value: 65.97823874864999 and parameters: {'num_leaves': 2171, 'reg_alpha': 1.8349849917753258e-06, 'reg_lambda': 0.06767289052002651, 'max_depth': 4, 'colsample_bytree': 0.6250559169085612, 'subsample': 0.7703403264157045, 'subsample_freq': 6, 'min_child_samples': 6, 'max_bin': 467}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:43,864] Trial 992 finished with value: 65.9405009597353 and parameters: {'num_leaves': 2898, 'reg_alpha': 1.5791000343863916e-08, 'reg_lambda': 0.06547980073083988, 'max_depth': 3, 'colsample_bytree': 0.6694321617531177, 'subsample': 0.717696871920801, 'subsample_freq': 6, 'min_child_samples': 13, 'max_bin': 390}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:44,362] Trial 993 finished with value: 66.56073525940877 and parameters: {'num_leaves': 3166, 'reg_alpha': 1.0706208434710391e-06, 'reg_lambda': 0.0007014640389372551, 'max_depth': 2, 'colsample_bytree': 0.948730818589145, 'subsample': 0.7601862642842979, 'subsample_freq': 7, 'min_child_samples': 8, 'max_bin': 412}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:44,915] Trial 994 finished with value: 66.55076544060856 and parameters: {'num_leaves': 2772, 'reg_alpha': 5.377533334222921e-07, 'reg_lambda': 0.07055623010256015, 'max_depth': 4, 'colsample_bytree': 0.9995083465885581, 'subsample': 0.8108082031577516, 'subsample_freq': 6, 'min_child_samples': 5, 'max_bin': 335}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:45,544] Trial 995 finished with value: 70.34831627383367 and parameters: {'num_leaves': 3291, 'reg_alpha': 2.8712314741242108e-06, 'reg_lambda': 0.043209339869511684, 'max_depth': 1, 'colsample_bytree': 0.9138297202181432, 'subsample': 0.7863450716898887, 'subsample_freq': 6, 'min_child_samples': 10, 'max_bin': 375}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:46,118] Trial 996 finished with value: 66.97109281243692 and parameters: {'num_leaves': 2345, 'reg_alpha': 1.998354326444576e-06, 'reg_lambda': 0.040816604978719, 'max_depth': 5, 'colsample_bytree': 0.9251213596636892, 'subsample': 0.7463271287414586, 'subsample_freq': 5, 'min_child_samples': 7, 'max_bin': 438}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:46,623] Trial 997 finished with value: 65.36686477558402 and parameters: {'num_leaves': 3611, 'reg_alpha': 1.2331983374675526e-06, 'reg_lambda': 0.06156325666221866, 'max_depth': 3, 'colsample_bytree': 0.9419935245138178, 'subsample': 0.7763667853385604, 'subsample_freq': 7, 'min_child_samples': 5, 'max_bin': 395}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:47,240] Trial 998 finished with value: 67.94484021334199 and parameters: {'num_leaves': 3011, 'reg_alpha': 5.018388806575703e-08, 'reg_lambda': 0.06414623805829385, 'max_depth': 3, 'colsample_bytree': 0.6973717162897516, 'subsample': 0.757376297364427, 'subsample_freq': 6, 'min_child_samples': 33, 'max_bin': 386}. Best is trial 893 with value: 64.61062461910419.
# [I 2021-07-22 18:20:47,701] Trial 999 finished with value: 66.76277583230653 and parameters: {'num_leaves': 2694, 'reg_alpha': 2.2458011544663275e-06, 'reg_lambda': 0.044163427195415876, 'max_depth': 2, 'colsample_bytree': 0.8995033801604111, 'subsample': 0.7355692718889977, 'subsample_freq': 7, 'min_child_samples': 9, 'max_bin': 453}. Best is trial 893 with value: 64.61062461910419.
# Best Score: 64.61062461910419
# Best trial: {'num_leaves': 2529, 'reg_alpha': 9.79323400107571e-07, 'reg_lambda': 0.02376241865987097, 'max_depth': 3, 'colsample_bytree': 0.9472292023261144, 'subsample': 0.7757757038057456, 'subsample_freq': 6, 'min_child_samples': 8, 'max_bin': 427}

# %%
lunch_param
# Out:
# {'num_leaves': 2529,
#  'reg_alpha': 9.79323400107571e-07,
#  'reg_lambda': 0.02376241865987097,
#  'max_depth': 3,
#  'colsample_bytree': 0.9472292023261144,
#  'subsample': 0.7757757038057456,
#  'subsample_freq': 6,
#  'min_child_samples': 8,
#  'max_bin': 427}

# %%
X_train, X_valid, y_train, y_valid = train_test_split(lunch_train, y_lunch, test_size=0.2)

lunch_model = LGBMRegressor(**lunch_param)
lunch_model.fit(
            X_train,
            y_train,
            eval_set=[(X_train, y_train), (X_valid, y_valid)],
            early_stopping_rounds=100,
            verbose=False,
        )
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.7041252632987905, importance_type='split',
#        learning_rate=0.1, max_bin=437, max_depth=12, min_child_samples=24,
#        min_child_weight=0.001, min_split_gain=0.0, n_estimators=100,
#        n_jobs=-1, num_leaves=7, objective=None, random_state=None,
#        reg_alpha=1.622564509910422e-05, reg_lambda=0.0727906280606794,
#        silent=True, subsample=0.9930902085857553, subsample_for_bin=200000,
#        subsample_freq=5)

# %%
lunch_predict = lunch_model.predict(lunch_test)
lunch_predict
# Out:
# array([1014.9777623 ,  909.47280049,  620.73854459, 1275.52885314,
#        1120.1193701 , 1127.0910706 ,  986.24555525,  708.89722304,
#        1283.51582216, 1122.94235589,  796.14195167, 1245.84667052,
#        1162.00161252, 1141.89353195,  993.62469507,  752.00117324,
#        1275.99392291, 1094.0339315 ,  927.92435468,  868.64589183,
#         586.10241297, 1189.69317269, 1063.32115747,  961.21331004,
#         642.78917573, 1277.47589973, 1129.91660887, 1066.60266004,
#         965.59432887,  717.72467543, 1272.38249029, 1040.64620536,
#        1042.94201421,  940.76896329,  685.8227375 , 1234.42374383,
#        1020.99966125,  906.05714052,  852.16730766,  596.73486267,
#        1213.45282297, 1059.7517666 ,  952.15550966,  839.7069533 ,
#         606.02660743, 1229.69615668, 1032.93963096,  955.71522891,
#         867.748619  ,  595.39489614])

# %%
def objective_dinner(trial: Trial) -> float:
    params_lgb = {
        "random_state": 42,
        "verbosity": -1,
        "learning_rate": 0.05,
        "n_estimators": 10000,
        "metric": "mae",
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 3e-5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 9e-2),
        "max_depth": trial.suggest_int("max_depth", 1, 20),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
        "subsample": trial.suggest_float("subsample", 0.3, 1.0),
        "subsample_freq": trial.suggest_int("subsample_freq", 1, 10),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "max_bin": trial.suggest_int("max_bin", 200, 500),
    }
    
    X_train, X_valid, y_train, y_valid = train_test_split(dinner_train, y_dinner, test_size=0.2)

    model = LGBMRegressor(**params_lgb)
    model.fit(
        X_train,
        y_train,
        eval_set=[(X_train, y_train), (X_valid, y_valid)],
        early_stopping_rounds=100,
        verbose=False,
    
    )

    lgb_pred = model.predict(X_valid)
    log_score = MAE(y_valid, lgb_pred)
    
    return log_score

# %%
sampler = TPESampler(seed=42)
study = optuna.create_study(
    study_name="lgbm_parameter_opt",
    direction="minimize",
    sampler=sampler,
)
study.optimize(objective_dinner, n_trials=1000)
dinner_param = study.best_trial.params

print("Best Score:", study.best_value)
print("Best trial:", study.best_trial.params)
# Out:
# Best Score: 45.37486993081729
# Best trial: {'reg_alpha': 1.718625207505066e-06, 'reg_lambda': 0.03536226882919215, 'max_depth': 13, 'num_leaves': 149, 'colsample_bytree': 0.7238257801656021, 'subsample': 0.9792806922458114, 'subsample_freq': 3, 'min_child_samples': 26, 'max_bin': 423}

# %%
X_train, X_valid, y_train, y_valid = train_test_split(dinner_train, y_dinner, test_size=0.2)

dinner_model = LGBMRegressor(**dinner_param)
dinner_model.fit(
            X_train,
            y_train,
            eval_set=[(X_train, y_train), (X_valid, y_valid)],
            early_stopping_rounds=100,
            verbose=False,
        )
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.7238257801656021, importance_type='split',
#        learning_rate=0.1, max_bin=423, max_depth=13, min_child_samples=26,
#        min_child_weight=0.001, min_split_gain=0.0, n_estimators=100,
#        n_jobs=-1, num_leaves=149, objective=None, random_state=None,
#        reg_alpha=1.718625207505066e-06, reg_lambda=0.03536226882919215,
#        silent=True, subsample=0.9792806922458114, subsample_for_bin=200000,
#        subsample_freq=3)

# %%
dinner_predict = dinner_model.predict(dinner_test)

# %%
submission = pd.read_csv('../data/sample_submission.csv')

submission.iloc[:,1] = lunch_predict
submission.iloc[:,2] = dinner_predict
submission.head()
# Out:
#            일자          중식계         석식계
# 0  2021-01-27  1014.977762  296.478621
# 1  2021-01-28   909.472800  416.123827
# 2  2021-01-29   620.738545  201.016733
# 3  2021-02-01  1275.528853  525.256840
# 4  2021-02-02  1120.119370  445.076138

# %%
lunch_predict
# Out:
# array([1014.9777623 ,  909.47280049,  620.73854459, 1275.52885314,
#        1120.1193701 , 1127.0910706 ,  986.24555525,  708.89722304,
#        1283.51582216, 1122.94235589,  796.14195167, 1245.84667052,
#        1162.00161252, 1141.89353195,  993.62469507,  752.00117324,
#        1275.99392291, 1094.0339315 ,  927.92435468,  868.64589183,
#         586.10241297, 1189.69317269, 1063.32115747,  961.21331004,
#         642.78917573, 1277.47589973, 1129.91660887, 1066.60266004,
#         965.59432887,  717.72467543, 1272.38249029, 1040.64620536,
#        1042.94201421,  940.76896329,  685.8227375 , 1234.42374383,
#        1020.99966125,  906.05714052,  852.16730766,  596.73486267,
#        1213.45282297, 1059.7517666 ,  952.15550966,  839.7069533 ,
#         606.02660743, 1229.69615668, 1032.93963096,  955.71522891,
#         867.748619  ,  595.39489614])

# %%
dinner_predict
# Out:
# array([296.47862072, 416.12382735, 201.01673302, 525.25684037,
#        445.07613808, 454.38717012, 419.8108143 , 353.44868964,
#        579.06900678, 504.16429542, 184.08296321, 670.10346759,
#        647.10410889, 370.81873435, 509.4142024 , 326.52502148,
#        671.21435543, 638.30608955, 362.45119747, 478.98080058,
#        267.86752703, 663.85305892, 440.18516041, 558.12546149,
#        374.58626533, 663.63897089, 631.93843878, 448.83570953,
#        585.18365146, 382.90783689, 729.8199353 , 577.95381799,
#        462.66135267, 508.80176125, 327.5116415 , 666.07311912,
#        608.39330405, 481.98506112, 468.49717427, 283.74313986,
#        699.59300679, 646.5709927 , 380.95390632, 416.58471339,
#        256.26716153, 626.59308347, 564.35689677, 418.94402019,
#        466.34231482, 249.13917059])

# %%
def compare_ans(DIR):
    answer = pd.read_csv(DIR)

    lunch_answer = np.array(answer.iloc[:,1])
    dinner_answer = np.array(answer.iloc[:,2])
    
    lunch_MAE = abs(submission.iloc[:,1] - lunch_answer).mean()
    dinner_MAE = abs(submission.iloc[:,2] - dinner_answer).mean()
    
    print("lunch_MAE : ", lunch_MAE)
    print("dinner_MAE : ", dinner_MAE)
    print("total_MAE : ", (lunch_MAE+dinner_MAE)/2)
    
    
compare_ans('../submission/20210701_lgbm_knfold_drop.csv')
compare_ans('../submission/20210715_pycaret_(2).csv')
compare_ans('../submission/20210719_best_data_ensemble.csv')
compare_ans('../submission/20210719_pycaret.csv')
# Out:
# lunch_MAE :  27.932682612863115
# dinner_MAE :  25.158157576966723
# total_MAE :  26.545420094914917
# lunch_MAE :  57.73127840756888
# dinner_MAE :  41.33405452565974
# total_MAE :  49.53266646661431
# lunch_MAE :  52.07852964790631
# dinner_MAE :  29.854066446514597
# total_MAE :  40.96629804721045
# lunch_MAE :  35.70944396511145
# dinner_MAE :  29.854066446514597
# total_MAE :  32.78175520581302

# %%
import glob

files = glob.glob('../submission/*')

for file in files[:-1]:
    print(file, compare_ans(file), end="\n\n" )
# Out:
# lunch_MAE :  28.054411287262766
# dinner_MAE :  33.613523594133746
# total_MAE :  30.833967440698256
# ../submission\20210624_pycaret_(4-2)_제출해봐야할거.csv None
#
# lunch_MAE :  55.113359637347266
# dinner_MAE :  37.351950671878306
# total_MAE :  46.232655154612786
# ../submission\20210625_cat.csv None
#
# lunch_MAE :  50.24057511286847
# dinner_MAE :  39.66195212739441
# total_MAE :  44.95126362013144
# ../submission\20210625_cat_10fold.csv None
#
# lunch_MAE :  51.229281587926096
# dinner_MAE :  38.820982925102236
# total_MAE :  45.02513225651417
# ../submission\20210627_cat_15_KJH.csv None
#
# lunch_MAE :  67.26376485036631
# dinner_MAE :  59.41562966586005
# total_MAE :  63.33969725811318
# ../submission\20210627_cat_after_2020.csv None
#
# lunch_MAE :  51.229281587926096
# dinner_MAE :  38.820982925102236
# total_MAE :  45.02513225651417
# ../submission\20210627_cat_KJH.csv None
#
# lunch_MAE :  51.229281587926096
# dinner_MAE :  38.820982925102236
# total_MAE :  45.02513225651417
# ../submission\20210627_pycaret_KJH.csv None
#
# lunch_MAE :  42.26215344850581
# dinner_MAE :  28.462419030081946
# total_MAE :  35.36228623929388
# ../submission\20210627_pycaret_menu.csv None
#
# lunch_MAE :  65.72661755947644
# dinner_MAE :  35.56453353302583
# total_MAE :  50.64557554625114
# ../submission\20210628_cat_15_.csv None
#
# lunch_MAE :  51.54301851140256
# dinner_MAE :  35.12857538900899
# total_MAE :  43.335796950205776
# ../submission\20210628_cat_15_KJH.csv None
#
# lunch_MAE :  36.2193588765493
# dinner_MAE :  35.98869837623468
# total_MAE :  36.104028626391994
# ../submission\20210628_cat_8_.csv None
#
# lunch_MAE :  34.52951575086949
# dinner_MAE :  30.063604194427253
# total_MAE :  32.296559972648375
# ../submission\20210628_cat_xgb_8.csv None
#
# lunch_MAE :  35.84310399186228
# dinner_MAE :  22.515448797247064
# total_MAE :  29.17927639455467
# ../submission\20210628_pycaret_ADD_FEATURE.csv None
#
# lunch_MAE :  32.63425205426974
# dinner_MAE :  26.5509410564256
# total_MAE :  29.59259655534767
# ../submission\20210629_best_data_ensemble.csv None
#
# lunch_MAE :  32.108038917752836
# dinner_MAE :  34.84587481961193
# total_MAE :  33.47695686868238
# ../submission\20210629_lgbm_autoML.csv None
#
# lunch_MAE :  32.63425205426974
# dinner_MAE :  21.3356160666154
# total_MAE :  26.98493406044257
# ../submission\20210630_best_data_ensemble.csv None
#
# lunch_MAE :  36.2193588765493
# dinner_MAE :  33.85586797048613
# total_MAE :  35.03761342351771
# ../submission\20210630_cat_8_.csv None
#
# lunch_MAE :  32.108038917752836
# dinner_MAE :  24.926913384240805
# total_MAE :  28.51747615099682
# ../submission\20210630_lgbm_autoML.csv None
#
# lunch_MAE :  44.14658699373113
# dinner_MAE :  27.428702149026375
# total_MAE :  35.78764457137875
# ../submission\20210701_lgbm_autoML.csv None
#
# lunch_MAE :  27.932682612863115
# dinner_MAE :  25.158157576966723
# total_MAE :  26.545420094914917
# ../submission\20210701_lgbm_knfold_drop.csv None
#
# lunch_MAE :  92.34115434333576
# dinner_MAE :  34.09942068025651
# total_MAE :  63.22028751179613
# ../submission\20210701_pycaret_(2)-69.8998.csv None
#
# lunch_MAE :  31.80174016308675
# dinner_MAE :  35.68321650096112
# total_MAE :  33.742478332023936
# ../submission\20210714_lgbm_autoML_20.csv None
#
# lunch_MAE :  29.628643658214415
# dinner_MAE :  31.173025822635992
# total_MAE :  30.400834740425204
# ../submission\20210714_lgbm_autoML_8.csv None
#
# lunch_MAE :  31.08485488696722
# dinner_MAE :  47.54730081137398
# total_MAE :  39.3160778491706
# ../submission\20210715_cat_autoML.csv None
#
# lunch_MAE :  30.54761503569336
# dinner_MAE :  22.604969609260465
# total_MAE :  26.576292322476913
# ../submission\20210715_lgbm_autoML.csv None
#
# lunch_MAE :  33.48397372040033
# dinner_MAE :  28.15561158239771
# total_MAE :  30.81979265139902
# ../submission\20210715_lgbm_autoML_ensenble.csv None
#
# lunch_MAE :  38.23353084321852
# dinner_MAE :  32.2415065606858
# total_MAE :  35.237518701952155
# ../submission\20210715_lgbm_sort_autoML.csv None
#
# lunch_MAE :  57.73127840756888
# dinner_MAE :  41.33405452565974
# total_MAE :  49.53266646661431
# ../submission\20210715_pycaret_(2).csv None
#
# lunch_MAE :  24.2924778017053
# dinner_MAE :  25.651475599714487
# total_MAE :  24.971976700709895
# ../submission\20210715_xgb_autoML.csv None
#
# lunch_MAE :  33.10038693343153
# dinner_MAE :  42.02098541168337
# total_MAE :  37.56068617255745
# ../submission\20210716_autoML.csv None
#
# lunch_MAE :  39.125385311838784
# dinner_MAE :  31.7656277360958
# total_MAE :  35.445506523967296
# ../submission\20210716_cat_autoML.csv None
#
# lunch_MAE :  29.88321313632449
# dinner_MAE :  23.93304563140855
# total_MAE :  26.90812938386652
# ../submission\20210716_lgbm_autoML.csv None
#
# lunch_MAE :  33.4779404892969
# dinner_MAE :  26.68773709151658
# total_MAE :  30.08283879040674
# ../submission\20210716_lgbm_autoML_ensenble.csv None
#
# lunch_MAE :  28.223977635350803
# dinner_MAE :  26.347785082061716
# total_MAE :  27.28588135870626
# ../submission\20210716_lgbm_autoML_in.csv None
#
# lunch_MAE :  26.5055936123783
# dinner_MAE :  32.95406835152653
# total_MAE :  29.729830981952414
# ../submission\20210716_lgbm_sort_autoML.csv None
#
# lunch_MAE :  48.116589426640914
# dinner_MAE :  29.86455092818277
# total_MAE :  38.99057017741184
# ../submission\20210717_best_data_ensemble.csv None
#
# lunch_MAE :  50.71758457059139
# dinner_MAE :  27.78195164187129
# total_MAE :  39.24976810623134
# ../submission\20210717_best_data_ensemble2.csv None
#
# lunch_MAE :  50.71758457059139
# dinner_MAE :  25.634556030662225
# total_MAE :  38.176070300626805
# ../submission\20210717_best_data_ensemble3.csv None
#
# lunch_MAE :  62.188537303983225
# dinner_MAE :  35.369611091812814
# total_MAE :  48.77907419789802
# ../submission\20210717_pycaret_(2).csv None
#
# lunch_MAE :  32.098294225256026
# dinner_MAE :  41.70267069058711
# total_MAE :  36.90048245792157
# ../submission\20210718_autoML_5.csv None
#
# lunch_MAE :  33.99998125819086
# dinner_MAE :  29.127422204665642
# total_MAE :  31.56370173142825
# ../submission\20210718_pycaret.csv None
#
# lunch_MAE :  63.644629122856514
# dinner_MAE :  41.52090891836312
# total_MAE :  52.58276902060982
# ../submission\20210718_pycaret_(2).csv None
#
# lunch_MAE :  52.07852964790631
# dinner_MAE :  29.854066446514597
# total_MAE :  40.96629804721045
# ../submission\20210719_best_data_ensemble.csv None
#
# lunch_MAE :  44.954770018432434
# dinner_MAE :  23.727243939218237
# total_MAE :  34.341006978825334
# ../submission\20210719_best_data_ensemble3.csv None
#
# lunch_MAE :  34.74825346118482
# dinner_MAE :  26.619029621545025
# total_MAE :  30.68364154136492
# ../submission\20210719_lgbm_autoML.csv None
#
# lunch_MAE :  35.70944396511145
# dinner_MAE :  29.854066446514597
# total_MAE :  32.78175520581302
# ../submission\20210719_pycaret.csv None
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-b403e7003817> in <module>
#       4
#       5 for file in files[:-1]:
# ----> 6     print(file, compare_ans(file), end="\n\n" )
#
# <ipython-input-62-d6e333cd4c05> in compare_ans(DIR)
#       2     answer = pd.read_csv(DIR)
#       3
# ----> 4     lunch_answer = np.array(answer.iloc[:,1])
#       5     dinner_answer = np.array(answer.iloc[:,2])
#       6
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1448     def _getitem_tuple(self, tup: Tuple):
#    1449
# -> 1450         self._has_valid_tuple(tup)
#    1451         with suppress(IndexingError):
#    1452             return self._getitem_lowerdim(tup)
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     721         for i, k in enumerate(key):
#     722             try:
# --> 723                 self._validate_key(k, i)
#     724             except ValueError as err:
#     725                 raise ValueError(
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1356             return
#    1357         elif is_integer(key):
# -> 1358             self._validate_integer(key, axis)
#    1359         elif isinstance(key, tuple):
#    1360             # a tuple should already have been caught by this point
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
import math

math.cos(math.pi*68.44/180)*69.5
# Out:
# 25.539537282882215

# %% [markdown]
# # 저장

# %%
import datetime
today = str(datetime.datetime.now().date()).replace("-","")
print("오늘 날짜 : " + today)

submission.to_csv(f'../submission/{today}_optuna_lgbm.csv', index =False)
# Out:
# 오늘 날짜 : 20210720

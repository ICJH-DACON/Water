# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['font.family'] = 'Gulim'
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
from workalendar.asia import SouthKorea
import pendulum

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# ## 전처리
# - 일자에서 월과 일을 분리
# - 요일을 레이블 인코딩화(EDA로 요일의 중요도 순 파악)
# - 월 별, 일 별 중식 석식 수요 차이 파악

# %%
train['월'] = pd.DatetimeIndex(train['일자']).month
test['월'] = pd.DatetimeIndex(test['일자']).month
train['주'] = pd.DatetimeIndex(train['일자']).week
test['주'] = pd.DatetimeIndex(test['일자']).week
train['일'] = pd.DatetimeIndex(train['일자']).day
test['일'] = pd.DatetimeIndex(test['일자']).day

train['출근'] = train['본사정원수']-(train['본사휴가자수']+train['본사출장자수']+train['현본사소속재택근무자수'])
train['휴가비율'] = train['본사휴가자수']/train['본사정원수']
train['출장비율'] = train['본사출장자수']/train['본사정원수']
train['야근비율'] = train['본사시간외근무명령서승인건수']/train['출근']
train['재택비율'] = train['현본사소속재택근무자수']/train['본사정원수']

test['출근'] = test['본사정원수']-(test['본사휴가자수']+test['본사출장자수']+test['현본사소속재택근무자수'])
test['휴가비율'] = test['본사휴가자수']/test['본사정원수']
test['출장비율'] = test['본사출장자수']/test['본사정원수']
test['야근비율'] = test['본사시간외근무명령서승인건수']/test['출근']
test['재택비율'] = test['현본사소속재택근무자수']/test['본사정원수']

train['식사가능자수'] = train['본사정원수'] - train['본사휴가자수'] - train['현본사소속재택근무자수']
test['식사가능자수'] = test['본사정원수'] - test['본사휴가자수'] - test['현본사소속재택근무자수']

# train['중식참여율'] = train['중식계'] / train['식사가능자수']
# Out:
# <ipython-input-4-b11c832c5082>:3: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   train['주'] = pd.DatetimeIndex(train['일자']).week
# <ipython-input-4-b11c832c5082>:4: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   test['주'] = pd.DatetimeIndex(test['일자']).week

# %%
month_rank4dinner = {
    1: 11,
    2: 2,
    3: 1,
    4: 4,
    5: 7,
    6: 6,
    7: 10,
    8: 8,
    9: 5,
    10: 3,
    11: 9,
    12: 12
}
train['월(석식)'] = train['월'].map(month_rank4dinner)
test['월(석식)'] = test['월'].map(month_rank4dinner)

month_rank4lunch = {
    1: 3,
    2: 1,
    3: 2,
    4: 6,
    5: 7,
    6: 8,
    7: 10,
    8: 9,
    9: 5,
    10: 4,
    11: 11,
    12: 12
}
train['월(중식)'] = train['월'].map(month_rank4lunch)
test['월(중식)'] = test['월'].map(month_rank4lunch)

weekday_rank4dinner = {
    '월': 1,
    '화': 2,
    '수': 4,
    '목': 3,
    '금': 5,
}

weekday_rank4lunch = {
    '월': 1,
    '화': 2,
    '수': 3,
    '목': 4,
    '금': 5,
}

train['요일(석식)'] = train['요일'].map(weekday_rank4dinner)
test['요일(석식)'] = test['요일'].map(weekday_rank4dinner)

train['요일(중식)'] = train['요일'].map(weekday_rank4lunch)
test['요일(중식)'] = test['요일'].map(weekday_rank4lunch)

# %%
rank = pd.DataFrame(range(1,53))
week_rank_lunch = pd.pivot_table(train,values='중식계',index='주').sort_values(by='중식계').reset_index().drop('중식계',axis=1)
week_rank_dinner = pd.pivot_table(train,values='석식계',index='주').sort_values(by='석식계').reset_index().drop('석식계',axis=1)


week_rank4lunch = {}
for i in range(len(rank)):
    week_rank4lunch[week_rank_lunch['주'][i]] = rank[0][i]


week_rank4dinner = {}
for i in range(len(rank)):
    week_rank4dinner[week_rank_dinner['주'][i]] = rank[0][i]
    
    
train['주(중식)'] = train['주'].map(week_rank4lunch)
test['주(중식)'] = test['주'].map(week_rank4lunch)

train['주(석식)'] = train['주'].map(week_rank4dinner)
test['주(석식)'] = test['주'].map(week_rank4dinner)

# %%
def is_holiday(date):
    holidays = list(map(str, pd.Series(np.array(SouthKorea().holidays(int(date[:4])))[:, 0])))
    
    yesterday = str(np.datetime64(date) - 1)
    tomorrow = str(np.datetime64(date) + 1)

    if tomorrow in holidays and yesterday in holidays:
        return 3
    if tomorrow in holidays:
        return 2
    elif yesterday in holidays:
        return 1
    else : 
        return 0

def week_of_month(x):
    dt = pendulum.parse(x)
    
    wom = dt.week_of_month
    if wom < 0:
        wom += 52
    return wom
    

df = pd.concat([train[['본사정원수', '일자']], test[['본사정원수', '일자']]])
df['년월'] = df['일자'].apply(lambda x : x[:7])
df = df[['년월', '본사정원수']].groupby(by=['년월'], as_index=False).mean()

def member_change(date):
    this_month = date[:7]
    last_month = str(np.datetime64(this_month) - 1)
    
    this_month_member = int(df[df['년월'] == this_month]['본사정원수'])
    last_month_member = int(df[df['년월'] == last_month]['본사정원수'])
    
    
    return  this_month_member - last_month_member

train['공휴일전후'] = train['일자'].apply(is_holiday)
test['공휴일전후'] = test['일자'].apply(is_holiday)

train['몇주차'] = train['일자'].apply(week_of_month)
test['몇주차'] = test['일자'].apply(week_of_month)

train = train[train['일자'] > '2016-03']
train['인원변화'] = train['일자'].apply(member_change)
test['인원변화'] = test['일자'].apply(member_change)

# %% [markdown]
# ## 공휴일 변수 생성

# %%
train.columns
# Out:
# Index(['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
#        '현본사소속재택근무자수', '조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계', '월', '주', '일',
#        '출근', '휴가비율', '출장비율', '야근비율', '재택비율', '식사가능자수', '월(석식)', '월(중식)',
#        '요일(석식)', '요일(중식)', '주(중식)', '주(석식)', '공휴일전후', '몇주차', '인원변화'],
#       dtype='object')

# %%
# 메뉴 변수 없이 사용할떄 해당 코드 사용['공휴일전후', '몇주차', '인원변화']

lunch_train = train[['공휴일전후', '몇주차', '인원변화', '요일(중식)','월(중식)','일','주(중식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수',]]
lunch_test = test[['공휴일전후', '몇주차', '인원변화', '요일(중식)','월(중식)','일','주(중식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수']]

dinner_train= train[['공휴일전후', '몇주차', '인원변화', '요일(석식)','월(석식)','일','주(석식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수']]
dinner_test = test[['공휴일전후', '몇주차', '인원변화', '요일(석식)','월(석식)','일','주(석식)','출근', '휴가비율', '출장비율', '야근비율', '재택비율','본사출장자수','본사휴가자수','식사가능자수']]

# %%
lunch_train.columns
# Out:
# Index(['공휴일전후', '몇주차', '인원변화', '요일(중식)', '월(중식)', '일', '주(중식)', '출근', '휴가비율',
#        '출장비율', '야근비율', '재택비율', '본사출장자수', '본사휴가자수', '식사가능자수'],
#       dtype='object')

# %%
print(lunch_train.shape)
print(lunch_test.shape)
# Out:
# (1187, 15)
# (50, 15)

# %%
print(dinner_train.shape)
print(dinner_test.shape)
# Out:
# (1187, 15)
# (50, 15)

# %%
cat_features = [f for f in lunch_train.columns if lunch_train[f].dtype == 'object']

def column_index(df, cat_features):
    cols = df.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols, cat_features, sorter=sidx)]

cat_features_idx = column_index(lunch_train, cat_features)    
print("Cat features are: %s" % [f for f in cat_features])
print(cat_features_idx)
# Out:
# Cat features are: []
# []

# %%
y_lunch = train[['중식계']]
y_dinner = train[['석식계']]

# %%
lunch_train.columns
# Out:
# Index(['공휴일전후', '몇주차', '인원변화', '요일(중식)', '월(중식)', '일', '주(중식)', '출근', '휴가비율',
#        '출장비율', '야근비율', '재택비율', '본사출장자수', '본사휴가자수', '식사가능자수'],
#       dtype='object')

# %% [markdown]
# #### 분포 확인 및 분포 조정

# %% [markdown]
# # 중식 예측모델

# %%
from automl_alex import LightGBMRegressor , AutoMLRegressor
from sklearn.metrics import mean_absolute_error as MAE
from IPython.display import clear_output
import sklearn

# %%
drop_columns = [[],['식사가능자수'], ['본사휴가자수'], ['본사출장자수'], ['인원변화']]
ks = [2,4,6,8,10]

# %%
random_seed = 0
pred_lunch = np.array([0]*50).astype(np.float64)

for dc in drop_columns:
    for k in ks:
        print(dc,random_seed,k)
        
        lunch_model = AutoMLRegressor(random_state=random_seed, metric=MAE)
        
        X_train = lunch_train.drop(columns=dc)
        X_test = lunch_test.drop(columns=dc)
        
        lunch_model.fit(X_train, y_lunch,
                        verbose=3,
                        folds=k,
                        opt_lvl=3,
                        early_stoping=50,
                        auto_parameters=False,
                        timeout=1100,
                       )

        pred_lunch += lunch_model.predict(X_test)

        clear_output(True)
                
        random_seed += 1
# Out:
# 20:18:41 | > Start Fit Base Model
# --- Logging error in Loguru Handler #10212 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7440, microseconds=674371), 'exception': None, 'extra': {}, 'file': (name='automl_alex.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\automl_alex.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 365, 'message': '> Start Fit Base Model', 'module': 'automl_alex', 'name': 'automl_alex.automl_alex', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 41, 126376, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# ['본사휴가자수']
# 20:18:42 | ##################################################
# --- Logging error in Loguru Handler #10212 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7442, microseconds=343012), 'exception': None, 'extra': {}, 'file': (name='automl_alex.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\automl_alex.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 429, 'message': '##################################################', 'module': 'automl_alex', 'name': 'automl_alex.automl_alex', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 42, 795017, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:18:42 | > Start Fit Models 2
# --- Logging error in Loguru Handler #10212 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7442, microseconds=346999), 'exception': None, 'extra': {}, 'file': (name='automl_alex.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\automl_alex.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 430, 'message': '> Start Fit Models 2', 'module': 'automl_alex', 'name': 'automl_alex.automl_alex', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 42, 799004, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:18:42 | ##################################################
# --- Logging error in Loguru Handler #10212 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7442, microseconds=349989), 'exception': None, 'extra': {}, 'file': (name='automl_alex.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\automl_alex.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 431, 'message': '##################################################', 'module': 'automl_alex', 'name': 'automl_alex.automl_alex', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 42, 801994, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:18:42 | ##################################################
# --- Logging error in Loguru Handler #10214 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7442, microseconds=368526), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 557, 'message': '##################################################', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 42, 820531, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# 20:18:43 | > Step 1: calc parameters and pruned score: get test 10 trials
# --- Logging error in Loguru Handler #10216 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7442, microseconds=742785), 'exception': None, 'extra': {}, 'file': (name='optimizer.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\optimizer.py'), 'function': 'opt', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 600, 'message': '> Step 1: calc parameters and pruned score: get test 10 trials', 'module': 'optimizer', 'name': 'automl_alex.optimizer', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 43, 194790, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=457808), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 924, 'message': 'Source data shape: (1187, 14)', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 44, 909813, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=461184), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 925, 'message': '##################################################', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 44, 913189, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=464172), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 926, 'message': '! START preprocessing Data', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 44, 916177, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=473248), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 942, 'message': '- Auto detect cat features: 3', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 44, 925253, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=479262), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 967, 'message': '> Clean Categorical Features', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 44, 931267, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=484247), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 978, 'message': '> Transform Categorical Features.', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 44, 936252, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# C:\anaconda3\envs\machinelearning\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=528983), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1005, 'message': ' - Encoder: HelmertEncoder ADD features: 12', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 44, 980988, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# C:\anaconda3\envs\machinelearning\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=543931), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1005, 'message': ' - Encoder: CountEncoder ADD features: 3', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 44, 995936, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=548970), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1022, 'message': '  No nans features', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 975, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=550955), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1039, 'message': '> CleanOutliers', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 2960, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=555893), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': 'Num of outlier detected: 31 in Feature 식사가능자수', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 7898, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=557931), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 661, 'message': 'Proportion of outlier detected: 2.6 %', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 9936, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=561630), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': 'Num of outlier detected: 84 in Feature 휴가비율', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 13635, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=567855), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 661, 'message': 'Proportion of outlier detected: 7.1 %', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 19860, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=573836), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': 'Num of outlier detected: 61 in Feature 공휴일전후', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 25841, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=576819), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 661, 'message': 'Proportion of outlier detected: 5.1 %', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 28824, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=579836), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': 'Num of outlier detected: 217 in Feature 재택비율', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 31841, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=581817), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 661, 'message': 'Proportion of outlier detected: 18.3 %', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 33822, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=586738), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': 'Num of outlier detected: 7 in Feature 출장비율', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 38743, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=588778), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 661, 'message': 'Proportion of outlier detected: 0.6 %', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 40783, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=593709), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': 'Num of outlier detected: 10 in Feature 본사출장자수', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 45714, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=595744), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 661, 'message': 'Proportion of outlier detected: 0.8 %', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 47749, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=602417), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': 'Num of outlier detected: 25 in Feature 출근', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 54422, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=604417), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 661, 'message': 'Proportion of outlier detected: 2.1 %', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 56422, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=607415), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 658, 'message': 'Num of outlier detected: 276 in Feature 인원변화', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 59420, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=609401), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 661, 'message': 'Proportion of outlier detected: 23.3 %', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 61406, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10220 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7444, microseconds=647874), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1098, 'message': '##################################################', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 18, 45, 99879, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# ...
# Record was: {'elapsed': datetime.timedelta(seconds=7650, microseconds=81787), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1098, 'message': '##################################################', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 22, 10, 533792, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10568 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7650, microseconds=83761), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1099, 'message': 'Final data shape: (1187, 404)', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 22, 10, 535766, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10568 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7650, microseconds=84757), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1100, 'message': 'Total ADD columns: 390', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 22, 10, 536762, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10568 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7650, microseconds=86750), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1101, 'message': 'Time fit data_preproc: 0.48 sec', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 22, 10, 538755, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# --- Logging error in Loguru Handler #10568 ---
# Record was: {'elapsed': datetime.timedelta(seconds=7650, microseconds=87746), 'exception': None, 'extra': {}, 'file': (name='data_prepare.py', path='C:\\anaconda3\\envs\\machinelearning\\lib\\site-packages\\automl_alex\\data_prepare.py'), 'function': 'fit_transform', 'level': (name='INFO', no=20, icon='ℹ️'), 'line': 1102, 'message': '##################################################', 'module': 'data_prepare', 'name': 'automl_alex.data_prepare', 'process': (id=888, name='MainProcess'), 'thread': (id=5944, name='MainThread'), 'time': datetime(2021, 7, 15, 20, 22, 10, 539751, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400), '대한민국 표준시'))}
# Traceback (most recent call last):
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_handler.py", line 177, in emit
#     self._sink.write(str_record)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 174, in write
#     self._terminate_file(is_rotating=True)
#   File "C:\anaconda3\envs\machinelearning\lib\site-packages\loguru\_file_sink.py", line 205, in _terminate_file
#     os.rename(old_path, renamed_path)
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.log' -> 'C:\\Users\\김영봉\\Desktop\\Project\\DACON\\식수인원예측\\notebook\\.automl-alex_tmp\\log.2021-07-15_16-29-06_270718.log'
# --- End of logging error ---
# C:\anaconda3\envs\machinelearning\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# C:\anaconda3\envs\machinelearning\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# Optimize: : 45it [03:05,  4.12s/it, | Model: LightGBM | OptScore: 71.1259 | Best mean_absolute_error: 71.2068 ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-f6ca839b83b5> in <module>
#      11         X_test = lunch_test.drop(columns=dc)
#      12
# ---> 13         lunch_model.fit(X_train, y_lunch,
#      14                         verbose=3,
#      15                         folds=k,
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\automl_alex\automl_alex.py in fit(self, X, y, timeout, auto_parameters, folds, score_folds, opt_lvl, early_stoping, feature_selection, verbose)
#     443
#     444         timeout_model_2 = (timeout) - (time.time() - start_step_0) - 120
# --> 445         history = self.model_2.opt(
#     446             X=X,
#     447             y=y,
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\automl_alex\optimizer.py in opt(self, X, y, timeout, verbose, fit_end)
#     664         with tqdm(file=sys.stderr, desc="Optimize: ", disable=disable_tqdm) as pbar:
#     665             try:
# --> 666                 self.study.optimize(
#     667                     lambda trial: objective(trial, self, step=2, **obj_config),
#     668                     timeout=timeout_step2,
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     399             )
#     400
# --> 401         _optimize(
#     402             study=self,
#     403             func=func,
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      63     try:
#      64         if n_jobs == 1:
# ---> 65             _optimize_sequential(
#      66                 study,
#      67                 func,
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160
#     161         try:
# --> 162             trial = _run_trial(study, func, catch)
#     163         except Exception:
#     164             raise
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\_optimize.py in _run_trial(study, func, catch)
#     246     finally:
#     247         if state == TrialState.COMPLETE:
# --> 248             study._log_completed_trial(trial, cast(List[float], values))
#     249         elif state == TrialState.PRUNED:
#     250             _logger.info("Trial {} pruned. {}".format(trial.number, str(func_err)))
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\study.py in _log_completed_trial(self, trial, values)
#    1014                     trial.params,
#    1015                     self.best_trial.number,
# -> 1016                     self.best_value,
#    1017                 )
#    1018             )
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\study.py in best_value(self)
#      73         """
#      74
# ---> 75         best_value = self.best_trial.value
#      76         assert best_value is not None
#      77
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\study.py in best_trial(self)
#      96             )
#      97
# ---> 98         return copy.deepcopy(self._storage.get_best_trial(self._study_id))
#      99
#     100     @property
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\storages\_cached_storage.py in get_best_trial(self, study_id)
#     282     def get_best_trial(self, study_id: int) -> FrozenTrial:
#     283
# --> 284         return self._backend.get_best_trial(study_id)
#     285
#     286     def get_trial_param(self, trial_id: int, param_name: str) -> float:
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\storages\_rdb\storage.py in get_best_trial(self, study_id)
#    1120                 trial = models.TrialModel.find_max_value_trial(study_id, 0, session)
#    1121             else:
# -> 1122                 trial = models.TrialModel.find_min_value_trial(study_id, 0, session)
#    1123             trial_id = trial.trial_id
#    1124
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\optuna\storages\_rdb\models.py in find_min_value_trial(cls, study_id, objective, session)
#     214
#     215         trial = (
# --> 216             session.query(cls)
#     217             .filter(cls.study_id == study_id)
#     218             .filter(cls.state == TrialState.COMPLETE)
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\orm\query.py in one_or_none(self)
#    2784
#    2785         """
# -> 2786         return self._iter().one_or_none()
#    2787
#    2788     def one(self):
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\orm\query.py in _iter(self)
#    2842
#    2843         statement = self._statement_20()
# -> 2844         result = self.session.execute(
#    2845             statement,
#    2846             params,
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\orm\session.py in execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, **kw)
#    1687         else:
#    1688             conn = self._connection_for_bind(bind)
# -> 1689         result = conn._execute_20(statement, params or {}, execution_options)
#    1690
#    1691         if compile_state_cls:
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\engine\base.py in _execute_20(self, statement, parameters, execution_options)
#    1580             )
#    1581         else:
# -> 1582             return meth(self, args_10style, kwargs_10style, execution_options)
#    1583
#    1584     def exec_driver_sql(
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     321     ):
#     322         if _force or self.supports_execution:
# --> 323             return connection._execute_clauseelement(
#     324                 self, multiparams, params, execution_options
#     325             )
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1449             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1450         )
# -> 1451         ret = self._execute_context(
#    1452             dialect,
#    1453             dialect.execution_ctx_cls._init_compiled,
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1811
#    1812         except BaseException as e:
# -> 1813             self._handle_dbapi_exception(
#    1814                 e, statement, parameters, cursor, context
#    1815             )
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1996                 )
#    1997             else:
# -> 1998                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1999
#    2000         finally:
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1768                             break
#    1769                 if not evt_handled:
# -> 1770                     self.dialect.do_execute(
#    1771                         cursor, statement, parameters, context
#    1772                     )
#
# C:\anaconda3\envs\machinelearning\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# KeyboardInterrupt:

# %%
random_seed = 0
pred_dinner = np.array([0]*50).astype(np.float64)

for dc in drop_columns:
    for k in ks:
        print(dc,random_seed,k)
        
        dinner_model = AutoMLRegressor(random_state=random_seed, metric=MAE)
        
        X_train = dinner_train.drop(columns=dc)
        X_test = dinner_test.drop(columns=dc)
        
        dinner_model.fit(X_train, y_dinner,
                        verbose=3,
                        folds=k,
                        opt_lvl=3,
                        early_stoping=50,
                        auto_parameters=False,
                        timeout=1100                        
                       )
            

            
        pred_dinner += dinner_model.predict(X_test)

        clear_output(True)
                
        random_seed += 1

# %%
submission = pd.read_csv('../data/sample_submission.csv')
N = len(ks)*len(drop_columns)

submission.iloc[:,1] = pred_lunch/N
submission.iloc[:,2] = pred_dinner/N
submission.head()

# %%
answer = pd.read_csv('../submission/20210630_lgbm_autoML.csv')

lunch_answer = np.array(answer.iloc[:,1])
dinner_answer = np.array(answer.iloc[:,2])

abs(pred_lunch/N - lunch_answer).mean(), abs(pred_dinner/N - dinner_answer).mean()

# %% [markdown]
# # 저장

# %%
import datetime
today = str(datetime.datetime.now().date()).replace("-","")
print("오늘 날짜 : " + today)

submission.to_csv(f'../submission/{today}_autoML_knfold_drop.csv', index =False)

# %%
import pandas as pd
import numpy as np
from pycaret.regression import setup, compare_models, blend_models,tune_model,predict_model,get_config, finalize_model

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['font.family'] = 'Gulim'

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %%
train.head()
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
# 2  2016-02-03  수   2601      56     180             111          0.0
# 3  2016-02-04  목   2601     104     220             355          0.0
# 4  2016-02-05  금   2601     278     181              34          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
# 2  모닝롤/베이글  우유/두유/주스 계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 콩나물국...
# 3  모닝롤/토마토샌드  우유/두유/주스 계란후라이  닭죽/쌀밥 (쌀,닭:국내산) 근대국...
# 4  모닝롤/와플  우유/두유/주스 계란후라이  쇠고기죽/쌀밥 (쌀:국내산) 재첩국  방...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
# 2  카레덮밥 (쌀,현미흑미:국내산) 팽이장국  치킨핑거 (닭고기:국내산) 쫄면야채무침 ...
# 3  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 쇠고기무국  주꾸미볶음  부추전  시금치나물  ...
# 4  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 떡국  돈육씨앗강정 (돼지고기:국내산) 우엉잡채...
#
#                                                 석식메뉴     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0
# 2  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 청국장찌개  황태양념구이 (황태:러시아산) 고기...  1017.0  573.0
# 3  미니김밥*겨자장 (쌀,현미흑미:국내산) 우동  멕시칸샐러드  군고구마  무피클  포...   978.0  525.0
# 4  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 차돌박이찌개 (쇠고기:호주산) 닭갈비 (닭고기:...   925.0  330.0

# %% [markdown]
# ## 전처리
# - 일자에서 월과 일을 분리
# - 요일을 레이블 인코딩화(EDA로 요일의 중요도 순 파악)
# - 월 별, 일 별 중식 석식 수요 차이 파악

# %%
train['월'] = pd.DatetimeIndex(train['일자']).month.astype(str)
test['월'] = pd.DatetimeIndex(test['일자']).month.astype(str)
train['주'] = pd.DatetimeIndex(train['일자']).week.astype(str)
test['주'] = pd.DatetimeIndex(test['일자']).week.astype(str)
train['일'] = pd.DatetimeIndex(train['일자']).day.astype(str)
test['일'] = pd.DatetimeIndex(test['일자']).day.astype(str)

train['출근'] = train['본사정원수']-(train['본사휴가자수']+train['본사출장자수']+train['현본사소속재택근무자수'])
train['휴가비율'] = train['본사휴가자수']/train['본사정원수']
train['출장비율'] = train['본사출장자수']/train['본사정원수']
train['야근비율'] = train['본사시간외근무명령서승인건수']/train['출근']
train['재택비율'] = train['현본사소속재택근무자수']/train['본사정원수']

test['출근'] = test['본사정원수']-(test['본사휴가자수']+test['본사출장자수']+test['현본사소속재택근무자수'])
test['휴가비율'] = test['본사휴가자수']/test['본사정원수']
test['출장비율'] = test['본사출장자수']/test['본사정원수']
test['야근비율'] = test['본사시간외근무명령서승인건수']/test['출근']
test['재택비율'] = test['현본사소속재택근무자수']/test['본사정원수']

# %% [markdown]
# ## 공휴일 변수 생성

# %%
train['공휴일전후'] = 'N'
test['공휴일전후'] = 'N'

# %% [markdown]
# [4h, 17s, 152s, 221s, 226s, 245h, 309s, 310s,311s,330s,379s, 421h,502h,511s,565s,650h,651s,705s,709s,732h,815s,864s,951e,971h, 1038s,1129h, 1187e, ]

# %%
train['공휴일전후'][4] = 'H'
train['공휴일전후'][17] = 'S'
train['공휴일전후'][152] = 'S'
train['공휴일전후'][245] = 'H'
train['공휴일전후'][310] = 'S'
train['공휴일전후'][311] = 'S'
train['공휴일전후'][330] = 'S'
train['공휴일전후'][379] = 'S'
train['공휴일전후'][421] = 'H'
train['공휴일전후'][502] = 'H'
train['공휴일전후'][511] = 'S'
train['공휴일전후'][565] = 'S'
train['공휴일전후'][650] = 'H'
train['공휴일전후'][651] = 'S'
train['공휴일전후'][705] = 'C'
train['공휴일전후'][709] = 'S'
train['공휴일전후'][732] = 'H'
train['공휴일전후'][815] = 'S'
train['공휴일전후'][864] = 'S'
train['공휴일전후'][951] = 'C'
train['공휴일전후'][971] = 'H'
train['공휴일전후'][1038] = 'S'
train['공휴일전후'][1129] = 'H'
train['공휴일전후'][1187] = 'C'


test['공휴일전후'][10] = 'H'

# %%
train[train['공휴일전후'] != 'N'][need]
# Out:
#               일자 요일    중식계    석식계      휴가비율
# 4     2016-02-05  금  925.0  330.0  0.106882
# 17    2016-02-29  월  869.0  344.0  0.228758
# 152   2016-09-13  화  820.0  238.0  0.184543
# 245   2017-01-26  목  844.0  147.0  0.136819
# 310   2017-05-04  목  383.0  262.0  0.464164
# 311   2017-05-08  월  792.0  308.0  0.271141
# 330   2017-06-05  월  760.0  306.0  0.239048
# 379   2017-08-14  월  692.0  275.0  0.326276
# 421   2017-10-20  금  533.0  416.0  0.071834
# 502   2018-02-14  수  850.0    0.0  0.154414
# 511   2018-03-02  금  508.0  349.0  0.309506
# 565   2018-05-21  월  543.0  234.0  0.316428
# 650   2018-09-21  금  929.0  247.0  0.094101
# 651   2018-10-08  월  895.0  442.0  0.151159
# 705   2018-12-24  월  296.0  104.0  0.314125
# 709   2018-12-31  월  332.0  135.0  0.381237
# 732   2019-02-01  금  804.0  171.0  0.100855
# 815   2019-06-07  금  389.0  244.0  0.322698
# 864   2019-08-16  금  466.0  313.0  0.310439
# 951   2019-12-24  화  462.0  221.0  0.153648
# 971   2020-01-23  목  685.0  117.0  0.170507
# 1038  2020-05-04  월  504.0  123.0  0.375760
# 1129  2020-09-28  월  358.0  165.0  0.314496
# 1187  2020-12-24  목  591.0  131.0  0.259866

# %% [markdown]
# ## 텍스트(메뉴) 전처리

# %% [markdown]
# ### train/test에서 중복 메뉴만 변수로서 사용

# %%
menu_train = train[['조식메뉴','중식메뉴','석식메뉴']]
menu_test = test[['조식메뉴','중식메뉴','석식메뉴']]
print(menu_train.shape)
print(menu_test.shape)
# Out:
# (1205, 3)
# (50, 3)

# %%
def clean_split(df):
    df = df.split()
    for j in df:
        if '(' in j:
            del df[df.index(j)]    
    return df

# %%
menu_train['조식메뉴_prepro'] = menu_train['조식메뉴'].apply(clean_split)
menu_train['중식메뉴_prepro'] = menu_train['중식메뉴'].apply(clean_split)
menu_train['석식메뉴_prepro'] = menu_train['석식메뉴'].apply(clean_split)

menu_test['조식메뉴_prepro'] = menu_test['조식메뉴'].apply(clean_split)
menu_test['중식메뉴_prepro'] = menu_test['중식메뉴'].apply(clean_split)
menu_test['석식메뉴_prepro'] = menu_test['석식메뉴'].apply(clean_split)

# %%
lunch_train_f = [menu[:3] for menu in menu_train.중식메뉴_prepro]
lunch_test_f = [menu[:3] for menu in menu_test.중식메뉴_prepro]

dinner_train_f = [menu[:3] for menu in menu_train.석식메뉴_prepro]
dinner_test_f = [menu[:3] for menu in menu_test.석식메뉴_prepro]

# %%
lunch_train_menu = pd.DataFrame(lunch_train_f, columns = ['밥', '국', '메인'])
lunch_test_menu = pd.DataFrame(lunch_test_f, columns = ['밥', '국', '메인'])

dinner_train_menu = pd.DataFrame(dinner_train_f, columns = ['밥', '국', '메인'])
dinner_test_menu = pd.DataFrame(dinner_test_f, columns = ['밥', '국', '메인'])

# %% [markdown]
# ## 최종 데이터 셋 구축

# %%
train.columns
# Out:
# Index(['일자', '요일', '본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수',
#        '현본사소속재택근무자수', '조식메뉴', '중식메뉴', '석식메뉴', '중식계', '석식계', '월', '주', '일',
#        '출근', '휴가비율', '출장비율', '야근비율', '재택비율', '공휴일전후'],
#       dtype='object')

# %%
lunch_train = pd.concat([train[['요일','월','일','주','본사시간외근무명령서승인건수', '본사출장자수', '본사휴가자수', '본사정원수','현본사소속재택근무자수', '공휴일전후','출근', '휴가비율', '출장비율', '야근비율', '재택비율','중식계']]],axis=1)
lunch_test = pd.concat([test[['요일','월','일','주','본사시간외근무명령서승인건수', '본사출장자수', '본사휴가자수', '본사정원수','현본사소속재택근무자수', '공휴일전후','출근', '휴가비율', '출장비율', '야근비율', '재택비율']]],axis=1)


dinner_train = pd.concat([train[['요일','월','일','주','본사시간외근무명령서승인건수', '본사출장자수', '본사휴가자수', '본사정원수','현본사소속재택근무자수', '공휴일전후','출근', '휴가비율', '출장비율', '야근비율', '재택비율','석식계']]],axis=1)
dinner_test = pd.concat([test[['요일','월','일','주','본사시간외근무명령서승인건수', '본사출장자수', '본사휴가자수', '본사정원수','현본사소속재택근무자수', '공휴일전후','출근', '휴가비율', '출장비율', '야근비율', '재택비율']]],axis=1)

# %%
print(lunch_train.shape)
print(lunch_test.shape)
# Out:
# (1205, 16)
# (50, 15)

# %%
print(dinner_train.shape)
print(dinner_test.shape)
# Out:
# (1205, 16)
# (50, 15)

# %% [markdown]
# #### 분포 확인 및 분포 조정

# %%
drop_index = dinner_train[dinner_train['석식계']==0].index

dinner_train.iloc[drop_index]
# Out:
#      요일   월   일   주  본사시간외근무명령서승인건수  본사출장자수  본사휴가자수  본사정원수  현본사소속재택근무자수 공휴일전후  \
# 204   수  11  30  48               0     207      68   2689          0.0     N
# 224   수  12  28  52               0     225     166   2705          0.0     N
# 244   수   1  25   4               0     203      79   2697          0.0     N
# 262   수   2  22   8               0     252      75   2632          0.0     N
# 281   수   3  22  12               0     235      53   2627          0.0     N
# 306   수   4  26  17               0     304      45   2626          0.0     N
# 327   수   5  31  22               0     265      43   2637          0.0     N
# 346   수   6  28  26               0     259      58   2648          0.0     N
# 366   수   7  26  30               0     246     254   2839          0.0     N
# 392   금   9   1  35              45     303     177   2642          0.0     N
# 410   수   9  27  39               0     265      70   2642          0.0     N
# 412   금   9  29  39              22     248     214   2642          0.0     N
# 424   수  10  25  43               0     289      75   2645          0.0     N
# 449   수  11  29  48               0     261      78   2644          0.0     N
# 468   수  12  27  52               0     255     169   2665          0.0     N
# 492   수   1  31   5               0     223      56   2655          0.0     N
# 502   수   2  14   7               0     159     418   2707          0.0     H
# 510   수   2  28   9               0     278     134   2707          0.0     N
# 529   수   3  28  13               0     252      45   2714          0.0     N
# 549   수   4  25  17               0     285      66   2714          0.0     N
# 571   수   5  30  22               0     281      80   2721          0.0     N
# 589   수   6  27  26               0     277      66   2728          0.0     N
# 609   수   7  25  30               1     256     226   2704          0.0     N
# 633   수   8  29  35               0     258     103   2996          0.0     N
# 648   수   9  19  38               0     288      77   2763          0.0     N
# 667   수  10  31  44               0     306     111   2805          0.0     N
# 687   수  11  28  48               1     298      69   2815          0.0     N
# 706   수  12  26  52               0     241     184   2846          0.0     N
# 730   수   1  30   5               1     226      66   2985          0.0     N
# 747   수   2  27   9               0     274     100   2806          0.0     N
# 766   수   3  27  13               0     259      92   2836          0.0     N
# 786   수   4  24  17               0     273      59   2822          0.0     N
# 809   수   5  29  22               0     237      50   2825          0.0     N
# 828   수   6  26  26               0     282      69   2758          0.0     N
# 853   수   7  31  31               0     231     495   2760          0.0     N
# 872   수   8  28  35               0     274     123   3305          0.0     N
# 890   수   9  25  39               1     285      60   3111          0.0     N
# 912   수  10  30  44               1     294     122   3121          0.0     N
# 932   수  11  27  48               1     288     134   3104          0.0     N
# 955   화  12  31   1              22     149     709   3111          0.0     N
# 973   수   1  29   5               4     214     101   2821          0.0     N
# 993   수   2  26   9               4     190     109   2872          0.0     N
# 1166  수  11  25  48               3     191     206   3021        387.0     N
#
#           출근      휴가비율      출장비율      야근비율      재택비율  석식계
# 204   2414.0  0.025288  0.076980  0.000000  0.000000  0.0
# 224   2314.0  0.061368  0.083179  0.000000  0.000000  0.0
# 244   2415.0  0.029292  0.075269  0.000000  0.000000  0.0
# 262   2305.0  0.028495  0.095745  0.000000  0.000000  0.0
# 281   2339.0  0.020175  0.089456  0.000000  0.000000  0.0
# 306   2277.0  0.017136  0.115765  0.000000  0.000000  0.0
# 327   2329.0  0.016306  0.100493  0.000000  0.000000  0.0
# 346   2331.0  0.021903  0.097810  0.000000  0.000000  0.0
# 366   2339.0  0.089468  0.086650  0.000000  0.000000  0.0
# 392   2162.0  0.066995  0.114686  0.020814  0.000000  0.0
# 410   2307.0  0.026495  0.100303  0.000000  0.000000  0.0
# 412   2180.0  0.080999  0.093868  0.010092  0.000000  0.0
# 424   2281.0  0.028355  0.109263  0.000000  0.000000  0.0
# 449   2305.0  0.029501  0.098714  0.000000  0.000000  0.0
# 468   2241.0  0.063415  0.095685  0.000000  0.000000  0.0
# 492   2376.0  0.021092  0.083992  0.000000  0.000000  0.0
# 502   2130.0  0.154414  0.058737  0.000000  0.000000  0.0
# 510   2295.0  0.049501  0.102697  0.000000  0.000000  0.0
# 529   2417.0  0.016581  0.092852  0.000000  0.000000  0.0
# 549   2363.0  0.024318  0.105011  0.000000  0.000000  0.0
# 571   2360.0  0.029401  0.103271  0.000000  0.000000  0.0
# 589   2385.0  0.024194  0.101540  0.000000  0.000000  0.0
# 609   2222.0  0.083580  0.094675  0.000450  0.000000  0.0
# 633   2635.0  0.034379  0.086115  0.000000  0.000000  0.0
# 648   2398.0  0.027868  0.104235  0.000000  0.000000  0.0
# 667   2388.0  0.039572  0.109091  0.000000  0.000000  0.0
# 687   2448.0  0.024512  0.105861  0.000408  0.000000  0.0
# 706   2421.0  0.064652  0.084680  0.000000  0.000000  0.0
# 730   2693.0  0.022111  0.075712  0.000371  0.000000  0.0
# 747   2432.0  0.035638  0.097648  0.000000  0.000000  0.0
# 766   2485.0  0.032440  0.091326  0.000000  0.000000  0.0
# 786   2490.0  0.020907  0.096740  0.000000  0.000000  0.0
# 809   2538.0  0.017699  0.083894  0.000000  0.000000  0.0
# 828   2407.0  0.025018  0.102248  0.000000  0.000000  0.0
# 853   2034.0  0.179348  0.083696  0.000000  0.000000  0.0
# 872   2908.0  0.037216  0.082905  0.000000  0.000000  0.0
# 890   2766.0  0.019286  0.091610  0.000362  0.000000  0.0
# 912   2705.0  0.039090  0.094201  0.000370  0.000000  0.0
# 932   2682.0  0.043170  0.092784  0.000373  0.000000  0.0
# 955   2253.0  0.227901  0.047895  0.009765  0.000000  0.0
# 973   2506.0  0.035803  0.075860  0.001596  0.000000  0.0
# 993   2573.0  0.037953  0.066156  0.001555  0.000000  0.0
# 1166  2237.0  0.068189  0.063224  0.001341  0.128103  0.0

# %%
dinner_train.drop(drop_index, inplace=True)

print(dinner_train.shape)
# Out:
# (1162, 16)

# %% [markdown]
# # 중식 예측모델

# %%
cat_features = [f for f in lunch_train.columns if lunch_train[f].dtype == 'object']

def column_index(df, cat_features):
    cols = df.columns.values
    sidx = np.argsort(cols)
    return sidx[np.searchsorted(cols, cat_features, sorter=sidx)]

cat_features_idx = column_index(lunch_train, cat_features)    
print("Cat features are: %s" % [f for f in cat_features])
print(cat_features_idx)
# Out:
# Cat features are: ['요일', '월', '일', '주', '공휴일전후']
# [0 1 2 3 9]

# %%
lunch_regression_model = setup(data=lunch_train, target='중식계', train_size=0.8,n_jobs=-1,fold = 5,
                               categorical_features = cat_features,
                               numeric_imputation = 'mean',
                               normalize = True)
# Out:
# <style  type="text/css" >
# #T_37617_row27_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_37617_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_37617_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_37617_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_37617_row0_col1" class="data row0 col1" >6123</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_37617_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_37617_row1_col1" class="data row1 col1" >중식계</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_37617_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_37617_row2_col1" class="data row2 col1" >(1205, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_37617_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_37617_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_37617_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_37617_row4_col1" class="data row4 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_37617_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_37617_row5_col1" class="data row5 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_37617_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_37617_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_37617_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_37617_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_37617_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_37617_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_37617_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_37617_row9_col1" class="data row9 col1" >(964, 112)</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_37617_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_37617_row10_col1" class="data row10 col1" >(241, 112)</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_37617_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_37617_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_37617_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_37617_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_37617_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_37617_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_37617_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_37617_row14_col1" class="data row14 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_37617_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_37617_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_37617_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_37617_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_37617_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_37617_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_37617_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_37617_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_37617_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_37617_row19_col1" class="data row19 col1" >4277</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_37617_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_37617_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_37617_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_37617_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_37617_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_37617_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_37617_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_37617_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_37617_level0_row24" class="row_heading level0 row24"

# %%
# 최고 성능 모델 선정(2개)
lunch_regression_best_models = compare_models(sort='MAE', fold=5, n_select=2)
# Out:
# <style  type="text/css" >
#     #T_e0fe5_ th {
#           text-align: left;
#     }#T_e0fe5_row0_col0,#T_e0fe5_row1_col0,#T_e0fe5_row1_col1,#T_e0fe5_row1_col2,#T_e0fe5_row1_col3,#T_e0fe5_row1_col4,#T_e0fe5_row1_col5,#T_e0fe5_row1_col6,#T_e0fe5_row2_col0,#T_e0fe5_row2_col1,#T_e0fe5_row2_col2,#T_e0fe5_row2_col3,#T_e0fe5_row2_col4,#T_e0fe5_row2_col5,#T_e0fe5_row2_col6,#T_e0fe5_row3_col0,#T_e0fe5_row3_col1,#T_e0fe5_row3_col2,#T_e0fe5_row3_col3,#T_e0fe5_row3_col4,#T_e0fe5_row3_col5,#T_e0fe5_row3_col6,#T_e0fe5_row4_col0,#T_e0fe5_row4_col1,#T_e0fe5_row4_col2,#T_e0fe5_row4_col3,#T_e0fe5_row4_col4,#T_e0fe5_row4_col5,#T_e0fe5_row4_col6,#T_e0fe5_row5_col0,#T_e0fe5_row5_col1,#T_e0fe5_row5_col2,#T_e0fe5_row5_col3,#T_e0fe5_row5_col4,#T_e0fe5_row5_col5,#T_e0fe5_row5_col6,#T_e0fe5_row6_col0,#T_e0fe5_row6_col1,#T_e0fe5_row6_col2,#T_e0fe5_row6_col3,#T_e0fe5_row6_col4,#T_e0fe5_row6_col5,#T_e0fe5_row6_col6,#T_e0fe5_row7_col0,#T_e0fe5_row7_col1,#T_e0fe5_row7_col2,#T_e0fe5_row7_col3,#T_e0fe5_row7_col4,#T_e0fe5_row7_col5,#T_e0fe5_row7_col6,#T_e0fe5_row8_col0,#T_e0fe5_row8_col1,#T_e0fe5_row8_col2,#T_e0fe5_row8_col3,#T_e0fe5_row8_col4,#T_e0fe5_row8_col5,#T_e0fe5_row8_col6,#T_e0fe5_row9_col0,#T_e0fe5_row9_col1,#T_e0fe5_row9_col2,#T_e0fe5_row9_col3,#T_e0fe5_row9_col4,#T_e0fe5_row9_col5,#T_e0fe5_row9_col6,#T_e0fe5_row10_col0,#T_e0fe5_row10_col1,#T_e0fe5_row10_col2,#T_e0fe5_row10_col3,#T_e0fe5_row10_col4,#T_e0fe5_row10_col5,#T_e0fe5_row10_col6,#T_e0fe5_row11_col0,#T_e0fe5_row11_col1,#T_e0fe5_row11_col2,#T_e0fe5_row11_col3,#T_e0fe5_row11_col4,#T_e0fe5_row11_col5,#T_e0fe5_row11_col6,#T_e0fe5_row12_col0,#T_e0fe5_row12_col1,#T_e0fe5_row12_col2,#T_e0fe5_row12_col3,#T_e0fe5_row12_col4,#T_e0fe5_row12_col5,#T_e0fe5_row12_col6,#T_e0fe5_row13_col0,#T_e0fe5_row13_col1,#T_e0fe5_row13_col2,#T_e0fe5_row13_col3,#T_e0fe5_row13_col4,#T_e0fe5_row13_col5,#T_e0fe5_row13_col6,#T_e0fe5_row14_col0,#T_e0fe5_row14_col1,#T_e0fe5_row14_col2,#T_e0fe5_row14_col3,#T_e0fe5_row14_col4,#T_e0fe5_row14_col5,#T_e0fe5_row14_col6,#T_e0fe5_row15_col0,#T_e0fe5_row15_col1,#T_e0fe5_row15_col2,#T_e0fe5_row15_col3,#T_e0fe5_row15_col4,#T_e0fe5_row15_col5,#T_e0fe5_row15_col6,#T_e0fe5_row16_col0,#T_e0fe5_row16_col1,#T_e0fe5_row16_col2,#T_e0fe5_row16_col3,#T_e0fe5_row16_col4,#T_e0fe5_row16_col5,#T_e0fe5_row16_col6,#T_e0fe5_row17_col0,#T_e0fe5_row17_col1,#T_e0fe5_row17_col2,#T_e0fe5_row17_col3,#T_e0fe5_row17_col4,#T_e0fe5_row17_col5,#T_e0fe5_row17_col6,#T_e0fe5_row18_col0,#T_e0fe5_row18_col1,#T_e0fe5_row18_col2,#T_e0fe5_row18_col3,#T_e0fe5_row18_col4,#T_e0fe5_row18_col5,#T_e0fe5_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_e0fe5_row0_col1,#T_e0fe5_row0_col2,#T_e0fe5_row0_col3,#T_e0fe5_row0_col4,#T_e0fe5_row0_col5,#T_e0fe5_row0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_e0fe5_row0_col7,#T_e0fe5_row1_col7,#T_e0fe5_row2_col7,#T_e0fe5_row3_col7,#T_e0fe5_row4_col7,#T_e0fe5_row5_col7,#T_e0fe5_row6_col7,#T_e0fe5_row7_col7,#T_e0fe5_row8_col7,#T_e0fe5_row10_col7,#T_e0fe5_row11_col7,#T_e0fe5_row12_col7,#T_e0fe5_row13_col7,#T_e0fe5_row15_col7,#T_e0fe5_row16_col7,#T_e0fe5_row17_col7,#T_e0fe5_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_e0fe5_row9_col7,#T_e0fe5_row14_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_e0fe5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e0fe5_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_e0fe5_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_e0fe5_row0_col1" class="data row0 col1" >65.8251</td>
#                         <td id="T_e0fe5_row0_col2" class="data row0 col2" >7891.4500</td>
#                         <td id="T_e0fe5_row0_col3" class="data row0 col3" >88.5893</td>
#                         <td id="T_e0fe5_row0_col4" class="data row0 col4" >0.8246</td>
#                         <td id="T_e0fe5_row0_col5" class="data row0 col5" >0.1120</td>
#                         <td id="T_e0fe5_row0_col6" class="data row0 col6" >0.0811</td>
#                         <td id="T_e0fe5_row0_col7" class="data row0 col7" >0.9840</td>
#             </tr>
#             <tr>
#                         <th id="T_e0fe5_level0_row1" class="row_heading level0 row1" >gbr</th>
#                         <td id="T_e0fe5_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_e0fe5_row1_col1" class="data row1 col1" >68.7135</td>
#                         <td id="T_e0fe5_row1_col2" class="data row1 col2" >8500.2164</td>
#                         <td id="T_e0fe5_row1_col3" class="data row1 col3" >91.9630</td>
#                         <td id="T_e0fe5_row1_col4" class="data row1 col4" >0.8111</td>
#                         <td id="T_e0fe5_row1_col5" class="data row1 col5" >0.1154</td>
#                         <td id="T_e0fe5_row1_col6" class="data row1 col6" >0.0846</td>
#                         <td id="T_e0fe5_row1_col7" class="data row1 col7" >0.0660</td>
#             </tr>
#             <tr>
#                         <th id="T_e0fe5_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_e0fe5_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#                         <td id="T_e0fe5_row2_col1" class="data row2 col1" >71.0057</td>
#                         <td id="T_e0fe5_row2_col2" class="data row2 col2" >9303.3238</td>
#                         <td id="T_e0fe5_row2_col3" class="data row2 col3" >96.0589</td>
#                         <td id="T_e0fe5_row2_col4" class="data row2 col4" >0.7933</td>
#                         <td id="T_e0fe5_row2_col5" class="data row2 col5" >0.1228</td>
#                         <td id="T_e0fe5_row2_col6" class="data row2 col6" >0.0882</td>
#                         <td id="T_e0fe5_row2_col7" class="data row2 col7" >0.1800</td>
#             </tr>
#             <tr>
#                         <th id="T_e0fe5_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#                         <td id="T_e0fe5_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_e0fe5_row3_col1" class="data row3 col1" >73.0409</td>
#                         <td id="T_e0fe5_row3_col2" class="data row3 col2" >9232.6812</td>
#                         <td id="T_e0fe5_row3_col3" class="data row3 col3" >95.9453</td>
#                         <td id="T_e0fe5_row3_col4" class="data row3 col4" >0.7939</td>
#                         <td id="T_e0fe5_row3_col5" class="data row3 col5" >0.1211</td>
#                         <td id="T_e0fe5_row3_col6" class="data row3 col6" >0.0895</td>
#                         <td id="T_e0fe5_row3_col7" class="data row3 col7" >0.2900</td>
#             </tr>
#             <tr>
#                         <th id="T_e0fe5_level0_row4" class="row_heading level0 row4" >xgboost</th>
#                         <td id="T_e0fe5_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_e0fe5_row4_col1" class="data row4 col1" >73.2768</td>
#                         <td id="T_e0fe5_row4_col2" class="data row4 col2" >9530.1688</td>
#                         <td id="T_e0fe5_row4_col3" class="data row4 col3" >97.3396</td>
#                         <td id="T_e0fe5_row4_col4" class="data row4 c

# %%
lunch_regression_best_models_tuned = [tune_model(model, optimize='MAE') for model in lunch_regression_best_models]
# Out:
# <style  type="text/css" >
# #T_039c5_row5_col0,#T_039c5_row5_col1,#T_039c5_row5_col2,#T_039c5_row5_col3,#T_039c5_row5_col4,#T_039c5_row5_col5{
#             background:  yellow;
#         }</style><table id="T_039c5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_039c5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_039c5_row0_col0" class="data row0 col0" >73.6920</td>
#                         <td id="T_039c5_row0_col1" class="data row0 col1" >9989.9877</td>
#                         <td id="T_039c5_row0_col2" class="data row0 col2" >99.9499</td>
#                         <td id="T_039c5_row0_col3" class="data row0 col3" >0.7816</td>
#                         <td id="T_039c5_row0_col4" class="data row0 col4" >0.1165</td>
#                         <td id="T_039c5_row0_col5" class="data row0 col5" >0.0879</td>
#             </tr>
#             <tr>
#                         <th id="T_039c5_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_039c5_row1_col0" class="data row1 col0" >65.9684</td>
#                         <td id="T_039c5_row1_col1" class="data row1 col1" >7339.5791</td>
#                         <td id="T_039c5_row1_col2" class="data row1 col2" >85.6713</td>
#                         <td id="T_039c5_row1_col3" class="data row1 col3" >0.8229</td>
#                         <td id="T_039c5_row1_col4" class="data row1 col4" >0.1053</td>
#                         <td id="T_039c5_row1_col5" class="data row1 col5" >0.0815</td>
#             </tr>
#             <tr>
#                         <th id="T_039c5_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_039c5_row2_col0" class="data row2 col0" >65.4595</td>
#                         <td id="T_039c5_row2_col1" class="data row2 col1" >7385.0620</td>
#                         <td id="T_039c5_row2_col2" class="data row2 col2" >85.9364</td>
#                         <td id="T_039c5_row2_col3" class="data row2 col3" >0.8112</td>
#                         <td id="T_039c5_row2_col4" class="data row2 col4" >0.1076</td>
#                         <td id="T_039c5_row2_col5" class="data row2 col5" >0.0796</td>
#             </tr>
#             <tr>
#                         <th id="T_039c5_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_039c5_row3_col0" class="data row3 col0" >66.5717</td>
#                         <td id="T_039c5_row3_col1" class="data row3 col1" >7440.2522</td>
#                         <td id="T_039c5_row3_col2" class="data row3 col2" >86.2569</td>
#                         <td id="T_039c5_row3_col3" class="data row3 col3" >0.8342</td>
#                         <td id="T_039c5_row3_col4" class="data row3 col4" >0.1075</td>
#                         <td id="T_039c5_row3_col5" class="data row3 col5" >0.0794</td>
#             </tr>
#             <tr>
#                         <th id="T_039c5_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_039c5_row4_col0" class="data row4 col0" >71.8473</td>
#                         <td id="T_039c5_row4_col1" class="data row4 col1" >9525.4860</td>
#                         <td id="T_039c5_row4_col2" class="data row4 col2" >97.5986</td>
#                         <td id="T_039c5_row4_col3" class="data row4 col3" >0.8213</td>
#                         <td id="T_039c5_row4_col4" class="data row4 col4" >0.1338</td>
#                         <td id="T_039c5_row4_col5" class="data row4 col5" >0.0927</td>
#             </tr>
#             <tr>
#                         <th id="T_039c5_level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_039c5_row5_col0" class="data row5 col0" >68.7078</td>
#                         <td id="T_039c5_row5_col1" class="data row5 col1" >8336.0734</td>
#                         <td id="T_039c5_row5_col2" class="data row5 col2" >91.0826</td>
#                         <td id="T_039c5_row5_col3" class="data row5 col3" >0.8142</td>
#                         <td id="T_039c5_row5_col4" class="data row5 col4" >0.1141</td>
#                         <td id="T_039c5_row5_col5" class="data row5 col5" >0.0842</td>
#             </tr>
#             <tr>
#                         <th id="T_039c5_level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_039c5_row6_col0" class="data row6 col0" >3.3858</td>
#                         <td id="T_039c5_row6_col1" class="data row6 col1" >1170.4746</td>
#                         <td id="T_039c5_row6_col2" class="data row6 col2" >6.3268</td>
#                         <td id="T_039c5_row6_col3" class="data row6 col3" >0.0179</td>
#                         <td id="T_039c5_row6_col4" class="data row6 col4" >0.0106</td>
#                         <td id="T_039c5_row6_col5" class="data row6 col5" >0.0053</td>
#             </tr>
#     </tbody></table>

# %%
lunch_model = blend_models(estimator_list=lunch_regression_best_models_tuned, fold=5, optimize='MAE')
# Out:
# <style  type="text/css" >
# #T_6c427_row5_col0,#T_6c427_row5_col1,#T_6c427_row5_col2,#T_6c427_row5_col3,#T_6c427_row5_col4,#T_6c427_row5_col5{
#             background:  yellow;
#         }</style><table id="T_6c427_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6c427_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6c427_row0_col0" class="data row0 col0" >70.5373</td>
#                         <td id="T_6c427_row0_col1" class="data row0 col1" >9396.3852</td>
#                         <td id="T_6c427_row0_col2" class="data row0 col2" >96.9350</td>
#                         <td id="T_6c427_row0_col3" class="data row0 col3" >0.7946</td>
#                         <td id="T_6c427_row0_col4" class="data row0 col4" >0.1144</td>
#                         <td id="T_6c427_row0_col5" class="data row0 col5" >0.0851</td>
#             </tr>
#             <tr>
#                         <th id="T_6c427_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6c427_row1_col0" class="data row1 col0" >65.7135</td>
#                         <td id="T_6c427_row1_col1" class="data row1 col1" >7454.7948</td>
#                         <td id="T_6c427_row1_col2" class="data row1 col2" >86.3412</td>
#                         <td id="T_6c427_row1_col3" class="data row1 col3" >0.8201</td>
#                         <td id="T_6c427_row1_col4" class="data row1 col4" >0.1060</td>
#                         <td id="T_6c427_row1_col5" class="data row1 col5" >0.0811</td>
#             </tr>
#             <tr>
#                         <th id="T_6c427_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6c427_row2_col0" class="data row2 col0" >64.2963</td>
#                         <td id="T_6c427_row2_col1" class="data row2 col1" >7059.7095</td>
#                         <td id="T_6c427_row2_col2" class="data row2 col2" >84.0221</td>
#                         <td id="T_6c427_row2_col3" class="data row2 col3" >0.8195</td>
#                         <td id="T_6c427_row2_col4" class="data row2 col4" >0.1064</td>
#                         <td id="T_6c427_row2_col5" class="data row2 col5" >0.0790</td>
#             </tr>
#             <tr>
#                         <th id="T_6c427_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6c427_row3_col0" class="data row3 col0" >66.4116</td>
#                         <td id="T_6c427_row3_col1" class="data row3 col1" >7196.0997</td>
#                         <td id="T_6c427_row3_col2" class="data row3 col2" >84.8298</td>
#                         <td id="T_6c427_row3_col3" class="data row3 col3" >0.8397</td>
#                         <td id="T_6c427_row3_col4" class="data row3 col4" >0.1072</td>
#                         <td id="T_6c427_row3_col5" class="data row3 col5" >0.0793</td>
#             </tr>
#             <tr>
#                         <th id="T_6c427_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6c427_row4_col0" class="data row4 col0" >69.7032</td>
#                         <td id="T_6c427_row4_col1" class="data row4 col1" >9345.2629</td>
#                         <td id="T_6c427_row4_col2" class="data row4 col2" >96.6709</td>
#                         <td id="T_6c427_row4_col3" class="data row4 col3" >0.8246</td>
#                         <td id="T_6c427_row4_col4" class="data row4 col4" >0.1316</td>
#                         <td id="T_6c427_row4_col5" class="data row4 col5" >0.0897</td>
#             </tr>
#             <tr>
#                         <th id="T_6c427_level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_6c427_row5_col0" class="data row5 col0" >67.3324</td>
#                         <td id="T_6c427_row5_col1" class="data row5 col1" >8090.4504</td>
#                         <td id="T_6c427_row5_col2" class="data row5 col2" >89.7598</td>
#                         <td id="T_6c427_row5_col3" class="data row5 col3" >0.8197</td>
#                         <td id="T_6c427_row5_col4" class="data row5 col4" >0.1131</td>
#                         <td id="T_6c427_row5_col5" class="data row5 col5" >0.0828</td>
#             </tr>
#             <tr>
#                         <th id="T_6c427_level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_6c427_row6_col0" class="data row6 col0" >2.3907</td>
#                         <td id="T_6c427_row6_col1" class="data row6 col1" >1053.2206</td>
#                         <td id="T_6c427_row6_col2" class="data row6 col2" >5.7993</td>
#                         <td id="T_6c427_row6_col3" class="data row6 col3" >0.0145</td>
#                         <td id="T_6c427_row6_col4" class="data row6 col4" >0.0097</td>
#                         <td id="T_6c427_row6_col5" class="data row6 col5" >0.0041</td>
#             </tr>
#     </tbody></table>

# %%
pred = predict_model(lunch_model)
# Out:
# <style  type="text/css" >
# </style><table id="T_cd7f6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cd7f6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cd7f6_row0_col0" class="data row0 col0" >Voting Regressor</td>
#                         <td id="T_cd7f6_row0_col1" class="data row0 col1" >129.4112</td>
#                         <td id="T_cd7f6_row0_col2" class="data row0 col2" >23557.6845</td>
#                         <td id="T_cd7f6_row0_col3" class="data row0 col3" >153.4851</td>
#                         <td id="T_cd7f6_row0_col4" class="data row0 col4" >0.3980</td>
#                         <td id="T_cd7f6_row0_col5" class="data row0 col5" >0.1704</td>
#                         <td id="T_cd7f6_row0_col6" class="data row0 col6" >0.1576</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 테스트 데이터 예측

# %%
submission = pd.read_csv('../data/sample_submission.csv')

# %%
final_model_lunch = finalize_model(lunch_model)
prep_pipe_lunch = get_config('prep_pipe')
prep_pipe_lunch.steps.append(['trained_model', final_model_lunch])

# %%
answer = pd.read_csv('../submission/제출해야될것.csv')['중식계']

abs(answer - pred_lunch).mean()
# Out:
# 36.93714801900568

# %%
pred_lunch = prep_pipe_lunch.predict(lunch_test)

submission.iloc[:,1] = pred_lunch
submission.head()
# Out:
#            일자          중식계  석식계
# 0  2021-01-27  1030.240513    0
# 1  2021-01-28   951.382904    0
# 2  2021-01-29   616.514112    0
# 3  2021-02-01  1224.098803    0
# 4  2021-02-02   976.909941    0

# %% [markdown]
# # 석식 예측모델

# %%
dinner_regression_model = setup(data=dinner_train, target='석식계', train_size=0.8,n_jobs=-1,fold = 5,
                               categorical_features = cat_features,
                               numeric_imputation = 'mean',
                               normalize = True)
# Out:
# <style  type="text/css" >
# #T_ec1dd_row27_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_ec1dd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ec1dd_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ec1dd_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_ec1dd_row0_col1" class="data row0 col1" >8008</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ec1dd_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_ec1dd_row1_col1" class="data row1 col1" >석식계</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ec1dd_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_ec1dd_row2_col1" class="data row2 col1" >(1162, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ec1dd_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_ec1dd_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ec1dd_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_ec1dd_row4_col1" class="data row4 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ec1dd_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_ec1dd_row5_col1" class="data row5 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ec1dd_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_ec1dd_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ec1dd_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_ec1dd_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_ec1dd_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_ec1dd_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_ec1dd_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_ec1dd_row9_col1" class="data row9 col1" >(929, 111)</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_ec1dd_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_ec1dd_row10_col1" class="data row10 col1" >(233, 111)</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_ec1dd_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_ec1dd_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_ec1dd_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_ec1dd_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_ec1dd_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_ec1dd_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_ec1dd_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_ec1dd_row14_col1" class="data row14 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_ec1dd_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_ec1dd_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_ec1dd_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_ec1dd_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_ec1dd_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_ec1dd_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_ec1dd_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_ec1dd_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_ec1dd_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_ec1dd_row19_col1" class="data row19 col1" >23dd</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_ec1dd_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_ec1dd_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_ec1dd_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_ec1dd_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_ec1dd_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_ec1dd_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_ec1dd_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_ec1dd_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_ec1dd_level0_row24" class="row_heading level0 row24"

# %%
dinner_regression_best_models = compare_models(sort='MAE', fold=5, n_select=3, exclude=['huber','llar','lar','par','lasso'])
# Out:
# <style  type="text/css" >
#     #T_1494d_ th {
#           text-align: left;
#     }#T_1494d_row0_col0,#T_1494d_row0_col2,#T_1494d_row0_col3,#T_1494d_row0_col4,#T_1494d_row1_col0,#T_1494d_row1_col1,#T_1494d_row1_col5,#T_1494d_row1_col6,#T_1494d_row2_col0,#T_1494d_row2_col1,#T_1494d_row2_col2,#T_1494d_row2_col3,#T_1494d_row2_col4,#T_1494d_row2_col5,#T_1494d_row2_col6,#T_1494d_row3_col0,#T_1494d_row3_col1,#T_1494d_row3_col2,#T_1494d_row3_col3,#T_1494d_row3_col4,#T_1494d_row3_col5,#T_1494d_row3_col6,#T_1494d_row4_col0,#T_1494d_row4_col1,#T_1494d_row4_col2,#T_1494d_row4_col3,#T_1494d_row4_col4,#T_1494d_row4_col5,#T_1494d_row4_col6,#T_1494d_row5_col0,#T_1494d_row5_col1,#T_1494d_row5_col2,#T_1494d_row5_col3,#T_1494d_row5_col4,#T_1494d_row5_col5,#T_1494d_row5_col6,#T_1494d_row6_col0,#T_1494d_row6_col1,#T_1494d_row6_col2,#T_1494d_row6_col3,#T_1494d_row6_col4,#T_1494d_row6_col5,#T_1494d_row6_col6,#T_1494d_row7_col0,#T_1494d_row7_col1,#T_1494d_row7_col2,#T_1494d_row7_col3,#T_1494d_row7_col4,#T_1494d_row7_col5,#T_1494d_row7_col6,#T_1494d_row8_col0,#T_1494d_row8_col1,#T_1494d_row8_col2,#T_1494d_row8_col3,#T_1494d_row8_col4,#T_1494d_row8_col5,#T_1494d_row8_col6,#T_1494d_row9_col0,#T_1494d_row9_col1,#T_1494d_row9_col2,#T_1494d_row9_col3,#T_1494d_row9_col4,#T_1494d_row9_col5,#T_1494d_row9_col6,#T_1494d_row10_col0,#T_1494d_row10_col1,#T_1494d_row10_col2,#T_1494d_row10_col3,#T_1494d_row10_col4,#T_1494d_row10_col5,#T_1494d_row10_col6,#T_1494d_row11_col0,#T_1494d_row11_col1,#T_1494d_row11_col2,#T_1494d_row11_col3,#T_1494d_row11_col4,#T_1494d_row11_col5,#T_1494d_row11_col6,#T_1494d_row12_col0,#T_1494d_row12_col1,#T_1494d_row12_col2,#T_1494d_row12_col3,#T_1494d_row12_col4,#T_1494d_row12_col5,#T_1494d_row12_col6,#T_1494d_row13_col0,#T_1494d_row13_col1,#T_1494d_row13_col2,#T_1494d_row13_col3,#T_1494d_row13_col4,#T_1494d_row13_col5,#T_1494d_row13_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_1494d_row0_col1,#T_1494d_row0_col5,#T_1494d_row0_col6,#T_1494d_row1_col2,#T_1494d_row1_col3,#T_1494d_row1_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_1494d_row0_col7,#T_1494d_row1_col7,#T_1494d_row2_col7,#T_1494d_row3_col7,#T_1494d_row4_col7,#T_1494d_row5_col7,#T_1494d_row6_col7,#T_1494d_row7_col7,#T_1494d_row8_col7,#T_1494d_row10_col7,#T_1494d_row11_col7,#T_1494d_row12_col7,#T_1494d_row13_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_1494d_row9_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_1494d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1494d_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_1494d_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_1494d_row0_col1" class="data row0 col1" >45.3093</td>
#                         <td id="T_1494d_row0_col2" class="data row0 col2" >4009.9611</td>
#                         <td id="T_1494d_row0_col3" class="data row0 col3" >63.0331</td>
#                         <td id="T_1494d_row0_col4" class="data row0 col4" >0.6611</td>
#                         <td id="T_1494d_row0_col5" class="data row0 col5" >0.1515</td>
#                         <td id="T_1494d_row0_col6" class="data row0 col6" >0.1091</td>
#                         <td id="T_1494d_row0_col7" class="data row0 col7" >0.9680</td>
#             </tr>
#             <tr>
#                         <th id="T_1494d_level0_row1" class="row_heading level0 row1" >et</th>
#                         <td id="T_1494d_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#                         <td id="T_1494d_row1_col1" class="data row1 col1" >46.3996</td>
#                         <td id="T_1494d_row1_col2" class="data row1 col2" >3985.8867</td>
#                         <td id="T_1494d_row1_col3" class="data row1 col3" >63.0041</td>
#                         <td id="T_1494d_row1_col4" class="data row1 col4" >0.6629</td>
#                         <td id="T_1494d_row1_col5" class="data row1 col5" >0.1555</td>
#                         <td id="T_1494d_row1_col6" class="data row1 col6" >0.1123</td>
#                         <td id="T_1494d_row1_col7" class="data row1 col7" >0.1920</td>
#             </tr>
#             <tr>
#                         <th id="T_1494d_level0_row2" class="row_heading level0 row2" >gbr</th>
#                         <td id="T_1494d_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_1494d_row2_col1" class="data row2 col1" >47.4480</td>
#                         <td id="T_1494d_row2_col2" class="data row2 col2" >4342.4268</td>
#                         <td id="T_1494d_row2_col3" class="data row2 col3" >65.6270</td>
#                         <td id="T_1494d_row2_col4" class="data row2 col4" >0.6330</td>
#                         <td id="T_1494d_row2_col5" class="data row2 col5" >0.1573</td>
#                         <td id="T_1494d_row2_col6" class="data row2 col6" >0.1127</td>
#                         <td id="T_1494d_row2_col7" class="data row2 col7" >0.0640</td>
#             </tr>
#             <tr>
#                         <th id="T_1494d_level0_row3" class="row_heading level0 row3" >rf</th>
#                         <td id="T_1494d_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#                         <td id="T_1494d_row3_col1" class="data row3 col1" >47.4622</td>
#                         <td id="T_1494d_row3_col2" class="data row3 col2" >4213.9110</td>
#                         <td id="T_1494d_row3_col3" class="data row3 col3" >64.7584</td>
#                         <td id="T_1494d_row3_col4" class="data row3 col4" >0.6436</td>
#                         <td id="T_1494d_row3_col5" class="data row3 col5" >0.1581</td>
#                         <td id="T_1494d_row3_col6" class="data row3 col6" >0.1145</td>
#                         <td id="T_1494d_row3_col7" class="data row3 col7" >0.1760</td>
#             </tr>
#             <tr>
#                         <th id="T_1494d_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#                         <td id="T_1494d_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_1494d_row4_col1" class="data row4 col1" >47.5172</td>
#                         <td id="T_1494d_row4_col2" class="data row4 col2" >4335.0982</td>
#                         <td id="T_1494d_row4_col3" class="data row4 col3" >65.6906</td>
#                         <td id="T_1494d_row4_col4" class="data row4 col4" >0.6326</td>
#                         <td id="T_1494d_row4_col5" class="data row4 col5" >0.1572</td>
#                         <td id="T_1494d_row4_col6" class="data row4 col6" >0.1139</td>
#                         <td id="T_1494d_row4_col7" class="data row4 col7" >0.3080</td>
#             </tr>
#             <tr>
#                         <th id="T_1494d_level0_row5" class="row_heading level0 row5" >xgboost</th>
#                         <td id="T_1494d_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_1494d_row5_col1" class="data row5 col1" >49.1034</td>
#                         <td id="T_1494d_row5_col2" class="data row5 col2" >4497.8227</td>
#                         <td id="T_1494d_row5_col3" class="data row5 col3" >66.9090</td>

# %%
dinner_regression_best_models_tuned[0].get_feature_importance()
# Out:
# array([9.85390119e+00, 1.23191220e+01, 3.81041743e+00, 9.88517015e+00,
#        4.57404490e+00, 2.89904811e+01, 7.81228759e+00, 1.13223587e+00,
#        1.06109230e+00, 4.45137387e-02, 1.03815628e-01, 1.51786296e-01,
#        2.76575759e+00, 5.13065869e-01, 7.58060966e-02, 2.89718741e+00,
#        8.76355001e-01, 9.30572351e-01, 0.00000000e+00, 1.51908275e-01,
#        1.97410203e-01, 5.36938932e-01, 3.84719331e-01, 3.81884536e-01,
#        0.00000000e+00, 4.44316560e-02, 1.53654545e-01, 0.00000000e+00,
#        0.00000000e+00, 1.13998746e-01, 0.00000000e+00, 4.35084226e-02,
#        0.00000000e+00, 0.00000000e+00, 6.18264789e-02, 0.00000000e+00,
#        2.41251630e-02, 3.60940865e-01, 4.59604235e-02, 1.45910205e-01,
#        1.45824829e-01, 3.03944925e-02, 2.52825336e-02, 7.65229388e-03,
#        0.00000000e+00, 0.00000000e+00, 7.73281793e-02, 5.71009241e-02,
#        2.58346707e-02, 2.50265449e-01, 5.49365467e-02, 1.45098424e-01,
#        6.75187491e-03, 1.97856732e-01, 3.37633342e-02, 0.00000000e+00,
#        1.29877796e-01, 0.00000000e+00, 0.00000000e+00, 9.60740975e-02,
#        1.40469016e-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.38940066e-02, 0.00000000e+00, 1.26411829e-01, 2.93026291e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.82509688e-02, 0.00000000e+00, 0.00000000e+00,
#        2.58343845e-01, 5.12168942e-02, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.09134581e-02, 1.94750235e-02, 0.00000000e+00,
#        4.16601648e-02, 5.24861278e-02, 7.38627668e-02, 1.78607546e-02,
#        1.64602594e-01, 9.82987598e-01, 5.82984569e-01, 3.32231307e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.47082441e-02,
#        2.98847076e-02, 0.00000000e+00, 0.00000000e+00, 6.37365130e-01,
#        4.52511033e-02, 3.70971714e-01, 1.64138406e+00, 6.02020244e-01,
#        1.08901569e-01, 1.06186383e-01, 8.71943061e-02, 7.76956084e-03,
#        1.15515605e-01, 1.92245171e+00, 0.00000000e+00])

# %%
dinner_regression_best_models_tuned = [tune_model(model, optimize='MAE') for model in lunch_regression_best_models]
# Out:
# <style  type="text/css" >
# #T_691f6_row5_col0,#T_691f6_row5_col1,#T_691f6_row5_col2,#T_691f6_row5_col3,#T_691f6_row5_col4,#T_691f6_row5_col5{
#             background:  yellow;
#         }</style><table id="T_691f6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_691f6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_691f6_row0_col0" class="data row0 col0" >46.8623</td>
#                         <td id="T_691f6_row0_col1" class="data row0 col1" >4212.9006</td>
#                         <td id="T_691f6_row0_col2" class="data row0 col2" >64.9069</td>
#                         <td id="T_691f6_row0_col3" class="data row0 col3" >0.6442</td>
#                         <td id="T_691f6_row0_col4" class="data row0 col4" >0.1453</td>
#                         <td id="T_691f6_row0_col5" class="data row0 col5" >0.1043</td>
#             </tr>
#             <tr>
#                         <th id="T_691f6_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_691f6_row1_col0" class="data row1 col0" >45.9561</td>
#                         <td id="T_691f6_row1_col1" class="data row1 col1" >3506.0913</td>
#                         <td id="T_691f6_row1_col2" class="data row1 col2" >59.2123</td>
#                         <td id="T_691f6_row1_col3" class="data row1 col3" >0.7001</td>
#                         <td id="T_691f6_row1_col4" class="data row1 col4" >0.1317</td>
#                         <td id="T_691f6_row1_col5" class="data row1 col5" >0.1023</td>
#             </tr>
#             <tr>
#                         <th id="T_691f6_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_691f6_row2_col0" class="data row2 col0" >50.6349</td>
#                         <td id="T_691f6_row2_col1" class="data row2 col1" >5521.6006</td>
#                         <td id="T_691f6_row2_col2" class="data row2 col2" >74.3075</td>
#                         <td id="T_691f6_row2_col3" class="data row2 col3" >0.5356</td>
#                         <td id="T_691f6_row2_col4" class="data row2 col4" >0.1786</td>
#                         <td id="T_691f6_row2_col5" class="data row2 col5" >0.1193</td>
#             </tr>
#             <tr>
#                         <th id="T_691f6_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_691f6_row3_col0" class="data row3 col0" >51.2972</td>
#                         <td id="T_691f6_row3_col1" class="data row3 col1" >4425.8640</td>
#                         <td id="T_691f6_row3_col2" class="data row3 col2" >66.5272</td>
#                         <td id="T_691f6_row3_col3" class="data row3 col3" >0.6458</td>
#                         <td id="T_691f6_row3_col4" class="data row3 col4" >0.1688</td>
#                         <td id="T_691f6_row3_col5" class="data row3 col5" >0.1312</td>
#             </tr>
#             <tr>
#                         <th id="T_691f6_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_691f6_row4_col0" class="data row4 col0" >48.3624</td>
#                         <td id="T_691f6_row4_col1" class="data row4 col1" >4400.1674</td>
#                         <td id="T_691f6_row4_col2" class="data row4 col2" >66.3338</td>
#                         <td id="T_691f6_row4_col3" class="data row4 col3" >0.6088</td>
#                         <td id="T_691f6_row4_col4" class="data row4 col4" >0.1756</td>
#                         <td id="T_691f6_row4_col5" class="data row4 col5" >0.1220</td>
#             </tr>
#             <tr>
#                         <th id="T_691f6_level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_691f6_row5_col0" class="data row5 col0" >48.6226</td>
#                         <td id="T_691f6_row5_col1" class="data row5 col1" >4413.3248</td>
#                         <td id="T_691f6_row5_col2" class="data row5 col2" >66.2575</td>
#                         <td id="T_691f6_row5_col3" class="data row5 col3" >0.6269</td>
#                         <td id="T_691f6_row5_col4" class="data row5 col4" >0.1600</td>
#                         <td id="T_691f6_row5_col5" class="data row5 col5" >0.1158</td>
#             </tr>
#             <tr>
#                         <th id="T_691f6_level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_691f6_row6_col0" class="data row6 col0" >2.0727</td>
#                         <td id="T_691f6_row6_col1" class="data row6 col1" >646.8150</td>
#                         <td id="T_691f6_row6_col2" class="data row6 col2" >4.8237</td>
#                         <td id="T_691f6_row6_col3" class="data row6 col3" >0.0542</td>
#                         <td id="T_691f6_row6_col4" class="data row6 col4" >0.0184</td>
#                         <td id="T_691f6_row6_col5" class="data row6 col5" >0.0110</td>
#             </tr>
#     </tbody></table>

# %%
dinner_model = blend_models(estimator_list=dinner_regression_best_models, fold=5, optimize='MAE')
# Out:
# <style  type="text/css" >
# #T_eee84_row5_col0,#T_eee84_row5_col1,#T_eee84_row5_col2,#T_eee84_row5_col3,#T_eee84_row5_col4,#T_eee84_row5_col5{
#             background:  yellow;
#         }</style><table id="T_eee84_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eee84_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eee84_row0_col0" class="data row0 col0" >41.7308</td>
#                         <td id="T_eee84_row0_col1" class="data row0 col1" >3224.2788</td>
#                         <td id="T_eee84_row0_col2" class="data row0 col2" >56.7827</td>
#                         <td id="T_eee84_row0_col3" class="data row0 col3" >0.7277</td>
#                         <td id="T_eee84_row0_col4" class="data row0 col4" >0.1315</td>
#                         <td id="T_eee84_row0_col5" class="data row0 col5" >0.0948</td>
#             </tr>
#             <tr>
#                         <th id="T_eee84_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_eee84_row1_col0" class="data row1 col0" >42.8660</td>
#                         <td id="T_eee84_row1_col1" class="data row1 col1" >3112.8588</td>
#                         <td id="T_eee84_row1_col2" class="data row1 col2" >55.7930</td>
#                         <td id="T_eee84_row1_col3" class="data row1 col3" >0.7338</td>
#                         <td id="T_eee84_row1_col4" class="data row1 col4" >0.1228</td>
#                         <td id="T_eee84_row1_col5" class="data row1 col5" >0.0948</td>
#             </tr>
#             <tr>
#                         <th id="T_eee84_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_eee84_row2_col0" class="data row2 col0" >47.8771</td>
#                         <td id="T_eee84_row2_col1" class="data row2 col1" >5041.9565</td>
#                         <td id="T_eee84_row2_col2" class="data row2 col2" >71.0067</td>
#                         <td id="T_eee84_row2_col3" class="data row2 col3" >0.5760</td>
#                         <td id="T_eee84_row2_col4" class="data row2 col4" >0.1673</td>
#                         <td id="T_eee84_row2_col5" class="data row2 col5" >0.1155</td>
#             </tr>
#             <tr>
#                         <th id="T_eee84_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_eee84_row3_col0" class="data row3 col0" >46.2995</td>
#                         <td id="T_eee84_row3_col1" class="data row3 col1" >3877.7496</td>
#                         <td id="T_eee84_row3_col2" class="data row3 col2" >62.2716</td>
#                         <td id="T_eee84_row3_col3" class="data row3 col3" >0.6897</td>
#                         <td id="T_eee84_row3_col4" class="data row3 col4" >0.1547</td>
#                         <td id="T_eee84_row3_col5" class="data row3 col5" >0.1173</td>
#             </tr>
#             <tr>
#                         <th id="T_eee84_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_eee84_row4_col0" class="data row4 col0" >45.0357</td>
#                         <td id="T_eee84_row4_col1" class="data row4 col1" >3971.0852</td>
#                         <td id="T_eee84_row4_col2" class="data row4 col2" >63.0165</td>
#                         <td id="T_eee84_row4_col3" class="data row4 col3" >0.6470</td>
#                         <td id="T_eee84_row4_col4" class="data row4 col4" >0.1701</td>
#                         <td id="T_eee84_row4_col5" class="data row4 col5" >0.1157</td>
#             </tr>
#             <tr>
#                         <th id="T_eee84_level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_eee84_row5_col0" class="data row5 col0" >44.7618</td>
#                         <td id="T_eee84_row5_col1" class="data row5 col1" >3845.5858</td>
#                         <td id="T_eee84_row5_col2" class="data row5 col2" >61.7741</td>
#                         <td id="T_eee84_row5_col3" class="data row5 col3" >0.6748</td>
#                         <td id="T_eee84_row5_col4" class="data row5 col4" >0.1493</td>
#                         <td id="T_eee84_row5_col5" class="data row5 col5" >0.1076</td>
#             </tr>
#             <tr>
#                         <th id="T_eee84_level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_eee84_row6_col0" class="data row6 col0" >2.2327</td>
#                         <td id="T_eee84_row6_col1" class="data row6 col1" >688.6216</td>
#                         <td id="T_eee84_row6_col2" class="data row6 col2" >5.4354</td>
#                         <td id="T_eee84_row6_col3" class="data row6 col3" >0.0584</td>
#                         <td id="T_eee84_row6_col4" class="data row6 col4" >0.0190</td>
#                         <td id="T_eee84_row6_col5" class="data row6 col5" >0.0105</td>
#             </tr>
#     </tbody></table>

# %%
pred = predict_model(dinner_model)
# Out:
# <style  type="text/css" >
# </style><table id="T_bc997_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bc997_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bc997_row0_col0" class="data row0 col0" >Voting Regressor</td>
#                         <td id="T_bc997_row0_col1" class="data row0 col1" >107.0931</td>
#                         <td id="T_bc997_row0_col2" class="data row0 col2" >17300.2967</td>
#                         <td id="T_bc997_row0_col3" class="data row0 col3" >131.5306</td>
#                         <td id="T_bc997_row0_col4" class="data row0 col4" >-0.4582</td>
#                         <td id="T_bc997_row0_col5" class="data row0 col5" >0.2718</td>
#                         <td id="T_bc997_row0_col6" class="data row0 col6" >0.2552</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 테스트

# %% [markdown]
# ### 테스트 데이터 예측

# %%
final_model_dinner = finalize_model(dinner_model)
prep_pipe_dinner = get_config('prep_pipe')
prep_pipe_dinner.steps.append(['trained_model', final_model_dinner])

# %%
pred_dinner = prep_pipe_dinner.predict(dinner_test)
submission.iloc[:,2] = pred_dinner
submission.head()
# Out:
#            일자          중식계         석식계
# 0  2021-01-27  1030.240513  383.742340
# 1  2021-01-28   951.382904  391.616347
# 2  2021-01-29   616.514112  247.968474
# 3  2021-02-01  1224.098803  550.179260
# 4  2021-02-02   976.909941  466.274002

# %% [markdown]
# # 저장

# %%
import datetime
today = str(datetime.datetime.now().date()).replace("-","")
print("오늘 날짜 : " + today)

submission.to_csv(f'../submission/{today}_pycaret_KJH.csv', index =False)
# Out:
# 오늘 날짜 : 20210627

# %%
def plot_feature_importance(importance, names, model_type):
    
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    plt.figure(figsize=(10,8))

    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])

    plt.title(model_type + ' Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')

# %%
len(dinner_regression_best_models_tuned[0].get_feature_importance())
# Out:
# 111

# %%
plot_feature_importance(dinner_regression_best_models_tuned[0].get_feature_importance(),dinner_train.columns,"CATBOOST")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-292-40601b04b983> in <module>
# ----> 1 plot_feature_importance(dinner_regression_best_models_tuned[0].get_feature_importance(),dinner_train.columns,"CATBOOST")
#
# <ipython-input-285-15a35cdf4d00> in plot_feature_importance(importance, names, model_type)
#       5
#       6     data={'feature_names':feature_names,'feature_importance':feature_importance}
# ----> 7     fi_df = pd.DataFrame(data)
#       8
#       9     fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# C:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# C:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# C:\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length
